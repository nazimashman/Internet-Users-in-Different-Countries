# %%
import requests
import re
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import urllib.request, urllib.parse, urllib.error
import ssl

# %%
# Begin initial scrape to get country names and country codes. 
# Country codes will be used to access the individual webpages fo each country.

# Scrape page

ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

# Read the HTML from the URL and pass on to BeautifulSoup
url = 'https://www.cia.gov/library/publications/the-world-factbook/'
print("Opening the file connection...")
uh= urllib.request.urlopen(url, context=ctx)
print("HTTP status",uh.getcode())
html =uh.read().decode()
print(f"Reading done. Total {len(html)} characters read.")

soup = BeautifulSoup(html, 'html.parser')
print(soup.prettify())
# Out:
# Opening the file connection...
# HTTP status 200
# Reading done. Total 75080 characters read.
# <!DOCTYPE html>
# <!--[if lt IE 7]> <html class="no-js lt-ie9 lt-ie8 lt-ie7" lang="en"> <![endif]-->
# <!--[if IE 7]>    <html class="no-js lt-ie9 lt-ie8" lang="en"> <![endif]-->
# <!--[if IE 8]>    <html class="no-js lt-ie9" lang="en"> <![endif]-->
# <!--[if gt IE 8]><!-->
# <html class="no-js" lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
#  <!--<![endif]-->
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <link href="css/publications.css" rel="stylesheet" type="text/css"/>
#   <link href="css/publications-detail.css" rel="stylesheet" type="text/css"/>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <title>
#    The World Factbook — Central Intelligence Agency
#   </title>
#   <meta content="" name="description"/>
#   <meta content="width=device-width" name="viewport"/>
#   <meta content="Apr 01, 2016" name="LastModified"/>
#   <link href="css/jobcart.css" rel="stylesheet"/>
#   <link href="css/smallscreen.css" rel="stylesheet"/>
#   <link href="css/modules.css" rel="stylesheet"/>
#   <!--[if lt IE 9]><link href="css/fullscreen.css" rel="stylesheet" type="text/css"><![endif]-->
#   <link href="css/fullscreen.css" media="only screen and (min-width: 993px)" rel="stylesheet" type="text/css"/>
#   <script src="js/modernizr.custom.73407.js">
#   </script>
#   <script src="js/jquery-1.8.3.min.js" type="text/javascript">
#   </script>
#   <script src="js/response.min.js" type="text/javascript">
#   </script>
#   <script src="js/rwd.js" type="text/javascript">
#   </script>
#   <script src="js/jquery.main.js" type="text/javascript">
#   </script>
#   <script src="js/connect.js" type="text/javascript">
#   </script>
#   <!-- css files for popup -->
#   <script>
#    var isIElt9 = false;
#   </script>
#   <link href="css/bootstrap_customized.css" rel="stylesheet"/>
#   <link href="css/expandcollapse.css" media="screen" rel="stylesheet" type="text/css"/>
#   <!--[if lt IE 9]>
#     <script async src="js/respond.min.js"></script>
#     <script async src="js/html5shiv.min.js"></script>
#     <script>var isIElt9 = true;</script>
# <![endif]-->
#   <!--   jquery code added for popup -->
#   <script async="" src="js/bootstrap_customized.min.js">
#   </script>
#   <!-- our public key -->
#   <script async="" src="/js2/pubkey.js">
#   </script>
#   <!-- image preloading -->
#   <script>
#    prePic = new Image();
#   prePic.src ="images/separator-2.gif";
#   prePic2 = new Image();
#   prePic2.src="images/arrow-5.gif";
#   prePic3 = new Image();
#   prePic3.src="images/bg-heading-panel.jpg";
#   prePic4 = new Image();
#   prePic4.src="images/heading-banners/CHI12052_Headers_contact.jpg";
#   </script>
#   <script src="js/jquery.ba-throttle-debounce.min.js" type="text/javascript">
#   </script>
#   <script src="js/expandcollapse.js" type="text/javascript">
#   </script>
#  </head>
#  <body class="template-document_view_publications_detail portaltype-agencypage site-CIAgov section-library icons-on">
#   <div>
#    <noscript>
#     Javascript must be enabled for the correct page display
#    </noscript>
#    <div id="wrapper">
#     <!-- Modal for Landing Page-->
#     <div aria-hidden="true" aria-labelledby="myModalLabel" class="modal fade" id="popupLandingModal" role="dialog" style="z-index:2147483647;overflow:auto" tabindex="-1">
#      <div class="modal-dialog">
#       <div class="modal-content">
#        <div class="modal-body">
#         <div class="section-contact-cia main-block-popup">
#          <button aria-hidden="true" aria-label="Close" class="cfclose" data-dismiss="modal" type="button">
#           ×
#          </button>
#          <br/>
#          <section id="mainLanding">
#           <div class="section-contact-cia heading-panel" style="width:93%">
#            <!--  <h1>Contact CIA</h1> -->
#           </div>
#           <div class="main-holder threecol" style="width:100%">
#            <div>
#             <ul class="breadcrumbs">
#              <li>
#               <a href="/">
#                Home
#               </a>
#              </li>
#              <li>
#               <a href="/library">
#                Library
#               </a>
#              </li>
#              <li>
#               <a href="/library/publications">
#                Publications
#               </a>
#              </li>
#              <li>
#               The World Factbook
#              </li>
#             </ul>
#             <article class="description-box">
#              <a id="main-content" tabindex="-1">
#              </a>
#              <div>
#               <div class="">
#                <div id="content">
#                 <h1>
#                  Contact CIA
#                 </h1>
#                 <div>
#                  <div class="" id="parent-fieldname-text-55a5766e45f049b42fce0fdbf970b9ae">
#                   <p>
#                    The Office of Public Affairs (OPA) is the single point of contact for all inquiries about the Central Intelligence Agency (CIA).
#                   </p>
#                   <p>
#                    We read every letter, fax, or e-mail we receive, and we will convey your comments to CIA officials outside OPA as appropriate. However, with limited staff and resources, we simply cannot respond to all who write to us.
#                   </p>
#                   <hr class="centerline" styple="margin-top:2px;margin-bottom:2px;"/>
#                   <h3>
#                    Contact Information
#                   </h3>
#                   <p>
#                    <a class="contactTriggerFromLanding btn btn-info btn-block" href="#" role="button">
#                     Submit questions or comments online
#                    </a>
#                   </p>
#                   <p>
#                    <b>
#                     By postal mail:
#                    </b>
#                    <br/>
#                    Central Intelligence Agency
#                    <br/>
#                    Office of Public Affairs
#                    <br/>
#                    Washington, D.C. 20505
#                   </p>
#                   <p>
#                    <b>
#                     By phone:
#                     <br/>
#                    </b>
#                    (703) 482-0623
#                    <br/>
#                    Open during normal business hours.
#                   </p>
#                   <p>
#                    <b>
#                     By fax:
#                     <br/>
#                    </b>
#                    (571) 204-3800
#                    <i>
#                     <br/>
#                     (please include a phone number where we may call you)
#                    </i>
#                   </p>
#                   <p>
#                    <br/>
#                    Contact the
#                    <a class="internal-link" href="/offices-of-cia/inspector-general/index.html">
#                     Office of Inspector General
#                    </a>
#                   </p>
#                   <p>
#                    Contact the
#                    <a class="internal-link" href="/contact-cia/employment-verification-office.html">
#                     Employment Verification Office
#                    </a>
#                   </p>
#                   <p>
#                   </p>
#                   <hr class="centerline" styple="margin-top:2px;margin-bottom:2px;"/>
#                   <p>
#                    <b>
#                     Before contacting us:
#                    </b>
#                   </p>
#                   <ul>
#                    <li>
#                     Please check our
#                     <a href="/sitemap.html" title="Site Map">
#                      <b>
#                       site map
#                      </b>
#                     </a>
#                     ,
#                     <b>
#                      search
#                     </b>
#                     feature, or
#                     <b>
#                      our site navigation on the left
#                     </b>
#                     to locate the information you seek. We do not routinely respond to questions for which answers are found within this Web site.
#                     <br/>
#                     <br/>
#                    </li>
#                    <li>
#                     <a href="/careers/index.html" title="Careers">
#                      <b>
#                       Employment
#                      </b>
#                     </a>
#                     <b>
#                      :
#                     </b>
#                     We do not routinely answer questions about employment beyond the information on this Web site, and we do not routinely answer inquiries about the status of job applications. Recruiting will contact applicants within 45 days if their qualifications meet our needs.
#                     <br/>
#                     <br/>
#                     Because of safety concerns for the prospective applicant, as well as security and communication issues, the CIA Recruitment Center does not accept resumes, nor can we return phone calls, e-mails or other forms of communication, from US citizens living outside of the US. When you return permanently to the US (not on vacation or leave), please visit the
#                     <a href="/careers/opportunities/index.html" title="Careers at CIA">
#                      CIA Careers page
#                     </a>
#                     and apply online for the position of interest.
#                     <br/>
#                     <br/>
#                     To verify an employee's employment, please contact the
#                     <a class="internal-link" href="/contact-cia/employment-verification-office.html">
#                      Employment Verification Office
#                     </a>
#                     .
#                     <br/>
#                     <br/>
#                    </li>
#                    <li>
#                     <b>
#                      Solicitations to transfer large sums of money to your bank account:
#                     </b>
#                     If you receive a solicitation to transfer a large amount of money from an African nation to your bank account in exchange for a payment of millions of dollars, go to the US Secret Service Web site for information about the Nigerian Advance Fee Fraud or "4-1-9" Fraud scheme.
#                     <br/>
#                     <br/>
#                    </li>
#                    <li>
#                     If you have information which you believe might be of interest to the CIA in pursuit of the CIA's foreign intelligence mission, you may use our
#                     <a class="contactTriggerFromLanding" href="#">
#                      <b>
#                       e-mail form
#                      </b>
#                     </a>
#                     . We will carefully protect all information you provide, including your identity. The CIA, as a foreign intelligence agency, does not engage in US domestic law enforcement.
#                     <br/>
#                     <br/>
#                    </li>
#                    <li>
#                     If you have information relating to Iraq which you believe might be of interest to the US Government, please contact us through the
#                     <a href="/about-cia/iraqi-rewards-program.html" title="Iraqi Rewards Program">
#                      <b>
#                       Iraqi Rewards Program
#                      </b>
#                     </a>
#                     —
#                     <a href="/about-cia/iraqi-rewards-program.html" title="Iraqi Rewards Program">
#                      <img alt="برنامج مكافآت العراق" class="image-inline" src="/contact-cia/secondary_page_link.gif/image.gif" title="secondary_page_link.gif"/>
#                     </a>
#                    </li>
#                   </ul>
#                  </div>
#                 </div>
#                </div>
#               </div>
#              </div>
#             </article>
#            </div>
#           </div>
#          </section>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#     <!-- Modal for Contact Page-->
#     <div aria-hidden="true" aria-labelledby="myModalLabel" class="modal fade" id="popupContactModal" role="dialog" style="z-index:2147483647;overflow:auto" tabindex="-1">
#      <div class="modal-dialog">
#       <div class="modal-content">
#        <div class="modal-body">
#         <div class="section-contact-cia main-block-popup">
#          <button aria-hidden="true" aria-label="Close" class="cfclose" data-dismiss="modal" type="button">
#           ×
#          </button>
#          <br/>
#          <div id="mainContact">
#           <div class="section-contact-cia heading-panel" style="width:93%">
#            <h1>
#             Library
#            </h1>
#           </div>
#           <div class="main-holder threecol" style="width:100%">
#            <div id="contentContact">
#             <ul class="breadcrumbs">
#              <li>
#               <a href="/">
#                Home
#               </a>
#              </li>
#              <li>
#               <a href="/library">
#                Library
#               </a>
#              </li>
#              <li>
#               <a href="/library/publications">
#                Publications
#               </a>
#              </li>
#              <li>
#               The World Factbook
#              </li>
#             </ul>
#             <div class="description-box">
#              <a id="main-content" tabindex="-1">
#              </a>
#              <div class="text-holderPopup" style="width:100%">
#               <div id="viewlet-above-content">
#               </div>
#               <div class="">
#                <div id="contentContact">
#                 <h1>
#                  <div id="popupBanner" style="margin-left:5%;margin-right:5%;color:#5f1d1d;font-size:0.6em">
#                   Contact Us Form
#                  </div>
#                 </h1>
#                 <div>
#                  <div class="" id="parent-fieldname-text-b7a1aa432b8946fc8bc268300efe896d">
#                   <div id="popupBodyFull">
#                   </div>
#                   <!-- popup form here -->
#                   <div id="popupBody">
#                    <meta content="telephone=no" name="format-detection"/>
#                    <form accept-charset="utf-8" class="form-horizontal" id="cf" name="cf" role="form">
#                     <div class="form-group" style="margin-left:6%;width:95%;margin-bottom:7px;">
#                      <label for="message" id="mlabel" type="label">
#                       Message:
#                       <span style="color:red">
#                        *
#                       </span>
#                      </label>
#                      <textarea autocapitalize="off" autocomplete="off" autocorrect="off" class="form-control" cols="70" id="message" name="message" placeholder="Message Text" required="true" rows="10" style="resize:none;width:90%"></textarea>
#                      <div id="messageErr">
#                      </div>
#                     </div>
#                     <div class="form-group" style="margin-left:6%;width:95%;margin-bottom:7px;">
#                      <label for="email" id="elabel">
#                       Email:
#                       <span style="color:red">
#                        *
#                       </span>
#                      </label>
#                      <input autocapitalize="off" autocomplete="off" autocorrect="off" class="form-control" id="email" maxlength="40" name="email" pattern="[a-zA-Z0-9._%+-]+@[a-zA-Z0-9.-]+\.[a-zA-Z0-9-]+)*$" placeholder="user@email.com" required="" size="40" style="width:90%" type="email"/>
#                     </div>
#                     <div class="form-group" style="margin-left:6%;width:95%;margin-bottom:7px;">
#                      <label for="name">
#                       Name:
#                      </label>
#                      <input autocapitalize="off" autocomplete="off" autocorrect="off" class="form-control" id="name" maxlength="40" name="sender" placeholder="Firstname Lastname" size="40" style="width:90%" type="text"/>
#                     </div>
#                     <div class="form-inline" style="margin-left:6%;margin-bottom:7px;">
#                      <label>
#                       Phone Number:
#                      </label>
#                      <br/>
#                      <input autocomplete="off" class="form-control" id="phone_cc" maxlength="5" name="ph_cc" placeholder="Country Code" size="12" style="max-width:55%" type="cc"/>
#                      <input autocomplete="off" class="form-control" id="phone" maxlength="20" name="phone_num" placeholder="Number" size="40" style="max-width:90%" type="tel"/>
#                     </div>
#                     <div class="form-inline" style="margin-left:6%;margin-bottom:7px;">
#                      <label>
#                       Mobile/Cell:
#                      </label>
#                      <br/>
#                      <input autocomplete="off" class="form-control" id="cellcc" maxlength="5" name="mobilecc" placeholder="Country Code" size="12" style="max-width:55%" type="cc"/>
#                      <input autocomplete="off" class="form-control" id="cellnumber" maxlength="20" name="mobilenum" placeholder="Number" size="40" style="max-width:90%" type="tel"/>
#                     </div>
#                     <br/>
#                     <p align="center">
#                     </p>
#                     <div id="refId" style="margin-left:5%">
#                     </div>
#                     <br/>
#                     <span id="submitFormButton">
#                      <input class="btn-lg btn-block btn-primary center-block" onclick="javascript:confirm_submission();" type="button" value="Send"/>
#                     </span>
#                     <br/>
#                     <input class="btn-lg btn-block center-block" name="Reset" type="reset" value="Reset"/>
#                     <p align="left">
#                      <span style="color:red;margin-left:5%">
#                       *
#                      </span>
#                      = required
#                     </p>
#                    </form>
#                   </div>
#                  </div>
#                 </div>
#                </div>
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#     <!-- Modal for Report Page-->
#     <div aria-hidden="true" aria-labelledby="myModalLabel" class="modal fade" id="popupReportModal" role="dialog" style="z-index:2147483647;overflow:auto" tabindex="-1">
#      <div class="modal-dialog">
#       <div class="modal-content">
#        <div class="modal-body">
#         <div class="section-contact-cia main-block-popup">
#          <button aria-hidden="true" aria-label="Close" class="cfclose" data-dismiss="modal" type="button">
#           ×
#          </button>
#          <br/>
#          <section id="mainReport">
#           <div class="section-contact-cia heading-panel" style="width:93%">
#            <h1>
#             Library
#            </h1>
#           </div>
#           <div class="main-holder threecol" style="width:100%">
#            <div>
#             <ul class="breadcrumbs">
#              <li>
#               <a href="/">
#                Home
#               </a>
#              </li>
#              <li>
#               <a href="/library">
#                Library
#               </a>
#              </li>
#              <li>
#               <a href="/library/publications">
#                Publications
#               </a>
#              </li>
#              <li>
#               The World Factbook
#              </li>
#             </ul>
#             <article class="description-box">
#              <a id="main-content" tabindex="-1">
#              </a>
#              <div>
#               <div class="">
#                <div>
#                 <h1>
#                  Report Threats
#                 </h1>
#                 <div>
#                  <div class="" id="parent-fieldname-text-84043b8c4f22633413a10d8a8009e18c">
#                   <p>
#                    The United States and its partners continue to face a
# growing number of global threats and challenges. The CIA’s mission
# includes collecting and analyzing information about high priority
# national security issues such as international terrorism, the
# proliferation of weapons of mass destruction, cyber attacks,
# international organized crime and narcotics trafficking, regional
# conflicts, counterintelligence threats, and the effects of environmental
#  and natural disasters.
#                   </p>
#                   <p>
#                    These challenges are international in scope and are priorities for
# the Central Intelligence Agency. If you have information about these or
# other national security challenges, please provide it through our secure
#  online form.  The information you provide will be protected and
# confidential. The CIA is particularly interested in information about
# imminent or planned terrorist attacks.  In cases where an imminent
# threat exists, immediately contact your local law enforcement agencies
# and provide them with the threat information.
#                   </p>
#                   <p align="center">
#                    <a class="contactTriggerFromReport" href="#">
#                     To contact the Central Intelligence Agency click here.
#                    </a>
#                   </p>
#                  </div>
#                 </div>
#                </div>
#               </div>
#              </div>
#             </article>
#            </div>
#           </div>
#          </section>
#         </div>
#        </div>
#        <div>
#        </div>
#       </div>
#      </div>
#     </div>
#     <header id="header">
#      <div class="header-holder">
#       <a accesskey="S" class="skip" href="#main-content">
#        skip to content
#       </a>
#       <span class="bg-globe">
#       </span>
#       <div class="header-panel">
#        <hgroup>
#         <h1 class="logo">
#          <a href="/">
#           <img alt="Central Intelligence Agency" src="/++theme++contextual.agencytheme/images/logo.png"/>
#           <span>
#            Central Intelligence Agency
#           </span>
#          </a>
#         </h1>
#         <h2 class="work-text">
#          The Work Of A Nation. The Center of Intelligence.
#         </h2>
#        </hgroup>
#        <div class="search-form">
#         <div class="row">
#          <div class="add-nav">
#           <ul>
#            <li>
#             <a class="active reportTrigger" href="/contact-cia/report-threats.html" title="Report Threats">
#              Report Threats
#             </a>
#            </li>
#            <li>
#             <a href="/about-cia/iraqi-rewards-program.html" title="Iraqi Rewards Program">
#              رعربيعربي
#             </a>
#            </li>
#            <li>
#             <a class="landingTrigger" href="/contact-cia" title="A single point of contact for all CIA inquiries.">
#              Contact
#             </a>
#            </li>
#           </ul>
#          </div>
#         </div>
#         <div class="row">
#          <form action="/search" id="ciaSearchForm" method="get">
#           <fieldset>
#            <legend class="visuallyhidden">
#             Search CIA.gov
#            </legend>
#            <label class="visuallyhidden" for="q">
#             Search
#            </label>
#            <input class="text" id="q" maxlength="2047" name="q" placeholder="Search CIA.gov..." type="text"/>
#            <input name="site" type="hidden" value="CIA"/>
#            <input name="output" type="hidden" value="xml_no_dtd"/>
#            <input name="client" type="hidden" value="CIA"/>
#            <input name="myAction" type="hidden" value="/search"/>
#            <input name="proxystylesheet" type="hidden" value="CIA"/>
#            <input name="submitMethod" type="hidden" value="get"/>
#            <input class="submit" type="submit" value="Search"/>
#           </fieldset>
#          </form>
#         </div>
#         <div class="row">
#          <ul class="lang-list">
#           <li lang="ar" xml:lang="ar">
#            <a href="/ar" title="Arabic">
#             عربي
#            </a>
#           </li>
#           <li lang="zh-cn" xml:lang="zh-cn">
#            <a href="/zh" title="Chinese">
#             中文
#            </a>
#           </li>
#           <li lang="en" xml:lang="en">
#            <a href="/" title="English">
#             English
#            </a>
#           </li>
#           <li lang="fr" xml:lang="fr">
#            <a href="/fr" title="French">
#             Français
#            </a>
#           </li>
#           <li lang="ru" xml:lang="ru">
#            <a href="/ru" title="Russian">
#             Русский
#            </a>
#           </li>
#           <li lang="es" xml:lang="es">
#            <a href="/es" title="Spanish">
#             Español
#            </a>
#           </li>
#           <li>
#            <a alt="More Languages" class="more" href="/foreign-languages" title="More Languages">
#             More
#             <span class="visuallyhidden">
#              Languages
#             </span>
#            </a>
#           </li>
#          </ul>
#         </div>
#        </div>
#       </div>
#       <nav id="nav">
#        <h3 class="visuallyhidden">
#         Navigation
#        </h3>
#        <ul>
#         <li class="">
#          <a class="" href="/" title="">
#           <span>
#            Home
#           </span>
#          </a>
#         </li>
#         <li class="">
#          <a class="hasChildrens" href="/about-cia" title="About CIA Description">
#           <span>
#            About CIA
#           </span>
#          </a>
#          <div class="drop">
#           <ul class="globalSectionsLevel1 show-static">
#            <li class="plain ">
#             <a class="" href="/about-cia/todays-cia" title="">
#              <span>
#               Today's CIA
#              </span>
#             </a>
#            </li>
#            <li class="plain ">
#             <a class="" href="/about-cia/leadership" title="">
#              <span>
#               Leadership
#              </span>
#             </a>
#            </li>
#            <li class="plain ">
#             <a class="" href="/about-cia/cia-vision-mission-values" title="">
#              <span>
#               CIA Vision, Mission, Ethos &amp; Challenges
#              </span>
#             </a>
#            </li>
#            <li class="plain ">
#             <a class="" href="/about-cia/headquarters-tour" title="">
#              <span>
#               Headquarters Tour
#              </span>
#             </a>
#            </li>
#            <li class="plain ">
#             <a class="" href="/about-cia/cia-museum" title="">
#              <span>
#               CIA Museum
#              </span>
#             </a>
#            </li>
#            <li class="plain ">
#             <a class="" href="/about-cia/history-of-the-cia" title="">
#              <span>
#               History of the CIA
#              </span>
#             </a>
#            </li>
#            <li class="plain ">
#             <a class="" href="/about-cia/publications-review-board" title="Publications Review Board">
#              <span>
#               Publications Review Board
#              </span>
#             </a>
#            </li>
#            <li class="plain ">
#             <a class="" href="/about-cia/accessibility" title="Accessibility ">
#              <span>
#               Accessibility
#              </span>
#             </a>
#            </li>
#            <li class="plain ">
#             <a class="" href="/about-cia/faqs" title="">
#              <span>
#               FAQs
#              </span>
#             </a>
#            </li>
#            <li class="plain ">
#             <a class="" href="/about-cia/no-fear-act" title="Note - link to the No Fear Act parent page, which is housed under EEO">
#              <span>
#               NoFEAR Act
#              </span>
#             </a>
#            </li>
#            <li class="plain ">
#             <a class="" href="/about-cia/site-policies" title="">
#              <span>
#               Site Policies
#              </span>
#             </a>
#            </li>
#           </ul>
#           <div class="static">
#            <img alt="About Menu" class="image-inline" src="/images/section-banners/about-menu/image.jpg" title="About Menu"/>
#            <h4>
#             <a href="/about-cia/">
#              About CIA
#             </a>
#            </h4>
#            <p>
#             Discover the CIA
#             <a href="/about-cia/">
#              history, mission, vision and values
#             </a>
#             .
#            </p>
#           </div>
#           <div class="visualClear">
#            <!-- -->
#           </div>
#          </div>
#         </li>
#         <li class="">
#          <a class="hasChildrens" href="/careers" title="">
#           <span>
#            Careers &amp; Internships
#           </span>
#          </a>
#          <div class="drop">
#           <ul class="globalSectionsLevel1 show-static">
#            <li class="plain ">
#             <a class="" href="/careers/opportunities" title="This is an overview of all career opportunities at the CIA. ">
#              <span>
#               Career Opportunities
#              </span>
#             </a>
#            </li>
#            <li class="plain ">
#             <a class="" href="/careers/student-opportunities" title="This is the student profile page for candidates looking for jobs/ job listings at the CIA. Student Opportunities - Student Profiles">
#              <span>
#               Student Opportunities
#              </span>
#             </a>
#            </li>
#            <li class="plain ">
#             <a class="" href="/careers/application-process" title="How to apply to the CIA.">
#              <span>
#               Application Process
#              </span>
#             </a>
#            </li>
#            <li class="plain ">
#             <a class="" href="/careers/life-at-cia" title="This is the about CIA section of the Careers Site">
#              <span>
#               Life at CIA
#              </span>
#             </a>
#            </li>
#            <li class="plain ">
#             <a class="" href="/careers/benefits.html" title="Every career at the CIA is a rewarding one. In addition to serving your country with the certainty that your work makes a difference, the CIA offers a comprehensive benefits package to reflect the dedication and contributions of our employees.">
#              <span>
#               Benefits
#              </span>
#             </a>
#            </li>
#            <li class="plain ">
#             <a class="" href="/careers/diversity" title="This is the diversity information for the Careers Site">
#              <span>
#               Diversity
#              </span>
#             </a>
#            </li>
#            <li class="plain ">
#             <a class="" href="/careers/military-transition" title="Your prior military service could qualify you to continue to serve your nation at the Central Intelligence Agency. Opportunities for qualified applicants are available in the U.S. and abroad.">
#              <span>
#               Military Transition
#              </span>
#             </a>
#            </li>
#            <li class="plain ">
#             <a class="" href="/careers/games-information" title="">
#              <span>
#               Tools and Challenges
#              </span>
#             </a>
#            </li>
#            <li class="plain ">
#             <a class="" href="/careers/faq" title="Frequently Asked Questions/ FAQ for a Career at the CIA in the Careers Section">
#              <span>
#               FAQs
#              </span>
#             </a>
#            </li>
#            <li class="plain ">
#             <a class="" href="/careers/video-center" title="Repository of CIA videos">
#              <span>
#               Video Center
#              </span>
#             </a>
#            </li>
#           </ul>
#           <div class="static">
#            <img alt="Careers Menu" class="image-inline" src="/images/section-banners/careers-menu/image.jpg" title="Careers Menu"/>
#            <h4>
#             <a href="/careers/">
#              Careers &amp; Internships
#             </a>
#            </h4>
#            <p>
#             Your talent. Your diverse skills. Our mission. Learn more about
#             <a href="/careers/">
#              Career Opportunities at CIA
#             </a>
#             .
#            </p>
#           </div>
#           <div class="visualClear">
#            <!-- -->
#           </div>
#          </div>
#         </li>
#         <li class="">
#          <a class="hasChildrens" href="/offices-of-cia" title="">
#           <span>
#            Offices of CIA
#           </span>
#          </a>
#          <div class="drop">
#           <ul class="globalSectionsLevel1 show-static">
#            <li class="plain ">
#             <a class="" href="/offices-of-cia/intelligence-analysis" title="">
#              <span>
#               Intelligence &amp; Analysis
#              </span>
#             </a>
#            </li>
#            <li class="plain ">
#             <a class="" href="/offices-of-cia/clandestine-service" title="">
#              <span>
#               Clandestine Service
#              </span>
#             </a>
#            </li>
#            <li class="plain ">
#             <a class="" href="/offices-of-cia/science-technology" title="">
#              <span>
#               Science &amp; Technology
#              </span>
#             </a>
#            </li>
#            <li class="plain ">
#             <a class="" href="/offices-of-cia/mission-support" title="">
#              <span>
#               Support to Mission
#              </span>
#             </a>
#            </li>
#            <li class="plain ">
#             <a class="" href="/offices-of-cia/digital-innovation" title="">
#              <span>
#               Digital Innovation
#              </span>
#             </a>
#            </li>
#            <li class="plain ">
#             <a class="" href="/offices-of-cia/mission-centers" title="">
#              <span>
#               Mission Centers
#              </span>
#             </a>
#            </li>
#            <li class="plain ">
#             <a class="" href="/offices-of-cia/human-resources" title="">
#              <span>
#               Human Resources
#              </span>
#             </a>
#            </li>
#            <li class="plain ">
#             <a class="" href="/offices-of-cia/public-affairs" title="Public Affairs">
#              <span>
#               Public Affairs
#              </span>
#             </a>
#            </li>
#            <li class="plain ">
#             <a class="" href="/offices-of-cia/general-counsel" title="">
#              <span>
#               General Counsel
#              </span>
#             </a>
#            </li>
#            <li class="plain ">
#             <a class="" href="/offices-of-cia/equal-employment-opportunity" title="">
#              <span>
#               Equal Employment Opportunity
#              </span>
#             </a>
#            </li>
#            <li class="plain ">
#             <a class="" href="/offices-of-cia/congressional-affairs" title="Office of Congressional Affairs">
#              <span>
#               Congressional Affairs
#              </span>
#             </a>
#            </li>
#            <li class="plain ">
#             <a class="" href="/offices-of-cia/inspector-general" title="Inspector General">
#              <span>
#               Inspector General
#              </span>
#             </a>
#            </li>
#            <li class="plain ">
#             <a class="" href="/offices-of-cia/military-affairs" title="Military Affairs">
#              <span>
#               Military Affairs
#              </span>
#             </a>
#            </li>
#           </ul>
#           <div class="static">
#            <img alt="Offices Menu" class="image-inline" src="/images/section-banners/offices-menu/image.jpg" title="Offices Menu"/>
#            <h4>
#             <a href="/offices-of-cia/">
#              Offices of CIA
#             </a>
#            </h4>
#            <p>
#             <a href="/offices-of-cia/">
#              Learn how the CIA is organized
#             </a>
#             into directorates and key offices, responsible for securing our nation.
#            </p>
#           </div>
#           <div class="visualClear">
#            <!-- -->
#           </div>
#          </div>
#         </li>
#         <li class="">
#          <a class="hasChildrens" href="/news-information" title="News &amp; Information Description">
#           <span>
#            News &amp; Information
#           </span>
#          </a>
#          <div class="drop">
#           <ul class="globalSectionsLevel1 show-static">
#            <li class="plain ">
#             <a class="" href="/news-information/blog" title="">
#              <span>
#               Blog
#              </span>
#             </a>
#            </li>
#            <li class="plain ">
#             <a class="" href="/news-information/press-releases-statements" title="">
#              <span>
#               Press Releases &amp; Statements
#              </span>
#             </a>
#            </li>
#            <li class="plain ">
#             <a class="" href="/news-information/speeches-testimony" title="">
#              <span>
#               Speeches &amp; Testimony
#              </span>
#             </a>
#            </li>
#            <li class="plain ">
#             <a class="" href="/news-information/cia-the-war-on-terrorism" title="">
#              <span>
#               CIA &amp; the War on Terrorism
#              </span>
#             </a>
#            </li>
#            <li class="plain ">
#             <a class="" href="/news-information/featured-story-archive" title="index for featured story">
#              <span>
#               Featured Story Archive
#              </span>
#             </a>
#            </li>
#            <li class="plain ">
#             <a class="" href="/news-information/your-news" title="">
#              <span>
#               Your News
#              </span>
#             </a>
#            </li>
#           </ul>
#           <div class="static">
#            <img alt="News Menu" class="image-inline" src="/images/section-banners/news-menu/image.jpg" title="News Menu"/>
#            <h4>
#             <a href="/news-information/">
#              News &amp; Information
#             </a>
#            </h4>
#            <p>
#             The most up-to-date CIA
#             <a href="/news-information/">
#              news, press releases, information and more
#             </a>
#             .
#            </p>
#           </div>
#           <div class="visualClear">
#            <!-- -->
#           </div>
#          </div>
#         </li>
#         <li class=" active ">
#          <a class="hasChildrens" href="/library" title="">
#           <span>
#            Library
#           </span>
#          </a>
#          <span class="arrow">
#          </span>
#          <div class="drop right">
#           <ul class="globalSectionsLevel1 show-static">
#            <li class="selected ">
#             <a class="" href="/library/publications" title="">
#              <span>
#               Publications
#              </span>
#             </a>
#            </li>
#            <li class="plain ">
#             <a class="" href="/library/center-for-the-study-of-intelligence" title="CSI section">
#              <span>
#               Center for the Study of Intelligence
#              </span>
#             </a>
#            </li>
#            <li class="plain ">
#             <a class="" href="/library/foia" title="">
#              <span>
#               Freedom of Information Act Electronic Reading Room
#              </span>
#             </a>
#            </li>
#            <li class="plain ">
#             <a class="" href="/library/kent-center-occasional-papers" title="">
#              <span>
#               Kent Center Occasional Papers
#              </span>
#             </a>
#            </li>
#            <li class="plain ">
#             <a class="" href="/library/intelligence-literature" title="">
#              <span>
#               Intelligence Literature
#              </span>
#             </a>
#            </li>
#            <li class="plain ">
#             <a class="" href="/library/reports" title="Reports">
#              <span>
#               Reports
#              </span>
#             </a>
#            </li>
#            <li class="plain ">
#             <a class="" href="/library/related-links.html" title="Related Links">
#              <span>
#               Related Links
#              </span>
#             </a>
#            </li>
#            <li class="plain ">
#             <a class="" href="/library/video-center" title="Repository of CIA videos">
#              <span>
#               Video Center
#              </span>
#             </a>
#            </li>
#           </ul>
#           <div class="static">
#            <img alt="Library Menu" class="image-inline" src="/images/section-banners/library-menu/image.jpg" title="Library Menu"/>
#            <h4>
#             <a href="/library/">
#              Library
#             </a>
#            </h4>
#            <p>
#             Our
#             <a href="/library/">
#              open-source library
#             </a>
#             houses the thousands of documents, periodicals, maps and reports released to the public.
#            </p>
#           </div>
#           <div class="visualClear">
#            <!-- -->
#           </div>
#          </div>
#         </li>
#         <li class="">
#          <a class="hasChildrens" href="/kids-page" title="Kids' Page Description">
#           <span>
#            Kids' Zone
#           </span>
#          </a>
#          <div class="drop right">
#           <ul class="globalSectionsLevel1 show-static">
#            <li class="plain ">
#             <a class="" href="/kids-page/k-5th-grade" title="K-5th Grade">
#              <span>
#               K-5th Grade
#              </span>
#             </a>
#            </li>
#            <li class="plain ">
#             <a class="" href="/kids-page/6-12th-grade" title="">
#              <span>
#               6-12th Grade
#              </span>
#             </a>
#            </li>
#            <li class="plain ">
#             <a class="" href="/kids-page/parents-teachers" title="">
#              <span>
#               Parents &amp; Teachers
#              </span>
#             </a>
#            </li>
#            <li class="plain ">
#             <a class="" href="/kids-page/games" title="">
#              <span>
#               Games
#              </span>
#             </a>
#            </li>
#            <li class="plain ">
#             <a class="" href="/kids-page/related-links" title="">
#              <span>
#               Related Links
#              </span>
#             </a>
#            </li>
#            <li class="plain ">
#             <a class="" href="/kids-page/privacy-statement" title="">
#              <span>
#               Privacy Statement
#              </span>
#             </a>
#            </li>
#           </ul>
#           <div class="static">
#            <p>
#             <img alt="Kids Menu" class="image-inline" src="/images/section-banners/kids-menu/image.jpg" title="Kids Menu"/>
#            </p>
#            <h4>
#             <a href="/kids-page/">
#              Kids' Zone
#             </a>
#            </h4>
#            <p>
#             <a href="/kids-page/">
#              Learn more about the Agency
#             </a>
#             and find some top secret things you won't see anywhere else.
#            </p>
#           </div>
#           <div class="visualClear">
#            <!-- -->
#           </div>
#          </div>
#         </li>
#        </ul>
#       </nav>
#      </div>
#     </header>
#     <div class="main-block">
#      <section id="main">
#       <div class="heading-panel">
#        <h1>
#         Library
#        </h1>
#       </div>
#       <div class="main-holder threecol">
#        <div id="sidebar">
#         <nav class="sidebar-nav">
#          <h2 class="visuallyhidden">
#           Secondary Navigation
#          </h2>
#          <ul>
#           <li class="navTreeItem navTreeTopNode">
#            <a class="contenttype-agencyfolder" href="/library" title="">
#             Library
#            </a>
#           </li>
#           <li class="navTreeItem visualNoMarker navTreeItemInPath navTreeFolderish section-publications">
#            <a class="state-published navTreeItemInPath navTreeFolderish contenttype-agencyfolder" href="/library/publications" title="">
#             Publications
#            </a>
#           </li>
#           <li class="navTreeItem visualNoMarker navTreeFolderish section-center-for-the-study-of-intelligence">
#            <a class="state-published navTreeFolderish contenttype-agencyfolder" href="/library/center-for-the-study-of-intelligence" title="CSI section">
#             Center for the Study of Intelligence
#            </a>
#           </li>
#           <li class="navTreeItem visualNoMarker navTreeFolderish section-foia">
#            <a class="state-published navTreeFolderish contenttype-agencyfolder" href="/library/foia" title="">
#             Freedom of Information Act Electronic Reading Room
#            </a>
#           </li>
#           <li class="navTreeItem visualNoMarker navTreeFolderish section-kent-center-occasional-papers">
#            <a class="state-published navTreeFolderish contenttype-agencyfolder" href="/library/kent-center-occasional-papers" title="">
#             Kent Center Occasional Papers
#            </a>
#           </li>
#           <li class="navTreeItem visualNoMarker navTreeFolderish section-intelligence-literature">
#            <a class="state-published navTreeFolderish contenttype-agencyfolder" href="/library/intelligence-literature" title="">
#             Intelligence Literature
#            </a>
#           </li>
#           <li class="navTreeItem visualNoMarker navTreeFolderish section-reports">
#            <a class="state-published navTreeFolderish contenttype-agencyfolder" href="/library/reports" title="Reports">
#             Reports
#            </a>
#           </li>
#           <li class="navTreeItem visualNoMarker section-related-links">
#            <a class="state-published contenttype-agencypage" href="/library/related-links.html" title="Related Links">
#             Related Links
#            </a>
#           </li>
#           <li class="navTreeItem visualNoMarker navTreeFolderish section-video-center">
#            <a class="state-published navTreeFolderish contenttype-agencyfolder" href="/library/video-center" title="Repository of CIA videos">
#             Video Center
#            </a>
#           </li>
#          </ul>
#         </nav>
#         <div class="portletWrapper kssattr-portlethash-706c6f6e652e6c656674636f6c756d6e0a636f6e746578740a2f434941676f760a6e617669676174696f6e" data-portlethash="706c6f6e652e6c656674636f6c756d6e0a636f6e746578740a2f434941676f760a6e617669676174696f6e" id="portletwrapper-706c6f6e652e6c656674636f6c756d6e0a636f6e746578740a2f434941676f760a6e617669676174696f6e">
#         </div>
#        </div>
#        <div id="content">
#         <ul class="breadcrumbs">
#          <li>
#           <a href="/">
#            Home
#           </a>
#          </li>
#          <li>
#           <a href="/library">
#            Library
#           </a>
#          </li>
#          <li>
#           <a href="/library/publications">
#            Publications
#           </a>
#          </li>
#          <li>
#           The World Factbook
#          </li>
#         </ul>
#         <article class="description-box">
#          <a id="main-content" tabindex="-1">
#          </a>
#          <div class="text-holder-full">
#           <div id="content">
#            <div id="content-core">
#             <!-- content goes here -->
#             <div id="wfb-text-holder">
#              <!-- dfl                   <div class="text-box">   -->
#              <!-- Page Content go here -->
#              <!--                <div class="wfbLogo"><img src="./images/banner_ext2.png" alt="World Factbook Banner" /></div>  -->
#              <div id="fbHeader">
#               <div id="fbLogo">
#                <img src="./images/banner_ext2.png" title="World Factbook Title"/>
#               </div>
#               <div id="cntrySelect">
#                <script>
#                 $(document).ready(function() {
#                  // $(".selecter_links").selecter({
#                  // defaultLabel: "Please Select a Country to View",
#                  // links: true
#                  // });
#                  $( ".selecter_links" ).change(function(e) {
#                  if (this.form.selecter_links.selectedIndex > 0) {
#                  window.location = this.form.selecter_links.options[this.form.selecter_links.selectedIndex].value;
#                  }
#                  });
#                  });
#                </script>
#                <form action="#" method="GET">
#                 <select class="selecter_links" name="selecter_links" onchange="document.location.href= this.value;">
#                  <option value="">
#                   Please select a country to view
#                  </option>
#                  <option value="geos/xx.html">
# ...
#                     var mydate=new Date()
# 												var year=mydate.getYear()
# 												if (year < 1000)
# 												year+=1900
# 												var day=mydate.getDay()
# 												var month=mydate.getMonth()
# 												var daym=mydate.getDate()
# 												//if (daym<10)
# 												//daym="0"+daym
# 												var dayarray=new Array("Sunday","Monday","Tuesday","Wednesday","Thursday","Friday","Saturday")
# 												var montharray=new Array("January","February","March","April","May","June","July","August","September","October","November","December")
# 												document.write(" "+dayarray[day]+", "+montharray[month]+" "+daym+" ")
#                    </script>
#                   </span>
#                  </div>
#                 </div>
#                 <div class="whats-new-text">
#                  <iframe allowtransparency="true" frameborder="0" height="220" scrolling="yes" src="docs/whatsnew_index.html" style="padding-bottom: 10px; z-index:1; background-color: transparent; overflow-x:hidden;" title="Whats New" width="430">
#                   HELLO
#                  </iframe>
#                 </div>
#                 <div>
#                  <a href="docs/whatsnew.html" onmouseout="MM_swapImgRestore()" onmouseover="MM_swapImage('View Updates','','graphics/view_updates_btn_on.gif',1)">
#                   <img alt="View All Updates" border="0" name="View Updates" src="graphics/view_updates_btn_off.gif" title="View All Updates"/>
#                  </a>
#                 </div>
#                </div>
#                <!--  end wn -->
#                <div id="buttons">
#                 <ul>
#                  <li>
#                   <a href="docs/refmaps.html" onmouseout="MM_swapImgRestore()" onmouseover="MM_swapImage('maps','','graphics/home_bttn_maps_hover.png',1)">
#                    <img alt="Regional and World Maps" border="0" height="47" id="maps" name="maps" src="graphics/home_bttn_maps.png" width="325"/>
#                   </a>
#                  </li>
#                  <li>
#                   <a href="docs/flagsoftheworld.html" onmouseout="MM_swapImgRestore()" onmouseover="MM_swapImage('flags','','graphics/home_bttn_flags_hover.png',1)">
#                    <img alt="Flags of the World" border="0" height="47" id="flags" name="flags" src="graphics/home_bttn_flags.png" width="325"/>
#                   </a>
#                  </li>
#                  <li>
#                   <a href="rankorder/rankorderguide.html" onmouseout="MM_swapImgRestore()" onmouseover="MM_swapImage('comparisons','','graphics/home_bttn_comparison_hover.png',1)">
#                    <img alt="Guide To Country Comparisons" border="0" height="47" id="comparisons" name="comparisons" src="graphics/home_bttn_comparison.png" width="325"/>
#                   </a>
#                  </li>
#                  <li>
#                   <a href="docs/guidetowfbook.html" onmouseout="MM_swapImgRestore()" onmouseover="MM_swapImage('The World Factbook Users Guide','','graphics/home_bttn_guide_hover.png',1)">
#                    <img alt="The World Factbook Users Guide" border="0" height="47" id="The World Factbook Users Guide" name="The World Factbook Users Guide" src="graphics/home_bttn_guide.png" width="325"/>
#                   </a>
#                  </li>
#                  <li style="text-align:center; padding-top:3px; padding-left:85px; ">
#                   <img src="graphics/home_ornament.jpg"/>
#                  </li>
#                 </ul>
#                </div>
#                <!--  end buttons -->
#               </div>
#               <!--  end wfb-nav-wn -->
#               <!-- End Page Content -->
#              </div>
#              <!--  wfb-text-box -->
#             </div>
#             <!--  wfb-text-holder -->
#             <!-- END added content -->
#            </div>
#           </div>
#          </div>
#         </article>
#        </div>
#        <aside class="content-box-2">
#        </aside>
#       </div>
#      </section>
#      <footer id="footer">
#       <span class="divider">
#       </span>
#       <a class="logo-2" href="#">
#        <img alt="Central Intelligence Agency" height="61" src="/++theme++contextual.agencytheme/images/logo-2.png" width="61"/>
#       </a>
#       <div class="footer-holder">
#        <div class="footer-frame">
#         <nav class="footer-nav">
#          <div class="info-block">
#           <h3>
#            <a href="/about-cia">
#             About CIA
#            </a>
#           </h3>
#           <ul>
#            <li>
#             <a href="/about-cia/todays-cia">
#              Today's CIA
#             </a>
#            </li>
#            <li>
#             <a href="/about-cia/leadership">
#              Leadership
#             </a>
#            </li>
#            <li>
#             <a href="/about-cia/cia-vision-mission-values">
#              CIA Vision, Mission, Ethos &amp; Challenges
#             </a>
#            </li>
#            <li>
#             <a href="/about-cia/headquarters-tour">
#              Headquarters Tour
#             </a>
#            </li>
#            <li>
#             <a href="/about-cia/cia-museum">
#              CIA Museum
#             </a>
#            </li>
#            <li>
#             <a href="/about-cia/history-of-the-cia">
#              History of the CIA
#             </a>
#            </li>
#            <li>
#             <a href="/about-cia/publications-review-board">
#              Publications Review Board
#             </a>
#            </li>
#            <li>
#             <a href="/about-cia/accessibility">
#              Accessibility
#             </a>
#            </li>
#            <li>
#             <a href="/about-cia/faqs">
#              FAQs
#             </a>
#            </li>
#            <li>
#             <a href="/about-cia/no-fear-act">
#              NoFEAR Act
#             </a>
#            </li>
#            <li>
#             <a href="/about-cia/site-policies">
#              Site Policies
#             </a>
#            </li>
#           </ul>
#          </div>
#          <div class="info-block">
#           <h3>
#            <a href="/careers">
#             Careers &amp; Internships
#            </a>
#           </h3>
#           <ul>
#            <li>
#             <a href="/careers/opportunities">
#              Career Opportunities
#             </a>
#            </li>
#            <li>
#             <a href="/careers/student-opportunities">
#              Student Opportunities
#             </a>
#            </li>
#            <li>
#             <a href="/careers/application-process">
#              Application Process
#             </a>
#            </li>
#            <li>
#             <a href="/careers/life-at-cia">
#              Life at CIA
#             </a>
#            </li>
#            <li>
#             <a href="/careers/benefits.html">
#              Benefits
#             </a>
#            </li>
#            <li>
#             <a href="/careers/diversity">
#              Diversity
#             </a>
#            </li>
#            <li>
#             <a href="/careers/military-transition">
#              Military Transition
#             </a>
#            </li>
#            <li>
#             <a href="/careers/games-information">
#              Tools and Challenges
#             </a>
#            </li>
#            <li>
#             <a href="/careers/faq">
#              FAQs
#             </a>
#            </li>
#            <li>
#             <a href="/careers/video-center">
#              Video Center
#             </a>
#            </li>
#           </ul>
#           <h3>
#            <a href="/offices-of-cia">
#             Offices of CIA
#            </a>
#           </h3>
#           <ul>
#            <li>
#             <a href="/offices-of-cia/intelligence-analysis">
#              Intelligence &amp; Analysis
#             </a>
#            </li>
#            <li>
#             <a href="/offices-of-cia/clandestine-service">
#              Clandestine Service
#             </a>
#            </li>
#            <li>
#             <a href="/offices-of-cia/science-technology">
#              Science &amp; Technology
#             </a>
#            </li>
#            <li>
#             <a href="/offices-of-cia/mission-support">
#              Support to Mission
#             </a>
#            </li>
#            <li>
#             <a href="/offices-of-cia/digital-innovation">
#              Digital Innovation
#             </a>
#            </li>
#            <li>
#             <a href="/offices-of-cia/mission-centers">
#              Mission Centers
#             </a>
#            </li>
#            <li>
#             <a href="/offices-of-cia/human-resources">
#              Human Resources
#             </a>
#            </li>
#            <li>
#             <a href="/offices-of-cia/public-affairs">
#              Public Affairs
#             </a>
#            </li>
#            <li>
#             <a href="/offices-of-cia/general-counsel">
#              General Counsel
#             </a>
#            </li>
#            <li>
#             <a href="/offices-of-cia/equal-employment-opportunity">
#              Equal Employment Opportunity
#             </a>
#            </li>
#            <li>
#             <a href="/offices-of-cia/congressional-affairs">
#              Congressional Affairs
#             </a>
#            </li>
#            <li>
#             <a href="/offices-of-cia/inspector-general">
#              Inspector General
#             </a>
#            </li>
#            <li>
#             <a href="/offices-of-cia/military-affairs">
#              Military Affairs
#             </a>
#            </li>
#           </ul>
#          </div>
#          <div class="info-block">
#           <h3>
#            <a href="/news-information">
#             News &amp; Information
#            </a>
#           </h3>
#           <ul>
#            <li>
#             <a href="/news-information/blog">
#              Blog
#             </a>
#            </li>
#            <li>
#             <a href="/news-information/press-releases-statements">
#              Press Releases &amp; Statements
#             </a>
#            </li>
#            <li>
#             <a href="/news-information/speeches-testimony">
#              Speeches &amp; Testimony
#             </a>
#            </li>
#            <li>
#             <a href="/news-information/cia-the-war-on-terrorism">
#              CIA &amp; the War on Terrorism
#             </a>
#            </li>
#            <li>
#             <a href="/news-information/featured-story-archive">
#              Featured Story Archive
#             </a>
#            </li>
#            <li>
#             <a href="/news-information/your-news">
#              Your News
#             </a>
#            </li>
#           </ul>
#           <h3>
#            <a href="/library">
#             Library
#            </a>
#           </h3>
#           <ul>
#            <li>
#             <a href="/library/publications">
#              Publications
#             </a>
#            </li>
#            <li>
#             <a href="/library/center-for-the-study-of-intelligence">
#              Center for the Study of Intelligence
#             </a>
#            </li>
#            <li>
#             <a href="/library/foia">
#              Freedom of Information Act Electronic Reading Room
#             </a>
#            </li>
#            <li>
#             <a href="/library/kent-center-occasional-papers">
#              Kent Center Occasional Papers
#             </a>
#            </li>
#            <li>
#             <a href="/library/intelligence-literature">
#              Intelligence Literature
#             </a>
#            </li>
#            <li>
#             <a href="/library/reports">
#              Reports
#             </a>
#            </li>
#            <li>
#             <a href="/library/related-links.html">
#              Related Links
#             </a>
#            </li>
#            <li>
#             <a href="/library/video-center">
#              Video Center
#             </a>
#            </li>
#           </ul>
#          </div>
#          <div class="info-block add">
#           <h3>
#            <a href="/kids-page">
#             Kids' Zone
#            </a>
#           </h3>
#           <ul>
#            <li>
#             <a href="/kids-page/k-5th-grade">
#              K-5th Grade
#             </a>
#            </li>
#            <li>
#             <a href="/kids-page/6-12th-grade">
#              6-12th Grade
#             </a>
#            </li>
#            <li>
#             <a href="/kids-page/parents-teachers">
#              Parents &amp; Teachers
#             </a>
#            </li>
#            <li>
#             <a href="/kids-page/games">
#              Games
#             </a>
#            </li>
#            <li>
#             <a href="/kids-page/related-links">
#              Related Links
#             </a>
#            </li>
#            <li>
#             <a href="/kids-page/privacy-statement">
#              Privacy Statement
#             </a>
#            </li>
#           </ul>
#           <h3>
#            <a href="/contact-cia">
#             Connect with CIA
#            </a>
#           </h3>
#           <ul class="socials-list">
#            <li>
#             <a class="social-6" href="https://twitter.com/CIA">
#              CIA Twitter
#             </a>
#            </li>
#            <li>
#             <a class="social-5" href="https://www.facebook.com/Central.Intelligence.Agency">
#              CIA Facebook
#             </a>
#            </li>
#            <li>
#             <a href="http://www.youtube.com/user/ciagov">
#              CIA YouTube
#             </a>
#            </li>
#            <li>
#             <a class="social-2" href="http://www.flickr.com/photos/ciagov">
#              CIA Flickr PhotoStream
#             </a>
#            </li>
#            <li>
#             <a class="social-3" href="/news-information/your-news">
#              RSS
#             </a>
#            </li>
#            <li>
#             <a class="social-4 landingTrigger" href="/contact-cia">
#              Contact Us
#             </a>
#            </li>
#           </ul>
#          </div>
#         </nav>
#         <div class="info-panel" id="plugins">
#          <h4>
#           * Required plugins
#          </h4>
#          <ul>
#           <li data-plugin="swf">
#            <a href="http://get.adobe.com/flashplayer/">
#             Adobe® Flash Player
#            </a>
#           </li>
#           <li data-plugin="pdf">
#            <a href="http://get.adobe.com/reader/">
#             Adobe® Reader®
#            </a>
#           </li>
#           <li data-plugin="doc">
#            <a href="http://www.microsoft.com/en-us/download/details.aspx?id=4">
#             MS Word Viewer
#            </a>
#           </li>
#          </ul>
#         </div>
#        </div>
#       </div>
#      </footer>
#     </div>
#     <div class="footer-panel">
#      <nav class="sub-nav">
#       <h3 class="visuallyhidden">
#        Footer Navigation
#       </h3>
#       <ul>
#        <li>
#         <a href="/about-cia/site-policies/#privacy-notice" title="Site Policies">
#          Privacy
#         </a>
#        </li>
#        <li>
#         <a href="/about-cia/site-policies/#copy" title="Site Policies">
#          Copyright
#         </a>
#        </li>
#        <li>
#         <a href="/about-cia/site-policies/" title="Site Policies">
#          Site Policies
#         </a>
#        </li>
#        <li>
#         <a href="http://www.usa.gov/">
#          USA.gov
#         </a>
#        </li>
#        <li>
#         <a href="http://www.foia.cia.gov/">
#          FOIA
#         </a>
#        </li>
#        <li>
#         <a href="http://www.dni.gov/">
#          DNI.gov
#         </a>
#        </li>
#        <li>
#         <a href="/about-cia/no-fear-act/" title="No FEAR Act">
#          NoFEAR Act
#         </a>
#        </li>
#        <li>
#         <a href="/offices-of-cia/inspector-general/">
#          Inspector General
#         </a>
#        </li>
#        <!--<li><a tal:attributes="href string:$portal_url/mobile/" href="#" >Mobile Site</a></li>-->
#        <li>
#         <a class="landingTrigger" href="/contact-cia/">
#          Contact CIA
#         </a>
#        </li>
#        <li>
#         <a href="/sitemap.html">
#          Site Map
#         </a>
#        </li>
#       </ul>
#       <a class="footer-logo" href="/open/">
#        <img alt="open gov" src="/++theme++contextual.agencytheme/images/ico-06.png"/>
#       </a>
#      </nav>
#     </div>
#     <div class="skip">
#      <a href="#wrapper">
#       back to top
#      </a>
#     </div>
#    </div>
#   </div>
#   <script async="" src="/js2/verification.js">
#   </script>
#  </body>
# </html>

# %%
# Collect country names and country codes. Store results in lists.

country_codes=[]
country_names=[]
for tag in soup.find_all('option'):
    country_codes.append(tag.get('value')[5:7])
    country_names.append(tag.text)

temp=country_codes.pop(0) # To remove the first entry 'World'
temp=country_names.pop(0) # To remove the first entry 'World'

# %%
# Checking if we get expected results for country names and codes.

print('COUNTRY NAMES\n'+'-'*30)
for country in country_names[1:]:
    print(country,end=',')
print('\n\nCOUNTRY CODES\n'+'-'*30)
for country in country_codes[1:]:
    print(country,end=',')
# Out:
# COUNTRY NAMES
# ------------------------------
#  Afghanistan , Akrotiri , Albania , Algeria , American Samoa , Andorra , Angola , Anguilla , Antarctica , Antigua and Barbuda , Arctic Ocean , Argentina , Armenia , Aruba , Ashmore and Cartier Islands , Atlantic Ocean , Australia , Austria , Azerbaijan , Bahamas, The , Bahrain , Baker Island , Bangladesh , Barbados , Belarus , Belgium , Belize , Benin , Bermuda , Bhutan , Bolivia , Bosnia and Herzegovina , Botswana , Bouvet Island , Brazil , British Indian Ocean Territory , British Virgin Islands , Brunei , Bulgaria , Burkina Faso , Burma , Burundi , Cabo Verde , Cambodia , Cameroon , Canada , Cayman Islands , Central African Republic , Chad , Chile , China , Christmas Island , Clipperton Island , Cocos (Keeling) Islands , Colombia , Comoros , Congo, Democratic Republic of the , Congo, Republic of the , Cook Islands , Coral Sea Islands , Costa Rica , Cote d'Ivoire , Croatia , Cuba , Curacao , Cyprus , Czechia , Denmark , Dhekelia , Djibouti , Dominica , Dominican Republic , Ecuador , Egypt , El Salvador , Equatorial Guinea , Eritrea , Estonia , Eswatini , Ethiopia , Falkland Islands (Islas Malvinas) , Faroe Islands , Fiji , Finland , France , French Polynesia , French Southern and Antarctic Lands , Gabon , Gambia, The , Gaza Strip , Georgia , Germany , Ghana , Gibraltar , Greece , Greenland , Grenada , Guam , Guatemala , Guernsey , Guinea , Guinea-Bissau , Guyana , Haiti , Heard Island and McDonald Islands , Holy See (Vatican City) , Honduras , Hong Kong , Howland Island , Hungary , Iceland , India , Indian Ocean , Indonesia , Iran , Iraq , Ireland , Isle of Man , Israel , Italy , Jamaica , Jan Mayen , Japan , Jarvis Island , Jersey , Johnston Atoll , Jordan , Kazakhstan , Kenya , Kingman Reef , Kiribati , Korea, North , Korea, South , Kosovo , Kuwait , Kyrgyzstan , Laos , Latvia , Lebanon , Lesotho , Liberia , Libya , Liechtenstein , Lithuania , Luxembourg , Macau , Macedonia , Madagascar , Malawi , Malaysia , Maldives , Mali , Malta , Marshall Islands , Mauritania , Mauritius , Mexico , Micronesia, Federated States of , Midway Islands , Moldova , Monaco , Mongolia , Montenegro , Montserrat , Morocco , Mozambique , Namibia , Nauru , Navassa Island , Nepal , Netherlands , New Caledonia , New Zealand , Nicaragua , Niger , Nigeria , Niue , Norfolk Island , Northern Mariana Islands , Norway , Oman , Pacific Ocean , Pakistan , Palau , Palmyra Atoll , Panama , Papua New Guinea , Paracel Islands , Paraguay , Peru , Philippines , Pitcairn Islands , Poland , Portugal , Puerto Rico , Qatar , Romania , Russia , Rwanda , Saint Barthelemy , Saint Helena, Ascension, and Tristan da Cunha , Saint Kitts and Nevis , Saint Lucia , Saint Martin , Saint Pierre and Miquelon , Saint Vincent and the Grenadines , Samoa , San Marino , Sao Tome and Principe , Saudi Arabia , Senegal , Serbia , Seychelles , Sierra Leone , Singapore , Sint Maarten , Slovakia , Slovenia , Solomon Islands , Somalia , South Africa , Southern Ocean , South Georgia and South Sandwich Islands , South Sudan , Spain , Spratly Islands , Sri Lanka , Sudan , Suriname , Svalbard , Sweden , Switzerland , Syria , Taiwan , Tajikistan , Tanzania , Thailand , Timor-Leste , Togo , Tokelau , Tonga , Trinidad and Tobago , Tunisia , Turkey , Turkmenistan , Turks and Caicos Islands , Tuvalu , Uganda , Ukraine , United Arab Emirates , United Kingdom , United States , United States Pacific Island Wildlife Refuges , Uruguay , Uzbekistan , Vanuatu , Venezuela , Vietnam , Virgin Islands , Wake Island , Wallis and Futuna , West Bank , Western Sahara , Yemen , Zambia , Zimbabwe , European Union ,
#
# COUNTRY CODES
# ------------------------------
# af,ax,al,ag,aq,an,ao,av,ay,ac,xq,ar,am,aa,at,zh,as,au,aj,bf,ba,um,bg,bb,bo,be,bh,bn,bd,bt,bl,bk,bc,bv,br,io,vi,bx,bu,uv,bm,by,cv,cb,cm,ca,cj,ct,cd,ci,ch,kt,ip,ck,co,cn,cg,cf,cw,cr,cs,iv,hr,cu,cc,cy,ez,da,dx,dj,do,dr,ec,eg,es,ek,er,en,wz,et,fk,fo,fj,fi,fr,fp,fs,gb,ga,gz,gg,gm,gh,gi,gr,gl,gj,gq,gt,gk,gv,pu,gy,ha,hm,vt,ho,hk,um,hu,ic,in,xo,id,ir,iz,ei,im,is,it,jm,jn,ja,um,je,um,jo,kz,ke,um,kr,kn,ks,kv,ku,kg,la,lg,le,lt,li,ly,ls,lh,lu,mc,mk,ma,mi,my,mv,ml,mt,rm,mr,mp,mx,fm,um,md,mn,mg,mj,mh,mo,mz,wa,nr,bq,np,nl,nc,nz,nu,ng,ni,ne,nf,cq,no,mu,zn,pk,ps,um,pm,pp,pf,pa,pe,rp,pc,pl,po,rq,qa,ro,rs,rw,tb,sh,sc,st,rn,sb,vc,ws,sm,tp,sa,sg,ri,se,sl,sn,sk,lo,si,bp,so,sf,oo,sx,od,sp,pg,ce,su,ns,sv,sw,sz,sy,tw,ti,tz,th,tt,to,tl,tn,td,ts,tu,tx,tk,tv,ug,up,ae,uk,us,um,uy,uz,nh,ve,vm,vq,wq,wf,we,wi,ym,za,zi,ee,

# %%
# Combine country names and country codes into a dictionary

country_dict = dict(zip(country_names[1:],country_codes[1:]))
country_dict
# Out:
# {' Afghanistan ': 'af',
#  ' Akrotiri ': 'ax',
#  ' Albania ': 'al',
#  ' Algeria ': 'ag',
#  ' American Samoa ': 'aq',
#  ' Andorra ': 'an',
#  ' Angola ': 'ao',
#  ' Anguilla ': 'av',
#  ' Antarctica ': 'ay',
#  ' Antigua and Barbuda ': 'ac',
#  ' Arctic Ocean ': 'xq',
#  ' Argentina ': 'ar',
#  ' Armenia ': 'am',
#  ' Aruba ': 'aa',
#  ' Ashmore and Cartier Islands ': 'at',
#  ' Atlantic Ocean ': 'zh',
#  ' Australia ': 'as',
#  ' Austria ': 'au',
#  ' Azerbaijan ': 'aj',
#  ' Bahamas, The ': 'bf',
#  ' Bahrain ': 'ba',
#  ' Baker Island ': 'um',
#  ' Bangladesh ': 'bg',
#  ' Barbados ': 'bb',
#  ' Belarus ': 'bo',
#  ' Belgium ': 'be',
#  ' Belize ': 'bh',
#  ' Benin ': 'bn',
#  ' Bermuda ': 'bd',
#  ' Bhutan ': 'bt',
#  ' Bolivia ': 'bl',
#  ' Bosnia and Herzegovina ': 'bk',
#  ' Botswana ': 'bc',
#  ' Bouvet Island ': 'bv',
#  ' Brazil ': 'br',
#  ' British Indian Ocean Territory ': 'io',
#  ' British Virgin Islands ': 'vi',
#  ' Brunei ': 'bx',
#  ' Bulgaria ': 'bu',
#  ' Burkina Faso ': 'uv',
#  ' Burma ': 'bm',
#  ' Burundi ': 'by',
#  ' Cabo Verde ': 'cv',
#  ' Cambodia ': 'cb',
#  ' Cameroon ': 'cm',
#  ' Canada ': 'ca',
#  ' Cayman Islands ': 'cj',
#  ' Central African Republic ': 'ct',
#  ' Chad ': 'cd',
#  ' Chile ': 'ci',
#  ' China ': 'ch',
#  ' Christmas Island ': 'kt',
#  ' Clipperton Island ': 'ip',
#  ' Cocos (Keeling) Islands ': 'ck',
#  ' Colombia ': 'co',
#  ' Comoros ': 'cn',
#  ' Congo, Democratic Republic of the ': 'cg',
#  ' Congo, Republic of the ': 'cf',
#  ' Cook Islands ': 'cw',
#  ' Coral Sea Islands ': 'cr',
#  ' Costa Rica ': 'cs',
#  " Cote d'Ivoire ": 'iv',
#  ' Croatia ': 'hr',
#  ' Cuba ': 'cu',
#  ' Curacao ': 'cc',
#  ' Cyprus ': 'cy',
#  ' Czechia ': 'ez',
#  ' Denmark ': 'da',
#  ' Dhekelia ': 'dx',
#  ' Djibouti ': 'dj',
#  ' Dominica ': 'do',
#  ' Dominican Republic ': 'dr',
#  ' Ecuador ': 'ec',
#  ' Egypt ': 'eg',
#  ' El Salvador ': 'es',
#  ' Equatorial Guinea ': 'ek',
#  ' Eritrea ': 'er',
#  ' Estonia ': 'en',
#  ' Eswatini ': 'wz',
#  ' Ethiopia ': 'et',
#  ' Falkland Islands (Islas Malvinas) ': 'fk',
#  ' Faroe Islands ': 'fo',
#  ' Fiji ': 'fj',
#  ' Finland ': 'fi',
#  ' France ': 'fr',
#  ' French Polynesia ': 'fp',
#  ' French Southern and Antarctic Lands ': 'fs',
#  ' Gabon ': 'gb',
#  ' Gambia, The ': 'ga',
#  ' Gaza Strip ': 'gz',
#  ' Georgia ': 'gg',
#  ' Germany ': 'gm',
#  ' Ghana ': 'gh',
#  ' Gibraltar ': 'gi',
#  ' Greece ': 'gr',
#  ' Greenland ': 'gl',
#  ' Grenada ': 'gj',
#  ' Guam ': 'gq',
#  ' Guatemala ': 'gt',
#  ' Guernsey ': 'gk',
#  ' Guinea ': 'gv',
#  ' Guinea-Bissau ': 'pu',
#  ' Guyana ': 'gy',
#  ' Haiti ': 'ha',
#  ' Heard Island and McDonald Islands ': 'hm',
#  ' Holy See (Vatican City) ': 'vt',
#  ' Honduras ': 'ho',
#  ' Hong Kong ': 'hk',
#  ' Howland Island ': 'um',
#  ' Hungary ': 'hu',
#  ' Iceland ': 'ic',
#  ' India ': 'in',
#  ' Indian Ocean ': 'xo',
#  ' Indonesia ': 'id',
#  ' Iran ': 'ir',
#  ' Iraq ': 'iz',
#  ' Ireland ': 'ei',
#  ' Isle of Man ': 'im',
#  ' Israel ': 'is',
#  ' Italy ': 'it',
#  ' Jamaica ': 'jm',
#  ' Jan Mayen ': 'jn',
#  ' Japan ': 'ja',
#  ' Jarvis Island ': 'um',
#  ' Jersey ': 'je',
#  ' Johnston Atoll ': 'um',
#  ' Jordan ': 'jo',
#  ' Kazakhstan ': 'kz',
#  ' Kenya ': 'ke',
#  ' Kingman Reef ': 'um',
#  ' Kiribati ': 'kr',
#  ' Korea, North ': 'kn',
#  ' Korea, South ': 'ks',
#  ' Kosovo ': 'kv',
#  ' Kuwait ': 'ku',
#  ' Kyrgyzstan ': 'kg',
#  ' Laos ': 'la',
#  ' Latvia ': 'lg',
#  ' Lebanon ': 'le',
#  ' Lesotho ': 'lt',
#  ' Liberia ': 'li',
#  ' Libya ': 'ly',
#  ' Liechtenstein ': 'ls',
#  ' Lithuania ': 'lh',
#  ' Luxembourg ': 'lu',
#  ' Macau ': 'mc',
#  ' Macedonia ': 'mk',
#  ' Madagascar ': 'ma',
#  ' Malawi ': 'mi',
#  ' Malaysia ': 'my',
#  ' Maldives ': 'mv',
#  ' Mali ': 'ml',
#  ' Malta ': 'mt',
#  ' Marshall Islands ': 'rm',
#  ' Mauritania ': 'mr',
#  ' Mauritius ': 'mp',
#  ' Mexico ': 'mx',
#  ' Micronesia, Federated States of ': 'fm',
#  ' Midway Islands ': 'um',
#  ' Moldova ': 'md',
#  ' Monaco ': 'mn',
#  ' Mongolia ': 'mg',
#  ' Montenegro ': 'mj',
#  ' Montserrat ': 'mh',
#  ' Morocco ': 'mo',
#  ' Mozambique ': 'mz',
#  ' Namibia ': 'wa',
#  ' Nauru ': 'nr',
#  ' Navassa Island ': 'bq',
#  ' Nepal ': 'np',
#  ' Netherlands ': 'nl',
#  ' New Caledonia ': 'nc',
#  ' New Zealand ': 'nz',
#  ' Nicaragua ': 'nu',
#  ' Niger ': 'ng',
#  ' Nigeria ': 'ni',
#  ' Niue ': 'ne',
#  ' Norfolk Island ': 'nf',
#  ' Northern Mariana Islands ': 'cq',
#  ' Norway ': 'no',
#  ' Oman ': 'mu',
#  ' Pacific Ocean ': 'zn',
#  ' Pakistan ': 'pk',
#  ' Palau ': 'ps',
#  ' Palmyra Atoll ': 'um',
#  ' Panama ': 'pm',
#  ' Papua New Guinea ': 'pp',
#  ' Paracel Islands ': 'pf',
#  ' Paraguay ': 'pa',
#  ' Peru ': 'pe',
#  ' Philippines ': 'rp',
#  ' Pitcairn Islands ': 'pc',
#  ' Poland ': 'pl',
#  ' Portugal ': 'po',
#  ' Puerto Rico ': 'rq',
#  ' Qatar ': 'qa',
#  ' Romania ': 'ro',
#  ' Russia ': 'rs',
#  ' Rwanda ': 'rw',
#  ' Saint Barthelemy ': 'tb',
#  ' Saint Helena, Ascension, and Tristan da Cunha ': 'sh',
#  ' Saint Kitts and Nevis ': 'sc',
#  ' Saint Lucia ': 'st',
#  ' Saint Martin ': 'rn',
#  ' Saint Pierre and Miquelon ': 'sb',
#  ' Saint Vincent and the Grenadines ': 'vc',
#  ' Samoa ': 'ws',
#  ' San Marino ': 'sm',
#  ' Sao Tome and Principe ': 'tp',
#  ' Saudi Arabia ': 'sa',
#  ' Senegal ': 'sg',
#  ' Serbia ': 'ri',
#  ' Seychelles ': 'se',
#  ' Sierra Leone ': 'sl',
#  ' Singapore ': 'sn',
#  ' Sint Maarten ': 'sk',
#  ' Slovakia ': 'lo',
#  ' Slovenia ': 'si',
#  ' Solomon Islands ': 'bp',
#  ' Somalia ': 'so',
#  ' South Africa ': 'sf',
#  ' Southern Ocean ': 'oo',
#  ' South Georgia and South Sandwich Islands ': 'sx',
#  ' South Sudan ': 'od',
#  ' Spain ': 'sp',
#  ' Spratly Islands ': 'pg',
#  ' Sri Lanka ': 'ce',
#  ' Sudan ': 'su',
#  ' Suriname ': 'ns',
#  ' Svalbard ': 'sv',
#  ' Sweden ': 'sw',
#  ' Switzerland ': 'sz',
#  ' Syria ': 'sy',
#  ' Taiwan ': 'tw',
#  ' Tajikistan ': 'ti',
#  ' Tanzania ': 'tz',
#  ' Thailand ': 'th',
#  ' Timor-Leste ': 'tt',
#  ' Togo ': 'to',
#  ' Tokelau ': 'tl',
#  ' Tonga ': 'tn',
#  ' Trinidad and Tobago ': 'td',
#  ' Tunisia ': 'ts',
#  ' Turkey ': 'tu',
#  ' Turkmenistan ': 'tx',
#  ' Turks and Caicos Islands ': 'tk',
#  ' Tuvalu ': 'tv',
#  ' Uganda ': 'ug',
#  ' Ukraine ': 'up',
#  ' United Arab Emirates ': 'ae',
#  ' United Kingdom ': 'uk',
#  ' United States ': 'us',
#  ' United States Pacific Island Wildlife Refuges ': 'um',
#  ' Uruguay ': 'uy',
#  ' Uzbekistan ': 'uz',
#  ' Vanuatu ': 'nh',
#  ' Venezuela ': 've',
#  ' Vietnam ': 'vm',
#  ' Virgin Islands ': 'vq',
#  ' Wake Island ': 'wq',
#  ' Wallis and Futuna ': 'wf',
#  ' West Bank ': 'we',
#  ' Western Sahara ': 'wi',
#  ' Yemen ': 'ym',
#  ' Zambia ': 'za',
#  ' Zimbabwe ': 'zi',
#  ' European Union ': 'ee'}

# %%
# The function takes in page_data (the country page) and metrics (a list of metrics or features that we want to scrape)
# This function then creates a dictionary for the feature names and corresponding value for a given country.
# If statements are used to 5 of the metrics, because scraping these values have their own nuances.

def create_metric_dict(page_data, metrics):

    metric_list = []

    for metric in metrics:
        s = page_data.find(text=re.compile(metric))
        value = np.nan
        if s != None:
            link_container = s.parent
            div_container = link_container.parent
            # For exchange rate, we need to look two siblings ahead since one row is dedicated to explaining the type of currency
            if s == "Exchange rates:" or s == "Land boundaries:":
                value = div_container.findNextSibling().findNextSibling()
                if value != None:
                    value=value.text
                else:
                    value = np.nan
                    
            elif s == "GDP - composition, by sector of origin:":
                value = []
                for i in range (0,3):
                    div_container = div_container.findNextSibling()
                    value.append(div_container.text)
                
                if not value:
                    value = np.nan
                    
            elif s == "GDP - composition, by end use:":
                value = []
                for i in range (0,6):
                    div_container = div_container.findNextSibling()
                    value.append(div_container.text)
                    
                if not value:
                    value = np.nan
                
            else:
                value = div_container.findNextSibling().text


        metric_list.append(value)
            
    metric_dict = dict(zip(metrics,metric_list))
    
    return metric_dict

# %%
# country_metrics is a list of dictionaries to store the economic and societal metrics for each country.
country_metrics = []

# economic_metrics and society metrics are the metrics/features that we are interested in scraping.

economic_metrics = ["GDP - per capita \(PPP\):", \
                    "Industrial production growth rate:",\
                    "Labor force:","Unemployment rate:",\
                    "Population below poverty line:", \
                    "Distribution of family income - Gini index:", \
                    "Public debt:", "Inflation", \
                    "Current account balance:", \
                    "Exports:", "Imports:", \
                    "Reserves of foreign exchange and gold:", \
                    "Exchange rates:", \
                   "GDP - composition, by sector of origin:", \
                   "GDP - composition, by end use:"]

society_metrics = ["Population:", \
                    "Population growth rate:", \
                    "Urbanization:", \
                    "Infant mortality rate:", \
                    "Education expenditures:", \
                    "Literacy:", \
                   "Telephones - fixed lines:", \
                   "Telephones - mobile cellular:", \
                   "Internet users:", \
                    "Land boundaries:", \
                  "Geographic coordinates:"]


metric_list = economic_metrics + society_metrics

# This for loop runs through all the countries and runs the create_metric_dict function to fill out country_metrics.

for key,value in country_dict.items():
    print(key)
    url = "https://www.cia.gov/library/publications/the-world-factbook/geos/" + str(value) + ".html"
    response = requests.get(url)
    if response.status_code == 404:
        print("Unable to reach website")
    page = response.text
    soup = BeautifulSoup(page,"lxml")
    
    metric_dict = create_metric_dict(soup,metric_list)
    metric_dict['Country'] = key
    country_metrics.append(metric_dict)
# Out:
#  Afghanistan
#  Akrotiri
#  Albania
#  Algeria
#  American Samoa
#  Andorra
#  Angola
#  Anguilla
#  Antarctica
#  Antigua and Barbuda
#  Arctic Ocean
#  Argentina
#  Armenia
#  Aruba
#  Ashmore and Cartier Islands
#  Atlantic Ocean
#  Australia
#  Austria
#  Azerbaijan
#  Bahamas, The
#  Bahrain
#  Baker Island
#  Bangladesh
#  Barbados
#  Belarus
#  Belgium
#  Belize
#  Benin
#  Bermuda
#  Bhutan
#  Bolivia
#  Bosnia and Herzegovina
#  Botswana
#  Bouvet Island
#  Brazil
#  British Indian Ocean Territory
#  British Virgin Islands
#  Brunei
#  Bulgaria
#  Burkina Faso
#  Burma
#  Burundi
#  Cabo Verde
#  Cambodia
#  Cameroon
#  Canada
#  Cayman Islands
#  Central African Republic
#  Chad
#  Chile
#  China
#  Christmas Island
#  Clipperton Island
#  Cocos (Keeling) Islands
#  Colombia
#  Comoros
#  Congo, Democratic Republic of the
#  Congo, Republic of the
#  Cook Islands
#  Coral Sea Islands
#  Costa Rica
#  Cote d'Ivoire
#  Croatia
#  Cuba
#  Curacao
#  Cyprus
#  Czechia
#  Denmark
#  Dhekelia
#  Djibouti
#  Dominica
#  Dominican Republic
#  Ecuador
#  Egypt
#  El Salvador
#  Equatorial Guinea
#  Eritrea
#  Estonia
#  Eswatini
#  Ethiopia
#  Falkland Islands (Islas Malvinas)
#  Faroe Islands
#  Fiji
#  Finland
#  France
#  French Polynesia
#  French Southern and Antarctic Lands
#  Gabon
#  Gambia, The
#  Gaza Strip
#  Georgia
#  Germany
#  Ghana
#  Gibraltar
#  Greece
#  Greenland
#  Grenada
#  Guam
#  Guatemala
#  Guernsey
#  Guinea
#  Guinea-Bissau
#  Guyana
#  Haiti
#  Heard Island and McDonald Islands
#  Holy See (Vatican City)
#  Honduras
#  Hong Kong
#  Howland Island
#  Hungary
#  Iceland
#  India
#  Indian Ocean
#  Indonesia
#  Iran
#  Iraq
#  Ireland
#  Isle of Man
#  Israel
#  Italy
#  Jamaica
#  Jan Mayen
#  Japan
#  Jarvis Island
#  Jersey
#  Johnston Atoll
#  Jordan
#  Kazakhstan
#  Kenya
#  Kingman Reef
#  Kiribati
#  Korea, North
#  Korea, South
#  Kosovo
#  Kuwait
#  Kyrgyzstan
#  Laos
#  Latvia
#  Lebanon
#  Lesotho
#  Liberia
#  Libya
#  Liechtenstein
#  Lithuania
#  Luxembourg
#  Macau
#  Macedonia
#  Madagascar
#  Malawi
#  Malaysia
#  Maldives
#  Mali
#  Malta
#  Marshall Islands
#  Mauritania
#  Mauritius
#  Mexico
#  Micronesia, Federated States of
#  Midway Islands
#  Moldova
#  Monaco
#  Mongolia
#  Montenegro
#  Montserrat
#  Morocco
#  Mozambique
#  Namibia
#  Nauru
#  Navassa Island
#  Nepal
#  Netherlands
#  New Caledonia
#  New Zealand
#  Nicaragua
#  Niger
#  Nigeria
#  Niue
#  Norfolk Island
#  Northern Mariana Islands
#  Norway
#  Oman
#  Pacific Ocean
#  Pakistan
#  Palau
#  Palmyra Atoll
#  Panama
#  Papua New Guinea
#  Paracel Islands
#  Paraguay
#  Peru
#  Philippines
#  Pitcairn Islands
#  Poland
#  Portugal
#  Puerto Rico
#  Qatar
#  Romania
#  Russia
#  Rwanda
#  Saint Barthelemy
#  Saint Helena, Ascension, and Tristan da Cunha
#  Saint Kitts and Nevis
#  Saint Lucia
#  Saint Martin
#  Saint Pierre and Miquelon
#  Saint Vincent and the Grenadines
#  Samoa
#  San Marino
#  Sao Tome and Principe
#  Saudi Arabia
#  Senegal
#  Serbia
#  Seychelles
#  Sierra Leone
#  Singapore
#  Sint Maarten
#  Slovakia
#  Slovenia
#  Solomon Islands
#  Somalia
#  South Africa
#  Southern Ocean
#  South Georgia and South Sandwich Islands
#  South Sudan
#  Spain
#  Spratly Islands
#  Sri Lanka
#  Sudan
#  Suriname
#  Svalbard
#  Sweden
#  Switzerland
#  Syria
#  Taiwan
#  Tajikistan
#  Tanzania
#  Thailand
#  Timor-Leste
#  Togo
#  Tokelau
#  Tonga
#  Trinidad and Tobago
#  Tunisia
#  Turkey
#  Turkmenistan
#  Turks and Caicos Islands
#  Tuvalu
#  Uganda
#  Ukraine
#  United Arab Emirates
#  United Kingdom
#  United States
#  United States Pacific Island Wildlife Refuges
#  Uruguay
#  Uzbekistan
#  Vanuatu
#  Venezuela
#  Vietnam
#  Virgin Islands
#  Wake Island
#  Wallis and Futuna
#  West Bank
#  Western Sahara
#  Yemen
#  Zambia
#  Zimbabwe
#  European Union

# %%
# Test to see if copmany metrics is a list of dictionaries.

country_metrics
# Out:
# [{'GDP - per capita \\(PPP\\):': '$2,000 (2017 est.)',
#   'Industrial production growth rate:': '-1.9% (2016 est.)',
#   'Labor force:': '8.478 million (2017 est.)',
#   'Unemployment rate:': '23.9% (2017 est.)',
#   'Population below poverty line:': '54.5% (2017 est.)',
#   'Distribution of family income - Gini index:': nan,
#   'Public debt:': '7.3% of GDP (2017 est.)',
#   'Inflation': '5% (2017 est.)',
#   'Current account balance:': '$328 million (2017 est.)',
#   'Exports:': '$784 million (2017 est.)',
#   'Imports:': '$7.616 billion (2017 est.)',
#   'Reserves of foreign exchange and gold:': '$7.405 billion (31 December 2016 est.)',
#   'Exchange rates:': '7.87 2017 est.)',
#   'GDP - composition, by sector of origin:': ['agriculture: 23%',
#    'industry: 21.1%',
#    'services: 55.9%'],
#   'GDP - composition, by end use:': ['household consumption: 81.6%',
#    'government consumption: 12%',
#    'investment in fixed capital: 17.2%',
#    'investment in inventories: 30%',
#    'exports of goods and services: 6.7%',
#    'imports of goods and services: -47.6% (2016 est.)'],
#   'Population:': '34,124,811 (July 2017 est.)',
#   'Population growth rate:': '2.36% (2017 est.)',
#   'Urbanization:': 'urban population: 25.5% of total population (2018)',
#   'Infant mortality rate:': 'total: 110.6 deaths/1,000 live births',
#   'Education expenditures:': '3.2% of GDP (2015)',
#   'Literacy:': 'definition: age 15 and over can read and write',
#   'Telephones - fixed lines:': 'total subscriptions: 118,769',
#   'Telephones - mobile cellular:': 'total subscriptions: 23,929,713',
#   'Internet users:': 'total: 3,531,770',
#   'Land boundaries:': 'border countries (6): China 91 km, Iran 921 km, Pakistan 2,670 km, Tajikistan 1,357 km, Turkmenistan 804 km, Uzbekistan 144 km',
#   'Geographic coordinates:': '33 00 N, 65 00 E',
#   'Country': ' Afghanistan '},
#  {'GDP - per capita \\(PPP\\):': nan,
#   'Industrial production growth rate:': nan,
#   'Labor force:': nan,
#   'Unemployment rate:': nan,
#   'Population below poverty line:': nan,
#   'Distribution of family income - Gini index:': nan,
#   'Public debt:': nan,
#   'Inflation': nan,
#   'Current account balance:': nan,
#   'Exports:': nan,
#   'Imports:': nan,
#   'Reserves of foreign exchange and gold:': nan,
#   'Exchange rates:': nan,
#   'GDP - composition, by sector of origin:': nan,
#   'GDP - composition, by end use:': nan,
#   'Population:': 'approximately 15,500 on the Sovereign Base Areas of Akrotiri and Dhekelia including 9,700 Cypriots and 5,800 Service and UK-based contract personnel and dependents (2011)',
#   'Population growth rate:': nan,
#   'Urbanization:': nan,
#   'Infant mortality rate:': nan,
#   'Education expenditures:': nan,
#   'Literacy:': nan,
#   'Telephones - fixed lines:': nan,
#   'Telephones - mobile cellular:': nan,
#   'Internet users:': nan,
#   'Land boundaries:': 'border countries (1): Cyprus 48 km',
#   'Geographic coordinates:': '34 37 N, 32 58 E',
#   'Country': ' Akrotiri '},
#  {'GDP - per capita \\(PPP\\):': '$12,500 (2017 est.)',
#   'Industrial production growth rate:': '3.5% (2017 est.)',
#   'Labor force:': '1.198 million (2017 est.)',
#   'Unemployment rate:': '14% (2017 est.)',
#   'Population below poverty line:': '14.3% (2012 est.)',
#   'Distribution of family income - Gini index:': '29 (2012 est.)',
#   'Public debt:': '71.2% of GDP (2017 est.)',
#   'Inflation': '2% (2017 est.)',
#   'Current account balance:': '-$945 million (2017 est.)',
#   'Exports:': '$960.9 million (2017 est.)',
#   'Imports:': '$4.084 billion (2017 est.)',
#   'Reserves of foreign exchange and gold:': '$3.274 billion (31 December 2017 est.)',
#   'Exchange rates:': '121.9 (2017 est.)',
#   'GDP - composition, by sector of origin:': ['agriculture: 22.6%',
#    'industry: 23.8%',
#    'services: 53.7%'],
#   'GDP - composition, by end use:': ['household consumption: 77.6%',
#    'government consumption: 10.9%',
#    'investment in fixed capital: 27%',
#    'investment in inventories: 0%',
#    'exports of goods and services: 29.7%',
#    'imports of goods and services: -45.2% (2017 est.)'],
#   'Population:': '3,047,987 (July 2017 est.)',
#   'Population growth rate:': '0.31% (2017 est.)',
#   'Urbanization:': 'urban population: 60.3% of total population (2018)',
#   'Infant mortality rate:': 'total: 11.9 deaths/1,000 live births',
#   'Education expenditures:': '3.5% of GDP (2015)',
#   'Literacy:': 'definition: age 15 and over can read and write',
#   'Telephones - fixed lines:': 'total subscriptions: 247,010',
#   'Telephones - mobile cellular:': 'total subscriptions: 3,497,950',
#   'Internet users:': 'total: 2,016,516',
#   'Land boundaries:': 'border countries (4): Greece 212 km, Kosovo 112 km, Macedonia 181 km, Montenegro 186 km',
#   'Geographic coordinates:': '41 00 N, 20 00 E',
#   'Country': ' Albania '},
#  {'GDP - per capita \\(PPP\\):': '$15,200 (2017 est.)',
#   'Industrial production growth rate:': '0.9% (2017 est.)',
#   'Labor force:': '11.82 million (2017 est.)',
#   'Unemployment rate:': '11.7% (2017 est.)',
#   'Population below poverty line:': '23% (2006 est.)',
#   'Distribution of family income - Gini index:': '35.3 (1995)',
#   'Public debt:': '25.8% of GDP (2017 est.)',
#   'Inflation': '5.6% (2017 est.)',
#   'Current account balance:': '-$21.94 billion (2017 est.)',
#   'Exports:': '$33.15 billion (2017 est.)',
#   'Imports:': '$49.99 billion (2017 est.)',
#   'Reserves of foreign exchange and gold:': '$97.67 billion (31 December 2017 est.)',
#   'Exchange rates:': '108.9 (2017 est.)',
#   'GDP - composition, by sector of origin:': ['agriculture: 13.2%',
#    'industry: 36.1%',
#    'services: 50.7% (2017 est.)'],
#   'GDP - composition, by end use:': ['household consumption: 42.7%',
#    'government consumption: 21.4%',
#    'investment in fixed capital: 42.7%',
#    'investment in inventories: 7.6%',
#    'exports of goods and services: 21%',
#    'imports of goods and services: -35.5% (2017 est.)'],
#   'Population:': '40,969,443 (July 2017 est.)',
#   'Population growth rate:': '1.7% (2017 est.)',
#   'Urbanization:': 'urban population: 72.6% of total population (2018)',
#   'Infant mortality rate:': 'total: 19.6 deaths/1,000 live births',
#   'Education expenditures:': '4.3% of GDP (2008)',
#   'Literacy:': 'definition: age 15 and over can read and write',
#   'Telephones - fixed lines:': 'total subscriptions: 3,130,090',
#   'Telephones - mobile cellular:': 'total subscriptions: 49,873,389',
#   'Internet users:': 'total: 17,291,463',
#   'Land boundaries:': 'border countries (7): Libya 989 km, Mali 1,359 km, Mauritania 460 km, Morocco 1,900 km, Niger 951 km, Tunisia 1,034 km, Western Sahara 41 km',
#   'Geographic coordinates:': '28 00 N, 3 00 E',
#   'Country': ' Algeria '},
#  {'GDP - per capita \\(PPP\\):': '$11,200 (2016 est.)',
#   'Industrial production growth rate:': 'NA%',
#   'Labor force:': '17,850 (2015 est.)',
#   'Unemployment rate:': '29.8% (2005)',
#   'Population below poverty line:': 'NA%',
#   'Distribution of family income - Gini index:': nan,
#   'Public debt:': '12.2% of GDP (2016 est.)',
#   'Inflation': '-0.5% (2015 est.)',
#   'Current account balance:': nan,
#   'Exports:': '$428 million (2016 est.)',
#   'Imports:': '$615 million (2016 est.)',
#   'Reserves of foreign exchange and gold:': nan,
#   'Exchange rates:': nan,
#   'GDP - composition, by sector of origin:': ['agriculture: 27.4%',
#    'industry: 12.4%',
#    'services: 60.2% (2012)'],
#   'GDP - composition, by end use:': ['household consumption: 66.4%',
#    'government consumption: 49.7%',
#    'investment if fixed capital: 7.3%',
#    'investment in inventories: 5.1%',
#    'exports of goods and services: 65%',
#    'imports of goods and services: -93.5% (2016 est.)'],
#   'Population:': '51,504 (July 2017 est.)',
#   'Population growth rate:': '-1.3% (2017 est.)',
#   'Urbanization:': 'urban population: 87.2% of total population (2018)',
#   'Infant mortality rate:': 'total: 11.3 deaths/1,000 live births',
#   'Education expenditures:': 'NA',
#   'Literacy:': nan,
#   'Telephones - fixed lines:': 'total subscriptions: 10,000',
#   'Telephones - mobile cellular:': nan,
#   'Internet users:': 'total: 17,000',
#   'Land boundaries:': 'Coastline:',
#   'Geographic coordinates:': '14 20 S, 170 00 W',
#   'Country': ' American Samoa '},
#  {'GDP - per capita \\(PPP\\):': '$49,900 (2015 est.)',
#   'Industrial production growth rate:': 'NA%',
#   'Labor force:': '39,750 (2016)',
#   'Unemployment rate:': '3.7% (2016 est.)',
#   'Population below poverty line:': 'NA%',
#   'Distribution of family income - Gini index:': nan,
#   'Public debt:': '41% of GDP (2014 est.)',
#   'Inflation': '-0.9% (2015 est.)',
#   'Current account balance:': nan,
#   'Exports:': '$78.71 million (2015 est.)',
#   'Imports:': '$1.257 billion (2015 est.)',
#   'Reserves of foreign exchange and gold:': nan,
#   'Exchange rates:': '0.89 (2017 est.)',
#   'GDP - composition, by sector of origin:': ['agriculture: 11.9%',
#    'industry: 33.6%',
#    'services: 54.5% (2015 est.)'],
#   'GDP - composition, by end use:': nan,
#   'Population:': '76,965 (July 2017 est.)',
#   'Population growth rate:': '0.03% (2017 est.)',
#   'Urbanization:': 'urban population: 88.1% of total population (2018)',
#   'Infant mortality rate:': 'total: 3.6 deaths/1,000 live births',
#   'Education expenditures:': '3.3% of GDP (2016)',
#   'Literacy:': 'definition: age 15 and over can read and write',
#   'Telephones - fixed lines:': 'total subscriptions: 38,411',
#   'Telephones - mobile cellular:': 'total subscriptions: 80,337',
#   'Internet users:': 'total: 83,887',
#   'Land boundaries:': 'border countries (2): France 55 km, Spain 63 km',
#   'Geographic coordinates:': '42 30 N, 1 30 E',
#   'Country': ' Andorra '},
#  {'GDP - per capita \\(PPP\\):': '$6,800 (2017 est.)',
#   'Industrial production growth rate:': '1.9% (2017 est.)',
#   'Labor force:': '12.51 million (2017 est.)',
#   'Unemployment rate:': '6.6% (2016 est.)',
#   'Population below poverty line:': '36.6% (2008 est.)',
#   'Distribution of family income - Gini index:': '42.7 (2008 est.)',
#   'Public debt:': '65.3% of GDP (2017 est.)',
#   'Inflation': '31.7% (2017 est.)',
#   'Current account balance:': '-$5.541 billion (2017 est.)',
#   'Exports:': '$33.82 billion (2017 est.)',
#   'Imports:': '$23 billion (2017 est.)',
#   'Reserves of foreign exchange and gold:': '$18.1 billion (31 December 2017 est.)',
#   'Exchange rates:': '172.6 (2017 est.)',
#   'GDP - composition, by sector of origin:': ['agriculture: 10.2%',
#    'industry: 61.4%',
#    'services: 28.4% (2011 est.)'],
#   'GDP - composition, by end use:': ['household consumption: 75.6%',
#    'government consumption: 15.4%',
#    'investment in fixed capital: 9.8%',
#    'investment in inventories: 0.1%',
#    'exports of goods and services: 28.4%',
#    'imports of goods and services: -29.3% (2017 est.)'],
#   'Population:': '29,310,273 (July 2017 est.)',
#   'Population growth rate:': '3.52% (2017 est.)',
#   'Urbanization:': 'urban population: 65.5% of total population (2018)',
#   'Infant mortality rate:': 'total: 67.6 deaths/1,000 live births',
#   'Education expenditures:': '3.5% of GDP (2010)',
#   'Literacy:': 'definition: age 15 and over can read and write',
#   'Telephones - fixed lines:': 'total subscriptions: 161,070',
#   'Telephones - mobile cellular:': 'total subscriptions: 13,323,952',
#   'Internet users:': 'total: 2,622,403',
#   'Land boundaries:': 'border countries (4): Democratic Republic of the Congo 2,646 km (of which 225 km is the boundary of discontiguous Cabinda Province), Republic of the Congo 231 km, Namibia 1,427 km, Zambia 1,065 km',
#   'Geographic coordinates:': '12 30 S, 18 30 E',
#   'Country': ' Angola '},
#  {'GDP - per capita \\(PPP\\):': '$12,200 (2008 est.)',
#   'Industrial production growth rate:': '2% (2017 est.)',
#   'Labor force:': '6,049 (2001)',
#   'Unemployment rate:': '8% (2002)',
#   'Population below poverty line:': '23% (2002 est.)',
#   'Distribution of family income - Gini index:': nan,
#   'Public debt:': '20.1% of GDP (2015 est.)',
#   'Inflation': '2.1% (2017 est.)',
#   'Current account balance:': '-$23.2 million (2017 est.)',
#   'Exports:': '$4.2 million (2017 est.)',
#   'Imports:': '$111.1 million (2017 est.)',
#   'Reserves of foreign exchange and gold:': nan,
#   'Exchange rates:': '2.7 (2017 est.)',
#   'GDP - composition, by sector of origin:': ['agriculture: 2.4%',
#    'industry: 21.3%',
#    'services: 76.3% (2017 est.)'],
#   'GDP - composition, by end use:': ['household consumption: 71.3%',
#    'government consumption: 14.5%',
#    'investment in fixed capital: 19.5%',
#    'investment in inventories: 0%',
#    'exports of goods and services: 42.5%',
#    'imports of goods and services: -47.9% (2017 est.)'],
#   'Population:': '17,087 (July 2017 est.)',
#   'Population growth rate:': '1.97% (2017 est.)',
#   'Urbanization:': 'urban population: 100% of total population (2018)',
#   'Infant mortality rate:': 'total: 3.3 deaths/1,000 live births',
#   'Education expenditures:': '2.8% of GDP (2008)',
#   'Literacy:': nan,
#   'Telephones - fixed lines:': 'total subscriptions: 6,000',
#   'Telephones - mobile cellular:': 'total subscriptions: 26,000',
#   'Internet users:': 'total: 13,665',
#   'Land boundaries:': 'Coastline:',
#   'Geographic coordinates:': '18 15 N, 63 10 W',
#   'Country': ' Anguilla '},
#  {'GDP - per capita \\(PPP\\):': nan,
#   'Industrial production growth rate:': nan,
#   'Labor force:': nan,
#   'Unemployment rate:': nan,
#   'Population below poverty line:': nan,
#   'Distribution of family income - Gini index:': nan,
#   'Public debt:': nan,
#   'Inflation': nan,
#   'Current account balance:': nan,
#   'Exports:': nan,
#   'Imports:': nan,
#   'Reserves of foreign exchange and gold:': nan,
#   'Exchange rates:': nan,
#   'GDP - composition, by sector of origin:': nan,
#   'GDP - composition, by end use:': nan,
#   'Population:': 'no indigenous inhabitants, but there are both permanent and summer-only staffed research stations',
#   'Population growth rate:': nan,
#   'Urbanization:': nan,
#   'Infant mortality rate:': nan,
#   'Education expenditures:': nan,
#   'Literacy:': nan,
#   'Telephones - fixed lines:': nan,
#   'Telephones - mobile cellular:': nan,
#   'Internet users:': 'total: 4,400',
#   'Land boundaries:': 'note: see entry on Disputes - international',
#   'Geographic coordinates:': '90 00 S, 0 00 E',
#   'Country': ' Antarctica '},
#  {'GDP - per capita \\(PPP\\):': '$26,300 (2017 est.)',
#   'Industrial production growth rate:': '3% (2017 est.)',
#   'Labor force:': '30,000 (1991)',
#   'Unemployment rate:': '11% (2014 est.)',
#   'Population below poverty line:': 'NA%',
#   'Distribution of family income - Gini index:': nan,
#   'Public debt:': '86.8% of GDP (2017 est.)',
#   'Inflation': '2.5% (2017 est.)',
#   'Current account balance:': '-$106 million (2017 est.)',
#   'Exports:': '$61.3 million (2017 est.)',
#   'Imports:': '$420.7 million (2017 est.)',
#   'Reserves of foreign exchange and gold:': nan,
#   'Exchange rates:': '2.7 (2017 est.)',
#   'GDP - composition, by sector of origin:': ['agriculture: 2.3%',
#    'industry: 20.2%',
#    'services: 77.5% (2017 est.)'],
#   'GDP - composition, by end use:': ['household consumption: 68%',
#    'government consumption: 16%',
#    'investment in fixed capital: 21.7%',
#    'investment in inventories: 0.1%',
#    'exports of goods and services: 34%',
#    'imports of goods and services: -39.7% (2017 est.)'],
#   'Population:': '94,731 (July 2017 est.)',
#   'Population growth rate:': '1.21% (2017 est.)',
#   'Urbanization:': 'urban population: 24.6% of total population (2018)',
#   'Infant mortality rate:': 'total: 12.1 deaths/1,000 live births',
#   'Education expenditures:': '2.5% of GDP (2009)',
#   'Literacy:': 'definition: age 15 and over has completed five or more years of schooling',
#   'Telephones - fixed lines:': 'total subscriptions: 22,504',
#   'Telephones - mobile cellular:': 'total subscriptions: 180,000',
#   'Internet users:': 'total: 60,000',
#   'Land boundaries:': 'Coastline:',
#   'Geographic coordinates:': '17 03 N, 61 48 W',
#   'Country': ' Antigua and Barbuda '},
#  {'GDP - per capita \\(PPP\\):': nan,
#   'Industrial production growth rate:': nan,
#   'Labor force:': nan,
#   'Unemployment rate:': nan,
#   'Population below poverty line:': nan,
#   'Distribution of family income - Gini index:': nan,
#   'Public debt:': nan,
#   'Inflation': nan,
#   'Current account balance:': nan,
#   'Exports:': nan,
#   'Imports:': nan,
#   'Reserves of foreign exchange and gold:': nan,
#   'Exchange rates:': nan,
#   'GDP - composition, by sector of origin:': nan,
#   'GDP - composition, by end use:': nan,
#   'Population:': nan,
#   'Population growth rate:': nan,
#   'Urbanization:': nan,
#   'Infant mortality rate:': nan,
#   'Education expenditures:': nan,
#   'Literacy:': nan,
#   'Telephones - fixed lines:': nan,
#   'Telephones - mobile cellular:': nan,
#   'Internet users:': nan,
#   'Land boundaries:': nan,
#   'Geographic coordinates:': '90 00 N, 0 00 E',
#   'Country': ' Arctic Ocean '},
#  {'GDP - per capita \\(PPP\\):': '$20,900 (2017 est.)',
#   'Industrial production growth rate:': '2.4%',
#   'Labor force:': '18 million',
#   'Unemployment rate:': '8.1% (2017 est.)',
#   'Population below poverty line:': '25.7%',
#   'Distribution of family income - Gini index:': '41.7 (2017 est.)',
#   'Public debt:': '52.6% of GDP (2017 est.)',
#   'Inflation': '25.7% (2017 est.)',
#   'Current account balance:': '-$30.79 billion (2017 est.)',
#   'Exports:': '$59.69 billion (2017 est.)',
#   'Imports:': '$60.78 billion (2017 est.)',
#   'Reserves of foreign exchange and gold:': '$52.97 billion (31 December 2017 est.)',
#   'Exchange rates:': '16.92 (2017 est.)',
#   'GDP - composition, by sector of origin:': ['agriculture: 10.9%',
#    'industry: 28.2%',
#    'services: 60.9% (2017 est.)'],
#   'GDP - composition, by end use:': ['household consumption: 66.5%',
#    'government consumption: 18%',
#    'investment in fixed capital: 15.3%',
#    'investment in inventories: 1.5%',
#    'exports of goods and services: 12%',
#    'imports of goods and services: -13.4% (2017 est.)'],
#   'Population:': '44,293,293 (July 2017 est.)',
#   'Population growth rate:': '0.91% (2017 est.)',
#   'Urbanization:': 'urban population: 91.9% of total population (2018)',
#   'Infant mortality rate:': 'total: 9.8 deaths/1,000 live births',
#   'Education expenditures:': '5.9% of GDP (2015)',
#   'Literacy:': 'definition: age 15 and over can read and write',
#   'Telephones - fixed lines:': 'total subscriptions: 9,530,349',
#   'Telephones - mobile cellular:': 'total subscriptions: 61,897,379',
#   'Internet users:': 'total: 30,786,889',
#   'Land boundaries:': 'border countries (5): Bolivia 942 km, Brazil 1,263 km, Chile 6,691 km, Paraguay 2,531 km, Uruguay 541 km',
#   'Geographic coordinates:': '34 00 S, 64 00 W',
#   'Country': ' Argentina '},
#  {'GDP - per capita \\(PPP\\):': '$9,500 (2017 est.)',
#   'Industrial production growth rate:': '5% (2017 est.)',
#   'Labor force:': '1.507 million (2017 est.)',
#   'Unemployment rate:': '18.9% (2017 est.)',
#   'Population below poverty line:': '32% (2013 est.)',
#   'Distribution of family income - Gini index:': '31.5 (2014)',
#   'Public debt:': '53.5% of GDP (2017 est.)',
#   'Inflation': '0.9% (2017 est.)',
#   'Current account balance:': '-$295 million (2017 est.)',
#   'Exports:': '$2.233 billion (2017 est.)',
#   'Imports:': '$3.361 billion (2017 est.)',
#   'Reserves of foreign exchange and gold:': '$2.242 billion (31 December 2017 est.)',
#   'Exchange rates:': '487.9 (2017 est.)',
#   'GDP - composition, by sector of origin:': ['agriculture: 17.7%',
#    'industry: 27.8%',
#    'services: 54.5% (2017 est.)'],
#   'GDP - composition, by end use:': ['household consumption: 76.6%',
#    'government consumption: 13.1%',
#    'investment in fixed capital: 17.9%',
#    'investment in inventories: 3%',
#    'exports of goods and services: 37.3%',
#    'imports of goods and services: -47.9% (2017 est.)'],
#   'Population:': '3,045,191 (July 2017 est.)',
#   'Population growth rate:': '-0.21% (2017 est.)',
#   'Urbanization:': 'urban population: 63.1% of total population (2018)',
#   'Infant mortality rate:': 'total: 12.7 deaths/1,000 live births',
#   'Education expenditures:': '2.8% of GDP (2016)',
#   'Literacy:': 'definition: age 15 and over can read and write',
#   'Telephones - fixed lines:': 'total subscriptions: 505,190',
#   'Telephones - mobile cellular:': 'total subscriptions: 3,488,524',
#   'Internet users:': 'total: 1,891,775',
#   'Land boundaries:': 'border countries (4): Azerbaijan 996 km, Georgia 219 km, Iran 44 km, Turkey 311 km',
#   'Geographic coordinates:': '40 00 N, 45 00 E',
#   'Country': ' Armenia '},
#  {'GDP - per capita \\(PPP\\):': '$25,300 (2011 est.)',
#   'Industrial production growth rate:': 'NA%',
#   'Labor force:': '51,610',
#   'Unemployment rate:': '6.9% (2005 est.)',
#   'Population below poverty line:': 'NA%',
#   'Distribution of family income - Gini index:': nan,
#   'Public debt:': '67% of GDP (2013)',
#   'Inflation': '-0.1% (2017 est.)',
#   'Current account balance:': nan,
#   'Exports:': '$246.3 million (2017 est.)',
#   'Imports:': '$1.165 billion (2017 est.)',
#   'Reserves of foreign exchange and gold:': nan,
#   'Exchange rates:': '1.79 (2017 est.)',
#   'GDP - composition, by sector of origin:': ['agriculture: 0.4%',
#    'industry: 33.3%',
#    'services: 66.3% (2002 est.)'],
#   'GDP - composition, by end use:': ['household consumption: 60.3%',
#    'government consumption: 26.2%',
#    'investment in fixed capital: 22.3%',
#    'investment in inventories: 0%',
#    'exports of goods and services: 70.2%',
#    'imports of goods and services: -79% (2014 est.)'],
#   'Population:': '115,120 (July 2017 est.)',
#   'Population growth rate:': '1.27% (2017 est.)',
#   'Urbanization:': 'urban population: 43.4% of total population (2018)',
#   'Infant mortality rate:': 'total: 10.7 deaths/1,000 live births',
#   'Education expenditures:': '6.5% of GDP (2015)',
#   'Literacy:': 'definition: age 15 and over can read and write',
#   'Telephones - fixed lines:': 'total subscriptions: 35,000',
#   'Telephones - mobile cellular:': 'total subscriptions: 141,000',
#   'Internet users:': 'total: 106,309',
#   'Land boundaries:': 'Coastline:',
#   'Geographic coordinates:': '12 30 N, 69 58 W',
#   'Country': ' Aruba '},
#  {'GDP - per capita \\(PPP\\):': nan,
#   'Industrial production growth rate:': nan,
#   'Labor force:': nan,
#   'Unemployment rate:': nan,
#   'Population below poverty line:': nan,
#   'Distribution of family income - Gini index:': nan,
#   'Public debt:': nan,
#   'Inflation': nan,
#   'Current account balance:': nan,
#   'Exports:': nan,
#   'Imports:': nan,
#   'Reserves of foreign exchange and gold:': nan,
#   'Exchange rates:': nan,
#   'GDP - composition, by sector of origin:': nan,
#   'GDP - composition, by end use:': nan,
#   'Population:': 'no indigenous inhabitants',
#   'Population growth rate:': nan,
#   'Urbanization:': nan,
#   'Infant mortality rate:': nan,
#   'Education expenditures:': nan,
#   'Literacy:': nan,
#   'Telephones - fixed lines:': nan,
#   'Telephones - mobile cellular:': nan,
#   'Internet users:': nan,
#   'Land boundaries:': 'Coastline:',
#   'Geographic coordinates:': '12 14 S, 123 05 E',
#   'Country': ' Ashmore and Cartier Islands '},
#  {'GDP - per capita \\(PPP\\):': nan,
#   'Industrial production growth rate:': nan,
#   'Labor force:': nan,
#   'Unemployment rate:': nan,
#   'Population below poverty line:': nan,
#   'Distribution of family income - Gini index:': nan,
#   'Public debt:': nan,
#   'Inflation': nan,
#   'Current account balance:': nan,
#   'Exports:': nan,
#   'Imports:': nan,
#   'Reserves of foreign exchange and gold:': nan,
#   'Exchange rates:': nan,
#   'GDP - composition, by sector of origin:': nan,
#   'GDP - composition, by end use:': nan,
#   'Population:': nan,
#   'Population growth rate:': nan,
#   'Urbanization:': nan,
#   'Infant mortality rate:': nan,
#   'Education expenditures:': nan,
#   'Literacy:': nan,
#   'Telephones - fixed lines:': nan,
#   'Telephones - mobile cellular:': nan,
#   'Internet users:': nan,
#   'Land boundaries:': nan,
#   'Geographic coordinates:': '0 00 N, 25 00 W',
#   'Country': ' Atlantic Ocean '},
#  {'GDP - per capita \\(PPP\\):': '$50,300 (2017 est.)',
#   'Industrial production growth rate:': '1% (2017 est.)',
#   'Labor force:': '12.91 million (2017 est.)',
#   'Unemployment rate:': '5.6% (2017 est.)',
#   'Population below poverty line:': 'NA%',
#   'Distribution of family income - Gini index:': '30.3 (2008)',
#   'Public debt:': '41.6% of GDP (2017 est.)',
#   'Inflation': '2% (2017 est.)',
#   'Current account balance:': '-$32.27 billion (2017 est.)',
#   'Exports:': '$224.5 billion (2017 est.)',
#   'Imports:': '$215.4 billion (2017 est.)',
#   'Reserves of foreign exchange and gold:': '$60.3 billion (31 December 2017 est.)',
#   'Exchange rates:': '1.31 (2017 est.)',
#   'GDP - composition, by sector of origin:': ['agriculture: 3.6%',
#    'industry: 26.1%',
#    'services: 70.3% (2017 est.)'],
#   'GDP - composition, by end use:': ['household consumption: 57.1%',
#    'government consumption: 19%',
#    'investment in fixed capital: 24.2%',
#    'investment in inventories: 0%',
#    'exports of goods and services: 20.5%',
#    'imports of goods and services: -20.8% (2017 est.)'],
#   'Population:': '23,232,413 (July 2017 est.)',
#   'Population growth rate:': '1.03% (2017 est.)',
#   'Urbanization:': 'urban population: 86% of total population (2018)',
#   'Infant mortality rate:': 'total: 4.3 deaths/1,000 live births',
#   'Education expenditures:': '5.2% of GDP (2014)',
#   'Literacy:': nan,
#   'Telephones - fixed lines:': 'total subscriptions: 8.46 million',
#   'Telephones - mobile cellular:': 'total subscriptions: 27.553 million',
#   'Internet users:': 'total: 20,288,409',
#   'Land boundaries:': 'Coastline:',
#   'Geographic coordinates:': '27 00 S, 133 00 E',
#   'Country': ' Australia '},
#  {'GDP - per capita \\(PPP\\):': '$49,900 (2017 est.)',
#   'Industrial production growth rate:': '3.4% (2017 est.)',
#   'Labor force:': '4.26 million (2017 est.)',
#   'Unemployment rate:': '5.5% (2017 est.)',
#   'Population below poverty line:': '3% (2017 est.)',
#   'Distribution of family income - Gini index:': '30.5 (2015)',
#   'Public debt:': '78.8% of GDP (2017 est.)',
#   'Inflation': '2.2% (2017 est.)',
#   'Current account balance:': '$8.6 billion (2017 est.)',
#   'Exports:': '$161.8 billion (2017 est.)',
#   'Imports:': '$168.3 billion (2017 est.)',
#   'Reserves of foreign exchange and gold:': '$20.68 billion (31 December 2017 est.)',
#   'Exchange rates:': '0.89 (2017 est.)',
#   'GDP - composition, by sector of origin:': ['agriculture: 1.2%',
#    'industry: 28.4%',
#    'services: 70.4% (2017 est.)'],
#   'GDP - composition, by end use:': ['household consumption: 52.1%',
#    'government consumption: 19.8%',
#    'investment in fixed capital: 23.1%',
#    'investment in inventories: 1.1%',
#    'exports of goods and services: 54.2%',
#    'imports of goods and services: -50.3% (2017 est.)'],
#   'Population:': '8,754,413 (July 2017 est.)',
#   'Population growth rate:': '0.47% (2017 est.)',
#   'Urbanization:': 'urban population: 58.3% of total population (2018)',
#   'Infant mortality rate:': 'total: 3.4 deaths/1,000 live births',
#   'Education expenditures:': '5.4% of GDP (2014)',
#   'Literacy:': nan,
#   'Telephones - fixed lines:': 'total subscriptions: 3,762,801',
#   'Telephones - mobile cellular:': 'total subscriptions: 14,924,340',
#   'Internet users:': 'total: 7,346,055',
#   'Land boundaries:': 'border countries (8): Czech Republic 402 km, Germany 801 km, Hungary 321 km, Italy 404 km, Liechtenstein 34 km, Slovakia 105 km, Slovenia 299 km, Switzerland 158 km',
#   'Geographic coordinates:': '47 20 N, 13 20 E',
#   'Country': ' Austria '},
#  {'GDP - per capita \\(PPP\\):': '$17,500 (2017 est.)',
#   'Industrial production growth rate:': '-6% (2017 est.)',
#   'Labor force:': '5.118 million (2017 est.)',
#   'Unemployment rate:': '6% (2017 est.)',
#   'Population below poverty line:': '4.9% (2015 est.)',
#   'Distribution of family income - Gini index:': '33.7 (2008)',
#   'Public debt:': '54.7% of GDP (2017 est.)',
#   'Inflation': '13% (2017 est.)',
#   'Current account balance:': '$1.413 billion (2017 est.)',
#   'Exports:': '$15.69 billion (2017 est.)',
#   'Imports:': '$8.734 billion (2017 est.)',
#   'Reserves of foreign exchange and gold:': '$8.886 billion (31 December 2017 est.)',
#   'Exchange rates:': '1.72 (2017 est.)',
#   'GDP - composition, by sector of origin:': ['agriculture: 6.2%',
#    'industry: 49.1%',
#    'services: 44.7% (2017 est.)'],
#   'GDP - composition, by end use:': ['household consumption: 53.9%',
#    'government consumption: 12.1%',
#    'investment in fixed capital: 26.3%',
#    'investment in inventories: 0.1%',
#    'exports of goods and services: 45.9%',
#    'imports of goods and services: -38.2% (2017 est.)'],
#   'Population:': '9,961,396 (July 2017 est.)',
#   'Population growth rate:': '0.87% (2017 est.)',
#   'Urbanization:': 'urban population: 55.7% of total population (2018)',
#   'Infant mortality rate:': 'total: 23.8 deaths/1,000 live births',
#   'Education expenditures:': '3% of GDP (2015)',
#   'Literacy:': 'definition: age 15 and over can read and write',
#   'Telephones - fixed lines:': 'total subscriptions: 1,688,325',
#   'Telephones - mobile cellular:': 'total subscriptions: 10.127 million',
#   'Internet users:': 'total: 7,720,502',
#   'Land boundaries:': 'border countries (5): Armenia 996 km, Georgia 428 km, Iran 689 km, Russia 338 km, Turkey 17 km',
#   'Geographic coordinates:': '40 30 N, 47 30 E',
#   'Country': ' Azerbaijan '},
#  {'GDP - per capita \\(PPP\\):': '$31,200 (2017 est.)',
#   'Industrial production growth rate:': '1.5% (2017 est.)',
#   'Labor force:': '196,900 (2013 est.)',
#   'Unemployment rate:': '10% (2017 est.)',
#   'Population below poverty line:': '9.3% (2010 est.)',
#   'Distribution of family income - Gini index:': nan,
#   'Public debt:': '57.2% of GDP (2017 est.)',
#   'Inflation': '1.4% (2017 est.)',
#   'Current account balance:': '-$1.909 billion (2017 est.)',
#   'Exports:': '$934.7 million (2017 est.)',
#   'Imports:': '$3.105 billion (2017 est.)',
#   'Reserves of foreign exchange and gold:': '$922.1 million (31 December 2017 est.)',
#   'Exchange rates:': '1 (2017 est.)',
#   'GDP - composition, by sector of origin:': ['agriculture: 2.3%',
#    'industry: 7.7%',
#    'services: 90% (2017 est.)'],
#   'GDP - composition, by end use:': ['household consumption: 66.4%',
#    'government consumption: 16.9%',
#    'investment in fixed capital: 28.3%',
#    'investment in inventories: 1%',
#    'exports of goods and services: 38.3%',
#    'imports of goods and services: -50.8% (2017 est.)'],
#   'Population:': '329,988',
#   'Population growth rate:': '0.81% (2017 est.)',
#   'Urbanization:': 'urban population: 83% of total population (2018)',
#   'Infant mortality rate:': 'total: 11.3 deaths/1,000 live births',
#   'Education expenditures:': 'NA',
#   'Literacy:': nan,
#   'Telephones - fixed lines:': 'total subscriptions: 113,852',
#   'Telephones - mobile cellular:': 'total subscriptions: 353,540',
#   'Internet users:': 'total: 261,853',
#   'Land boundaries:': 'Coastline:',
#   'Geographic coordinates:': '24 15 N, 76 00 W',
#   'Country': ' Bahamas, The '},
#  {'GDP - per capita \\(PPP\\):': '$48,500 (2017 est.)',
#   'Industrial production growth rate:': '0% (2017 est.)',
#   'Labor force:': '831,600',
#   'Unemployment rate:': '3.8% (2017 est.)',
#   'Population below poverty line:': 'NA%',
#   'Distribution of family income - Gini index:': nan,
#   'Public debt:': '90.3% of GDP (2017 est.)',
#   'Inflation': '1.4% (2017 est.)',
#   'Current account balance:': '-$1.37 billion (2017 est.)',
#   'Exports:': '$14.33 billion (2017 est.)',
#   'Imports:': '$13.96 billion (2017 est.)',
#   'Reserves of foreign exchange and gold:': '$2.166 billion (31 December 2017 est.)',
#   'Exchange rates:': '0.38 (2017 est.)',
#   'GDP - composition, by sector of origin:': ['agriculture: 0.3%',
#    'industry: 38.2%',
#    'services: 61.5% (2017 est.)'],
#   'GDP - composition, by end use:': ['household consumption: 45.8%',
#    'government consumption: 15.5%',
#    'investment in fixed capital: 26.1%',
#    'investment in inventories: 0.4%',
#    'exports of goods and services: 80.2%',
#    'imports of goods and services: -67.9% (2017 est.)'],
#   'Population:': '1,410,942 (July 2017 est.)',
#   'Population growth rate:': '2.26% (2017 est.)',
#   'Urbanization:': 'urban population: 89.3% of total population (2018)',
#   'Infant mortality rate:': 'total: 8.9 deaths/1,000 live births',
#   'Education expenditures:': '2.7% of GDP (2016)',
#   'Literacy:': 'definition: age 15 and over can read and write',
#   'Telephones - fixed lines:': 'total subscriptions: 285,318',
#   'Telephones - mobile cellular:': 'total subscriptions: 2,364,477',
#   'Internet users:': 'total: 1,351,326',
#   'Land boundaries:': 'Coastline:',
#   'Geographic coordinates:': '26 00 N, 50 33 E',
#   'Country': ' Bahrain '},
#  {'GDP - per capita \\(PPP\\):': nan,
#   'Industrial production growth rate:': nan,
#   'Labor force:': nan,
#   'Unemployment rate:': nan,
#   'Population below poverty line:': nan,
#   'Distribution of family income - Gini index:': nan,
#   'Public debt:': nan,
#   'Inflation': nan,
#   'Current account balance:': nan,
#   'Exports:': nan,
#   'Imports:': nan,
#   'Reserves of foreign exchange and gold:': nan,
#   'Exchange rates:': nan,
#   'GDP - composition, by sector of origin:': nan,
#   'GDP - composition, by end use:': nan,
#   'Population:': 'no indigenous inhabitants',
#   'Population growth rate:': nan,
#   'Urbanization:': nan,
#   'Infant mortality rate:': nan,
#   'Education expenditures:': nan,
#   'Literacy:': nan,
#   'Telephones - fixed lines:': nan,
#   'Telephones - mobile cellular:': nan,
#   'Internet users:': nan,
#   'Land boundaries:': 'Coastline:',
#   'Geographic coordinates:': 'Baker Island: 0 13 N, 176 28 W',
#   'Country': ' Baker Island '},
#  {'GDP - per capita \\(PPP\\):': '$4,200 (2017 est.)',
#   'Industrial production growth rate:': '8.6% (2017 est.)',
#   'Labor force:': '66.64 million',
#   'Unemployment rate:': '4% (2017 est.)',
#   'Population below poverty line:': '24.3% (2016 est.)',
#   'Distribution of family income - Gini index:': '32.1 (2010)',
#   'Public debt:': '32.4% of GDP (2017 est.)',
#   'Inflation': '5.7% (2017 est.)',
#   'Current account balance:': '-$3.158 billion (2017 est.)',
#   'Exports:': '$35.91 billion (2017 est.)',
#   'Imports:': '$42.38 billion (2017 est.)',
#   'Reserves of foreign exchange and gold:': '$33.66 billion (31 December 2017 est.)',
#   'Exchange rates:': '80.69 (2017 est.)',
#   'GDP - composition, by sector of origin:': ['agriculture: 14.2%',
#    'industry: 29.2%',
#    'services: 56.5% (2017 est.)'],
#   'GDP - composition, by end use:': ['household consumption: 67.5%',
#    'government consumption: 6.4%',
#    'investment in fixed capital: 30.3%',
#    'investment in inventories: 1%',
#    'exports of goods and services: 15.5%',
#    'imports of goods and services: -20.7% (2017 est.)'],
#   'Population:': '157,826,578 (July 2017 est.)',
#   'Population growth rate:': '1.04% (2017 est.)',
#   'Urbanization:': 'urban population: 36.6% of total population (2018)',
#   'Infant mortality rate:': 'total: 31.7 deaths/1,000 live births',
#   'Education expenditures:': '2.5% of GDP (2016)',
#   'Literacy:': 'definition: age 15 and over can read and write',
#   'Telephones - fixed lines:': 'total subscriptions: 710,189',
#   'Telephones - mobile cellular:': 'total subscriptions: 145,113,669',
#   'Internet users:': 'total: 28,499,324',
#   'Land boundaries:': 'border countries (2): Burma 271 km, India 4,142 km',
#   'Geographic coordinates:': '24 00 N, 90 00 E',
#   'Country': ' Bangladesh '},
#  {'GDP - per capita \\(PPP\\):': '$18,700 (2017 est.)',
#   'Industrial production growth rate:': '-3.5% (2016 est.)',
#   'Labor force:': '144,000 (2017 est.)',
#   'Unemployment rate:': '10.5% (2017 est.)',
#   'Population below poverty line:': 'NA%',
#   'Distribution of family income - Gini index:': nan,
#   'Public debt:': '132.9% of GDP (2017 est.)',
#   'Inflation': '4.4% (2017 est.)',
#   'Current account balance:': '-$184 million (2017 est.)',
#   'Exports:': '$482.5 million (2017 est.)',
#   'Imports:': '$1.515 billion (2017 est.)',
#   'Reserves of foreign exchange and gold:': '$204.9 million (31 December 2017 est.)',
#   'Exchange rates:': '2 (2017 est.)',
#   'GDP - composition, by sector of origin:': ['agriculture: 1.4%',
#    'industry: 4.8%',
#    'services: 93.8% (2016 est.)'],
#   'GDP - composition, by end use:': ['household consumption: 83.4%',
#    'government consumption: 13.6%',
#    'investment in fixed capital: 17.1%',
#    'investment in inventories: 0.2%',
#    'exports of goods and services: 36.4%',
#    'imports of goods and services: -50% (2016 est.)'],
#   'Population:': '292,336 (July 2017 est.)',
#   'Population growth rate:': '0.28% (2017 est.)',
#   'Urbanization:': 'urban population: 31.1% of total population (2018)',
#   'Infant mortality rate:': 'total: 10.2 deaths/1,000 live births',
#   'Education expenditures:': '5.1% of GDP (2016)',
#   'Literacy:': nan,
#   'Telephones - fixed lines:': 'total subscriptions: 139,645',
#   'Telephones - mobile cellular:': 'total subscriptions: 337,791',
#   'Internet users:': 'total: 231,883',
#   'Land boundaries:': 'Coastline:',
#   'Geographic coordinates:': '13 10 N, 59 32 W',
#   'Country': ' Barbados '},
#  {'GDP - per capita \\(PPP\\):': '$18,900 (2017 est.)',
#   'Industrial production growth rate:': '3.5% (2017 est.)',
#   'Labor force:': '4.381 million (2016 est.)',
#   'Unemployment rate:': '1% (2017 est.)',
#   'Population below poverty line:': '5.7% (2016 est.)',
#   'Distribution of family income - Gini index:': '26.5 (2011)',
#   'Public debt:': '51% of GDP (2017 est.)',
#   'Inflation': '6% (2017 est.)',
#   'Current account balance:': '-$956 million (2017 est.)',
#   'Exports:': '$24.2 billion (2017 est.)',
#   'Imports:': '$26.2 billion (2017 est.)',
#   'Reserves of foreign exchange and gold:': '$5.059 billion (31 December 2017 est.)',
#   'Exchange rates:': '1.9 (2017 est.)',
#   'GDP - composition, by sector of origin:': ['agriculture: 8.3%',
#    'industry: 40.6%',
#    'services: 51.1% (2017 est.)'],
#   'GDP - composition, by end use:': ['household consumption: 54.8%',
#    'government consumption: 16.8%',
#    'investment in fixed capital: 24.1%',
#    'investment in inventories: -1.1%',
#    'exports of goods and services: 65%',
#    'imports of goods and services: -59.6% (2017 est.)'],
#   'Population:': '9,549,747 (July 2017 est.)',
#   'Population growth rate:': '-0.22% (2017 est.)',
#   'Urbanization:': 'urban population: 78.6% of total population (2018)',
#   'Infant mortality rate:': 'total: 3.6 deaths/1,000 live births',
#   'Education expenditures:': '5% of GDP (2016)',
#   'Literacy:': 'definition: age 15 and over can read and write',
#   'Telephones - fixed lines:': 'total subscriptions: 4,499,821',
#   'Telephones - mobile cellular:': 'total subscriptions: 10,963,224',
#   'Internet users:': 'total: 6,805,786',
#   'Land boundaries:': 'border countries (5): Latvia 161 km, Lithuania 640 km, Poland 418 km, Russia 1,312 km, Ukraine 1,111 km',
#   'Geographic coordinates:': '53 00 N, 28 00 E',
#   'Country': ' Belarus '},
#  {'GDP - per capita \\(PPP\\):': '$46,600 (2017 est.)',
#   'Industrial production growth rate:': '1.5% (2017 est.)',
#   'Labor force:': '5.324 million (2017 est.)',
#   'Unemployment rate:': '7.3% (2017 est.)',
#   'Population below poverty line:': '15.1% (2013 est.)',
#   'Distribution of family income - Gini index:': '25.9 (2013 est.)',
#   'Public debt:': '103.2% of GDP (2017 est.)',
#   'Inflation': '2.2% (2017 est.)',
#   'Current account balance:': '$484 million (2017 est.)',
#   'Exports:': '$309.1 billion (2017 est.)',
#   'Imports:': '$306.1 billion (2017 est.)',
#   'Reserves of foreign exchange and gold:': '$23.57 billion (31 December 2016 est.)',
#   'Exchange rates:': '0.89 (2017 est.)',
#   'GDP - composition, by sector of origin:': ['agriculture: 0.7%',
#    'industry: 21.8%',
#    'services: 77.5% (2017 est.)'],
#   'GDP - composition, by end use:': ['household consumption: 50.8%',
#    'government consumption: 23.3%',
#    'investment in fixed capital: 23%',
#    'investment in inventories: 0.5%',
#    'exports of goods and services: 87.7%',
#    'imports of goods and services: -85.3% (2017 est.)'],
#   'Population:': '11,491,346 (July 2017 est.)',
#   'Population growth rate:': '0.7% (2017 est.)',
#   'Urbanization:': 'urban population: 98% of total population (2018)',
#   'Infant mortality rate:': 'total: 3.4 deaths/1,000 live births',
#   'Education expenditures:': '6.6% of GDP (2014)',
#   'Literacy:': nan,
#   'Telephones - fixed lines:': 'total subscriptions: 4,251,564',
#   'Telephones - mobile cellular:': 'total subscriptions: 11,961,089',
#   'Internet users:': 'total: 9,870,734',
#   'Land boundaries:': 'border countries (4): France 556 km, Germany 133 km, Luxembourg 130 km, Netherlands 478 km',
#   'Geographic coordinates:': '50 50 N, 4 00 E',
#   'Country': ' Belgium '},
#  {'GDP - per capita \\(PPP\\):': '$8,300 (2017 est.)',
#   'Industrial production growth rate:': '-2% (2017 est.)',
#   'Labor force:': '120,500',
#   'Unemployment rate:': '10.1% (2017 est.)',
#   'Population below poverty line:': '41% (2013 est.)',
#   'Distribution of family income - Gini index:': nan,
#   'Public debt:': '99% of GDP (2017 est.)',
#   'Inflation': '1.1% (2017 est.)',
#   'Current account balance:': '-$143 million (2017 est.)',
#   'Exports:': '$483.4 million (2017 est.)',
#   'Imports:': '$944.4 million (2017 est.)',
#   'Reserves of foreign exchange and gold:': '$368.3 million (31 December 2017 est.)',
#   'Exchange rates:': '2 (2017 est.)',
#   'GDP - composition, by sector of origin:': ['agriculture: 9.7%',
#    'industry: 13.8%',
#    'services: 62.2% (2017 est.)'],
#   'GDP - composition, by end use:': ['household consumption: 75.6%',
#    'government consumption: 14.1%',
#    'investment in fixed capital: 23%',
#    'investment in inventories: 1%',
#    'exports of goods and services: 57.8%',
#    'imports of goods and services: -71.5% (2017 est.)'],
#   'Population:': '360,346 (July 2017 est.)',
#   'Population growth rate:': '1.8% (2017 est.)',
#   'Urbanization:': 'urban population: 45.7% of total population (2018)',
#   'Infant mortality rate:': 'total: 18.9 deaths/1,000 live births',
#   'Education expenditures:': '7.4% of GDP (2017)',
#   'Literacy:': nan,
#   'Telephones - fixed lines:': 'total subscriptions: 23,000',
#   'Telephones - mobile cellular:': 'total subscriptions: 227,000',
#   'Internet users:': 'total: 157,735',
#   'Land boundaries:': 'border countries (2): Guatemala 266 km, Mexico 276 km',
#   'Geographic coordinates:': '17 15 N, 88 45 W',
#   'Country': ' Belize '},
#  {'GDP - per capita \\(PPP\\):': '$2,300 (2017 est.)',
#   'Industrial production growth rate:': '5% (2017 est.)',
#   'Labor force:': '3.662 million (2007 est.)',
#   'Unemployment rate:': '1% (2014 est.)',
#   'Population below poverty line:': '36.2% (2011 est.)',
#   'Distribution of family income - Gini index:': '36.5 (2003)',
#   'Public debt:': '54.6% of GDP (2017 est.)',
#   'Inflation': '0.1% (2017 est.)',
#   'Current account balance:': '-$869 million (2017 est.)',
#   'Exports:': '$1.76 billion (2017 est.)',
#   'Imports:': '$2.448 billion (2017 est.)',
#   'Reserves of foreign exchange and gold:': '$60.2 million (31 December 2017 est.)',
#   'Exchange rates:': '605.3 (2017 est.)',
#   'GDP - composition, by sector of origin:': ['agriculture: 25.6%',
#    'industry: 23.1%',
#    'services: 51.3% (2017 est.)'],
#   'GDP - composition, by end use:': ['household consumption: 69%',
#    'government consumption: 17%',
#    'investment in fixed capital: 26.5%',
#    'investment in inventories: -0.1%',
#    'exports of goods and services: 27.1%',
#    'imports of goods and services: -39.6% (2017 est.)'],
#   'Population:': '11,038,805',
#   'Population growth rate:': '2.71% (2017 est.)',
#   'Urbanization:': 'urban population: 47.3% of total population (2018)',
#   'Infant mortality rate:': 'total: 52.8 deaths/1,000 live births',
#   'Education expenditures:': '4.4% of GDP (2015)',
#   'Literacy:': 'definition: age 15 and over can read and write',
#   'Telephones - fixed lines:': 'total subscriptions: 56,787',
#   'Telephones - mobile cellular:': 'total subscriptions: 8,773,044',
#   'Internet users:': 'total: 1,288,336',
#   'Land boundaries:': 'border countries (4): Burkina Faso 386 km, Niger 277 km, Nigeria 809 km, Togo 651 km',
#   'Geographic coordinates:': '9 30 N, 2 15 E',
#   'Country': ' Benin '},
#  {'GDP - per capita \\(PPP\\):': '$99,400 (2016 est.)',
#   'Industrial production growth rate:': '2.3% (2017 est.)',
#   'Labor force:': '33,480 (2016)',
#   'Unemployment rate:': '7% (2017 est.)',
#   'Population below poverty line:': '11% (2008 est.)',
#   'Distribution of family income - Gini index:': nan,
#   'Public debt:': '43% of GDP (FY14/15)',
#   'Inflation': '1.6% (2017 est.)',
#   'Current account balance:': nan,
#   'Exports:': '$20 million (2017 est.)',
#   'Imports:': '$979.5 million (2017 est.)',
#   'Reserves of foreign exchange and gold:': nan,
#   'Exchange rates:': '1 (2017 est.)',
#   'GDP - composition, by sector of origin:': ['agriculture: 0.8%',
#    'industry: 5.8%',
#    'services: 93.3% (2017 est.)'],
#   'GDP - composition, by end use:': ['household consumption: 54.2%',
#    'government consumption: 16.3%',
#    'investment in fixed capital: 13.1%',
#    'investment in inventories: 0%',
#    'exports of goods and services: 50.4%',
#    'imports of goods and services: -34% (2017 est.)'],
#   'Population:': '70,864 (July 2017 est.)',
#   'Population growth rate:': '0.45% (2017 est.)',
#   'Urbanization:': 'urban population: 100% of total population (2018)',
#   'Infant mortality rate:': 'total: 2.5 deaths/1,000 live births',
#   'Education expenditures:': '1.5% of GDP (2017)',
#   'Literacy:': nan,
#   'Telephones - fixed lines:': 'total subscriptions: 21,883',
#   'Telephones - mobile cellular:': 'total subscriptions: 64,997',
#   'Internet users:': 'total: 69,126',
#   'Land boundaries:': 'Coastline:',
#   'Geographic coordinates:': '32 20 N, 64 45 W',
#   'Country': ' Bermuda '},
#  {'GDP - per capita \\(PPP\\):': '$8,700 (2017 est.)',
#   'Industrial production growth rate:': '8.9% (2017 est.)',
#   'Labor force:': '397,900',
#   'Unemployment rate:': '3.2% (2017 est.)',
#   'Population below poverty line:': '12% (2012 est.)',
#   'Distribution of family income - Gini index:': '38.8 (2012)',
#   'Public debt:': '102.4% of GDP (2017 est.)',
#   'Inflation': '3.4% (2017 est.)',
#   'Current account balance:': '-$479 million (2017 est.)',
#   'Exports:': '$580 million (2017 est.)',
#   'Imports:': '$1.1 billion (2017 est.)',
#   'Reserves of foreign exchange and gold:': nan,
#   'Exchange rates:': '64.97 (2017 est.)',
#   'GDP - composition, by sector of origin:': ['agriculture: 15.7%',
#    'industry: 42.6%',
#    'services: 41.7% (2017 est.)'],
#   'GDP - composition, by end use:': ['household consumption: 50.1%',
#    'government consumption: 15.9%',
#    'investment in fixed capital: 49.4%',
#    'investment in inventories: 0%',
#    'exports of goods and services: 25.9%',
#    'imports of goods and services: -41.4% (2017 est.)'],
#   'Population:': '758,288 (July 2017 est.)',
#   'Population growth rate:': '1.07% (2017 est.)',
#   'Urbanization:': 'urban population: 40.9% of total population (2018)',
#   'Infant mortality rate:': 'total: 32.1 deaths/1,000 live births',
#   'Education expenditures:': '7.4% of GDP (2015)',
#   'Literacy:': 'definition: age 15 and over can read and write',
#   'Telephones - fixed lines:': 'total subscriptions: 21,364',
#   'Telephones - mobile cellular:': 'total subscriptions: 730,623',
#   'Internet users:': 'total: 313,347',
#   'Land boundaries:': 'border countries (2): China 477 km, India 659 km',
#   'Geographic coordinates:': '27 30 N, 90 30 E',
#   'Country': ' Bhutan '},
#  {'GDP - per capita \\(PPP\\):': '$7,500 (2017 est.)',
#   'Industrial production growth rate:': '3.5% (2017 est.)',
#   'Labor force:': '5.719 million (2016 est.)',
#   'Unemployment rate:': '4% (2017 est.)',
#   'Population below poverty line:': '38.6%',
#   'Distribution of family income - Gini index:': '47 (2016 est.)',
#   'Public debt:': '50.9% of GDP (2017 est.)',
#   'Inflation': '2.8% (2017 est.)',
#   'Current account balance:': '-$2.155 billion (2017 est.)',
#   'Exports:': '$7.986 billion (2017 est.)',
#   'Imports:': '$9.288 billion (2017 est.)',
#   'Reserves of foreign exchange and gold:': '$10.26 billion (31 December 2017 est.)',
#   'Exchange rates:': '6.86 (2017 est.)',
#   'GDP - composition, by sector of origin:': ['agriculture: 13%',
#    'industry: 37.4%',
#    'services: 50% (2017 est.)'],
#   'GDP - composition, by end use:': ['household consumption: 69%',
#    'government consumption: 17.6%',
#    'investment in fixed capital: 20.3%',
#    'investment in inventories: 0.5%',
#    'exports of goods and services: 24.2%',
#    'imports of goods and services: -31.6% (2017 est.)'],
# ...
#   'Industrial production growth rate:': '9.4% (2017 est.)',
#   'Labor force:': '54.8 million (2017 est.)',
#   'Unemployment rate:': '2.2% (2017 est.)',
#   'Population below poverty line:': '8% (2017 est.)',
#   'Distribution of family income - Gini index:': '34.8 (2014)',
#   'Public debt:': '58.2% of GDP (2017 est.)',
#   'Inflation': '3.5% (2017 est.)',
#   'Current account balance:': '$9.104 billion (2017 est.)',
#   'Exports:': '$214 billion (2017 est.)',
#   'Imports:': '$211.1 billion (2017 est.)',
#   'Reserves of foreign exchange and gold:': '$57.5 billion (10 February 2018 est.)',
#   'Exchange rates:': '22,425 (2017 est.)',
#   'GDP - composition, by sector of origin:': ['agriculture: 15.3%',
#    'industry: 33.3%',
#    'services: 41.3% (2017 est.)'],
#   'GDP - composition, by end use:': ['household consumption: 68.5%',
#    'government consumption: 6.6%',
#    'investment in fixed capital: 24.8%',
#    'investment in inventories: 2.9%',
#    'exports of goods and services: 98.6%',
#    'imports of goods and services: -101.4% (2017 est.)'],
#   'Population:': '96,160,163 (July 2017 est.)',
#   'Population growth rate:': '0.93% (2017 est.)',
#   'Urbanization:': 'urban population: 35.9% of total population (2018)',
#   'Infant mortality rate:': 'total: 17.3 deaths/1,000 live births',
#   'Education expenditures:': '5.7% of GDP (2013)',
#   'Literacy:': 'definition: age 15 and over can read and write',
#   'Telephones - fixed lines:': 'total subscriptions: 4,526,077',
#   'Telephones - mobile cellular:': 'total subscriptions: 120,016,181',
#   'Internet users:': 'total: 49.741 million',
#   'Land boundaries:': 'border countries (3): Cambodia 1,158 km, China 1,297 km, Laos 2,161 km',
#   'Geographic coordinates:': '16 10 N, 107 50 E',
#   'Country': ' Vietnam '},
#  {'GDP - per capita \\(PPP\\):': '$37,000 (2016 est.)',
#   'Industrial production growth rate:': 'NA%',
#   'Labor force:': '48,550 (2016 est.)',
#   'Unemployment rate:': '10.4% (2017 est.)',
#   'Population below poverty line:': '28.9% (2002 est.)',
#   'Distribution of family income - Gini index:': nan,
#   'Public debt:': '53.3% of GDP (2016 est.)',
#   'Inflation': '1% (2016 est.)',
#   'Current account balance:': nan,
#   'Exports:': '$1.81 billion (2016 est.)',
#   'Imports:': '$2.489 billion (2016 est.)',
#   'Reserves of foreign exchange and gold:': nan,
#   'Exchange rates:': nan,
#   'GDP - composition, by sector of origin:': ['agriculture: 2%',
#    'industry: 20%',
#    'services: 78% (2012 est.)'],
#   'GDP - composition, by end use:': ['household consumption: 68.2%',
#    'government consumption: 26.8%',
#    'investment in fixed assets: 7.5%',
#    'investment in inventories: NA%',
#    'exports of goods and services: 46.7%',
#    'imports of goods and services: -64.3% (2016 est.)'],
#   'Population:': '107,268 (July 2017 est.)',
#   'Population growth rate:': '-0.25% (2017 est.)',
#   'Urbanization:': 'urban population: 95.7% of total population (2018)',
#   'Infant mortality rate:': 'total: 7.9 deaths/1,000 live births',
#   'Education expenditures:': nan,
#   'Literacy:': nan,
#   'Telephones - fixed lines:': 'total subscriptions: 76,000',
#   'Telephones - mobile cellular:': nan,
#   'Internet users:': 'total: 57,000',
#   'Land boundaries:': 'Coastline:',
#   'Geographic coordinates:': '18 20 N, 64 50 W',
#   'Country': ' Virgin Islands '},
#  {'GDP - per capita \\(PPP\\):': nan,
#   'Industrial production growth rate:': nan,
#   'Labor force:': nan,
#   'Unemployment rate:': nan,
#   'Population below poverty line:': nan,
#   'Distribution of family income - Gini index:': nan,
#   'Public debt:': nan,
#   'Inflation': nan,
#   'Current account balance:': nan,
#   'Exports:': nan,
#   'Imports:': nan,
#   'Reserves of foreign exchange and gold:': nan,
#   'Exchange rates:': nan,
#   'GDP - composition, by sector of origin:': nan,
#   'GDP - composition, by end use:': nan,
#   'Population:': 'no indigenous inhabitants',
#   'Population growth rate:': nan,
#   'Urbanization:': nan,
#   'Infant mortality rate:': nan,
#   'Education expenditures:': nan,
#   'Literacy:': nan,
#   'Telephones - fixed lines:': nan,
#   'Telephones - mobile cellular:': nan,
#   'Internet users:': nan,
#   'Land boundaries:': 'Coastline:',
#   'Geographic coordinates:': '19 17 N, 166 39 E',
#   'Country': ' Wake Island '},
#  {'GDP - per capita \\(PPP\\):': '$3,800 (2004 est.)',
#   'Industrial production growth rate:': 'NA%',
#   'Labor force:': '4,482 (2013)',
#   'Unemployment rate:': '8.8% (2013 est.)',
#   'Population below poverty line:': 'NA%',
#   'Distribution of family income - Gini index:': nan,
#   'Public debt:': '5.6% of GDP (2004 est.)',
#   'Inflation': '0.9% (2015)',
#   'Current account balance:': nan,
#   'Exports:': '$47,450 (2004 est.)',
#   'Imports:': '$61.17 million (2004)',
#   'Reserves of foreign exchange and gold:': nan,
#   'Exchange rates:': '110.2 (2015 est.)',
#   'GDP - composition, by sector of origin:': ['agriculture: NA%',
#    'industry: NA%',
#    'services: NA%'],
#   'GDP - composition, by end use:': ['household consumption: 26%',
#    'government consumption: 54% (2005)',
#    'GDP - composition, by sector of origin:',
#    'agriculture: NA%',
#    'industry: NA%',
#    'services: NA%'],
#   'Population:': '15,714 (July 2017 est.)',
#   'Population growth rate:': '0.32% (2017 est.)',
#   'Urbanization:': 'urban population: 0% of total population (2018)',
#   'Infant mortality rate:': 'total: 4.3 deaths/1,000 live births',
#   'Education expenditures:': nan,
#   'Literacy:': nan,
#   'Telephones - fixed lines:': 'total subscriptions: 3,132',
#   'Telephones - mobile cellular:': nan,
#   'Internet users:': 'total: 3,450',
#   'Land boundaries:': 'Coastline:',
#   'Geographic coordinates:': '13 18 S, 176 12 W',
#   'Country': ' Wallis and Futuna '},
#  {'GDP - per capita \\(PPP\\):': '$4,300 (2014 est.)',
#   'Industrial production growth rate:': '4%',
#   'Labor force:': '1.24 million',
#   'Unemployment rate:': '26.7% (2017 est.)',
#   'Population below poverty line:': '18% (2011 est.)',
#   'Distribution of family income - Gini index:': '34.5 (2009 est.)',
#   'Public debt:': '24.4% of GDP (2014 est.)',
#   'Inflation': '0.8% (2017 est.)',
#   'Current account balance:': '-$1.444 billion (2017 est.)',
#   'Exports:': '$1.955 billion (2017 est.)',
#   'Imports:': '$6.476 billion (2017 est.)',
#   'Reserves of foreign exchange and gold:': '$312.8 million (31 December 2016 est.)',
#   'Exchange rates:': '3.61 (2017 est.)',
#   'GDP - composition, by sector of origin:': ['agriculture: 3%',
#    'industry: 21.1%',
#    'services: 75%'],
#   'GDP - composition, by end use:': ['household consumption: 91.3%',
#    'government consumption: 26.7%',
#    'investment in fixed capital: 23%',
#    'investment in inventories: 0%',
#    'exports of goods and services: 20%',
#    'imports of goods and services: -61%'],
#   'Population:': '2,747,943 (July 2017 est.)',
#   'Population growth rate:': '1.84% (2017 est.)',
#   'Urbanization:': 'urban population: 76.2% of total population (2018)',
#   'Infant mortality rate:': 'total: 14.1 deaths/1,000 live births',
#   'Education expenditures:': '5.7% of GDP',
#   'Literacy:': 'definition: age 15 and over can read and write',
#   'Telephones - fixed lines:': 'total subscriptions: 472,293 (includes Gaza Strip)',
#   'Telephones - mobile cellular:': 'total subscriptions: 4,135,363 (includes Gaza Strip)',
#   'Internet users:': 'total: 2.673 million (includes Gaza Strip)',
#   'Land boundaries:': 'border countries (2): Israel 330 km, Jordan 148 km',
#   'Geographic coordinates:': '32 00 N, 35 15 E',
#   'Country': ' West Bank '},
#  {'GDP - per capita \\(PPP\\):': '$2,500 (2007 est.)',
#   'Industrial production growth rate:': 'NA%',
#   'Labor force:': '144,000 (2010 est.)',
#   'Unemployment rate:': 'NA%',
#   'Population below poverty line:': 'NA%',
#   'Distribution of family income - Gini index:': nan,
#   'Public debt:': nan,
#   'Inflation': 'NA%',
#   'Current account balance:': nan,
#   'Exports:': '$NA',
#   'Imports:': '$NA',
#   'Reserves of foreign exchange and gold:': nan,
#   'Exchange rates:': '9.64 (2017 est.)',
#   'GDP - composition, by sector of origin:': ['agriculture: NA%',
#    'industry: NA%',
#    'services: 40% (2007 est.)'],
#   'GDP - composition, by end use:': nan,
#   'Population:': '603,253',
#   'Population growth rate:': '2.7% (2017 est.)',
#   'Urbanization:': 'urban population: 86.7% of total population (2018)',
#   'Infant mortality rate:': 'total: 51.9 deaths/1,000 live births',
#   'Education expenditures:': nan,
#   'Literacy:': nan,
#   'Telephones - fixed lines:': nan,
#   'Telephones - mobile cellular:': nan,
#   'Internet users:': nan,
#   'Land boundaries:': 'border countries (3): Algeria 41 km, Mauritania 1,564 km, Morocco 444 km',
#   'Geographic coordinates:': '24 30 N, 13 00 W',
#   'Country': ' Western Sahara '},
#  {'GDP - per capita \\(PPP\\):': '$1,300 (2017 est.)',
#   'Industrial production growth rate:': '13.7% (2017 est.)',
#   'Labor force:': '7.425 million (2017 est.)',
#   'Unemployment rate:': '27% (2014 est.)',
#   'Population below poverty line:': '54% (2014 est.)',
#   'Distribution of family income - Gini index:': '37.9 (2009 est.)',
#   'Public debt:': '135.5% of GDP (2017 est.)',
#   'Inflation': '4.9% (2017 est.)',
#   'Current account balance:': '-$164 million (2017 est.)',
#   'Exports:': '$501.2 million (2017 est.)',
#   'Imports:': '$4.573 billion (2017 est.)',
#   'Reserves of foreign exchange and gold:': '$245.1 million (31 December 2017 est.)',
#   'Exchange rates:': '275 (2017 est.)',
#   'GDP - composition, by sector of origin:': ['agriculture: 24.1%',
#    'industry: 14.3%',
#    'services: 61.6% (2017 est.)'],
#   'GDP - composition, by end use:': ['household consumption: 121.3%',
#    'government consumption: 13.5%',
#    'investment in fixed capital: 3.7%',
#    'investment in inventories: -7.8%',
#    'exports of goods and services: 4.2%',
#    'imports of goods and services: -34.8% (2017 est.)'],
#   'Population:': '28,036,829 (July 2017 est.)',
#   'Population growth rate:': '2.28% (2017 est.)',
#   'Urbanization:': 'urban population: 36.6% of total population (2018)',
#   'Infant mortality rate:': 'total: 46 deaths/1,000 live births',
#   'Education expenditures:': '4.6% of GDP (2008)',
#   'Literacy:': 'definition: age 15 and over can read and write',
#   'Telephones - fixed lines:': 'total subscriptions: 1,165,828',
#   'Telephones - mobile cellular:': 'total subscriptions: 16,433,055',
#   'Internet users:': 'total: 6,732,928',
#   'Land boundaries:': 'border countries (2): Oman 294 km, Saudi Arabia 1,307 km',
#   'Geographic coordinates:': '15 00 N, 48 00 E',
#   'Country': ' Yemen '},
#  {'GDP - per capita \\(PPP\\):': '$4,000 (2017 est.)',
#   'Industrial production growth rate:': '5.1% (2017 est.)',
#   'Labor force:': '6.898 million (2017 est.)',
#   'Unemployment rate:': '15% (2008 est.)',
#   'Population below poverty line:': '54.4% (2015 est.)',
#   'Distribution of family income - Gini index:': '57.5 (2013)',
#   'Public debt:': '62.8% of GDP (2017 est.)',
#   'Inflation': '6.6% (2017 est.)',
#   'Current account balance:': '-$832 million (2017 est.)',
#   'Exports:': '$8.106 billion (2017 est.)',
#   'Imports:': '$7.336 billion (2017 est.)',
#   'Reserves of foreign exchange and gold:': '$2.426 billion (31 December 2017 est.)',
#   'Exchange rates:': '9.2 (2017 est.)',
#   'GDP - composition, by sector of origin:': ['agriculture: 5.4%',
#    'industry: 35.6%',
#    'services: 59% (2017 est.)'],
#   'GDP - composition, by end use:': ['household consumption: 53.8%',
#    'government consumption: 21.2%',
#    'investment in fixed capital: 27.8%',
#    'investment in inventories: 1.2%',
#    'exports of goods and services: 45.3%',
#    'imports of goods and services: -49.2% (2017 est.)'],
#   'Population:': '15,972,001',
#   'Population growth rate:': '2.93% (2017 est.)',
#   'Urbanization:': 'urban population: 43.5% of total population (2018)',
#   'Infant mortality rate:': 'total: 61.1 deaths/1,000 live births',
#   'Education expenditures:': '1.1% of GDP (2008)',
#   'Literacy:': 'definition: age 15 and over can read and write English',
#   'Telephones - fixed lines:': 'total subscriptions: 101,444',
#   'Telephones - mobile cellular:': 'total subscriptions: 13,438,539',
#   'Internet users:': 'total: 3,956,252',
#   'Land boundaries:': 'border countries (8): Angola 1,065 km, Botswana 0.15 km, Democratic Republic of the Congo 2,332 km, Malawi 847 km, Mozambique 439 km, Namibia 244 km, Tanzania 353 km, Zimbabwe 763 km',
#   'Geographic coordinates:': '15 00 S, 30 00 E',
#   'Country': ' Zambia '},
#  {'GDP - per capita \\(PPP\\):': '$2,300 (2017 est.)',
#   'Industrial production growth rate:': '2.1% (2017 est.)',
#   'Labor force:': '7.907 million (2017 est.)',
#   'Unemployment rate:': '11.3% (2014 est.)',
#   'Population below poverty line:': '72.3% (2012 est.)',
#   'Distribution of family income - Gini index:': '43.2 (2011 est.)',
#   'Public debt:': '75.5% of GDP (2017 est.)',
#   'Inflation': '1.3% (2017 est.)',
#   'Current account balance:': '-$455 million (2017 est.)',
#   'Exports:': '$3.763 billion (2017 est.)',
#   'Imports:': '$5.605 billion (2017 est.)',
#   'Reserves of foreign exchange and gold:': '$374 million (31 December 2017 est.)',
#   'Exchange rates:': '1 (2017 est.)',
#   'GDP - composition, by sector of origin:': ['agriculture: 12.5%',
#    'industry: 26.9%',
#    'services: 60.6% (2017 est.)'],
#   'GDP - composition, by end use:': ['household consumption: 84%',
#    'government consumption: 20.5%',
#    'investment in fixed capital: 13.8%',
#    'investment in inventories: 0%',
#    'exports of goods and services: 26.4%',
#    'imports of goods and services: -44.9% (2017 est.)'],
#   'Population:': '13,805,084',
#   'Population growth rate:': '1.56% (2017 est.)',
#   'Urbanization:': 'urban population: 32.2% of total population (2018)',
#   'Infant mortality rate:': 'total: 32.7 deaths/1,000 live births',
#   'Education expenditures:': '8.4% of GDP (2014)',
#   'Literacy:': 'definition: age 15 and over can read and write English',
#   'Telephones - fixed lines:': 'total subscriptions: 264,150',
#   'Telephones - mobile cellular:': 'total subscriptions: 14,092,104',
#   'Internet users:': 'total: 3,363,256',
#   'Land boundaries:': 'border countries (4): Botswana 834 km, Mozambique 1,402 km, South Africa 230 km, Zambia 763 km',
#   'Geographic coordinates:': '20 00 S, 30 00 E',
#   'Country': ' Zimbabwe '},
#  {'GDP - per capita \\(PPP\\):': '$40,900 (2017 est.)',
#   'Industrial production growth rate:': '1.9% (2017 est.)',
#   'Labor force:': '238.9 million (2016 est.)',
#   'Unemployment rate:': '8.6% (2016 est.)',
#   'Population below poverty line:': '9.8%',
#   'Distribution of family income - Gini index:': '30.8 (2016 est.)',
#   'Public debt:': '86.8% of GDP (2014)',
#   'Inflation': '1.5% (2017 est.)',
#   'Current account balance:': '$404.9 billion (2017 est.)',
#   'Exports:': '$1.929 trillion (2016 est.)',
#   'Imports:': '$1.895 trillion (2016 est.)',
#   'Reserves of foreign exchange and gold:': '$740.9 billion (31 December 2014 est.)',
#   'Exchange rates:': '0.89 (2017 est.)',
#   'GDP - composition, by sector of origin:': ['agriculture: 1.6%',
#    'industry: 24.7%',
#    'services: 70.7% (2017 est.)'],
#   'GDP - composition, by end use:': ['household consumption: 54.4%',
#    'government consumption: 20.4%',
#    'investment in fixed capital: 19.8%',
#    'investment in inventories: 0.4%',
#    'exports of goods and services: 43.9%',
#    'imports of goods and services: -40.5% (2016 est.)'],
#   'Population:': 'total: 516,195,432',
#   'Population growth rate:': '0.21% (2017 est.)',
#   'Urbanization:': nan,
#   'Infant mortality rate:': 'total: 4 deaths/1,000 live births',
#   'Education expenditures:': nan,
#   'Literacy:': nan,
#   'Telephones - fixed lines:': 'total: 210,621,546',
#   'Telephones - mobile cellular:': 'total subscriptions: 625,000,799',
#   'Internet users:': 'total: 398.1 million (July 2016 est.)',
#   'Land boundaries:': 'border countries (17): Albania 212 km, Andorra 118 km, Belarus 1,176 km, Bosnia and Herzegovina 956 km, Holy See 3 km, Liechtenstein 34 km, Macedonia 396 km, Moldova 683 km, Monaco 6 km, Montenegro 19 km, Norway 2,375 km, Russia 2,435 km, San Marino 37 km, Serbia 1,353 km, Switzerland 1,729 km, Turkey 415 km, Ukraine 1,324 km',
#   'Geographic coordinates:': nan,
#   'Country': ' European Union '}]

# %%
# Convert country_metrics to DataFrame
df = pd.DataFrame(country_metrics)

# Drop some columns which we are not interested in. These were qualitative decisions.
df = df.drop(columns = ["Distribution of family income - Gini index:",\
                        "Population growth rate:", 'Exchange rates:',\
                        'Literacy:', \
                        'Reserves of foreign exchange and gold:',\
                        'Current account balance:',\
                        'Industrial production growth rate:',\
                        'Labor force:',\
                        'GDP - composition, by end use:','Inflation'])

# drop columns with too many nan's
df=df.dropna(thresh=10)
df.head()
# Out:
#             Country Education expenditures:                    Exports:  \
# 0      Afghanistan       3.2% of GDP (2015)    $784 million (2017 est.)
# 2          Albania       3.5% of GDP (2015)  $960.9 million (2017 est.)
# 3          Algeria       4.3% of GDP (2008)  $33.15 billion (2017 est.)
# 4   American Samoa                       NA    $428 million (2016 est.)
# 5          Andorra       3.3% of GDP (2016)  $78.71 million (2015 est.)
#
#              GDP - composition, by sector of origin:  \
# 0  [agriculture: 23%, industry: 21.1%, services: ...
# 2  [agriculture: 22.6%, industry: 23.8%, services...
# 3  [agriculture: 13.2%, industry: 36.1%, services...
# 4  [agriculture: 27.4%, industry: 12.4%, services...
# 5  [agriculture: 11.9%, industry: 33.6%, services...
#
#   GDP - per capita \(PPP\): Geographic coordinates:  \
# 0        $2,000 (2017 est.)        33 00 N, 65 00 E
# 2       $12,500 (2017 est.)        41 00 N, 20 00 E
# 3       $15,200 (2017 est.)         28 00 N, 3 00 E
# 4       $11,200 (2016 est.)       14 20 S, 170 00 W
# 5       $49,900 (2015 est.)         42 30 N, 1 30 E
#
#                      Imports:                 Infant mortality rate:  \
# 0  $7.616 billion (2017 est.)  total: 110.6 deaths/1,000 live births
# 2  $4.084 billion (2017 est.)   total: 11.9 deaths/1,000 live births
# 3  $49.99 billion (2017 est.)   total: 19.6 deaths/1,000 live births
# 4    $615 million (2016 est.)   total: 11.3 deaths/1,000 live births
# 5  $1.257 billion (2015 est.)    total: 3.6 deaths/1,000 live births
#
#      Internet users:                                   Land boundaries:  \
# 0   total: 3,531,770  border countries (6): China 91 km, Iran 921 km...
# 2   total: 2,016,516  border countries (4): Greece 212 km, Kosovo 11...
# 3  total: 17,291,463  border countries (7): Libya 989 km, Mali 1,359...
# 4      total: 17,000                                         Coastline:
# 5      total: 83,887    border countries (2): France 55 km, Spain 63 km
#
#   Population below poverty line:                  Population:  \
# 0              54.5% (2017 est.)  34,124,811 (July 2017 est.)
# 2              14.3% (2012 est.)   3,047,987 (July 2017 est.)
# 3                23% (2006 est.)  40,969,443 (July 2017 est.)
# 4                            NA%      51,504 (July 2017 est.)
# 5                            NA%      76,965 (July 2017 est.)
#
#                Public debt:       Telephones - fixed lines:  \
# 0   7.3% of GDP (2017 est.)    total subscriptions: 118,769
# 2  71.2% of GDP (2017 est.)    total subscriptions: 247,010
# 3  25.8% of GDP (2017 est.)  total subscriptions: 3,130,090
# 4  12.2% of GDP (2016 est.)     total subscriptions: 10,000
# 5    41% of GDP (2014 est.)     total subscriptions: 38,411
#
#      Telephones - mobile cellular: Unemployment rate:  \
# 0  total subscriptions: 23,929,713  23.9% (2017 est.)
# 2   total subscriptions: 3,497,950    14% (2017 est.)
# 3  total subscriptions: 49,873,389  11.7% (2017 est.)
# 4                              NaN       29.8% (2005)
# 5      total subscriptions: 80,337   3.7% (2016 est.)
#
#                                        Urbanization:
# 0  urban population: 25.5% of total population (2...
# 2  urban population: 60.3% of total population (2...
# 3  urban population: 72.6% of total population (2...
# 4  urban population: 87.2% of total population (2...
# 5  urban population: 88.1% of total population (2...

# %%
# Rename columns 

df = df.rename(index=str, columns={'Education expenditures:': "education_exp", \
                              'Unemployment rate:': "unemp_rate", \
                              'Population below poverty line:': "pop_below_pov", \
                              'Inflation':'inflation',\
                              'Population:':'population', \
                              'Exports:':'exports', \
                              'Imports:':'imports', \
                              'Public debt:':'public_debt', \
                              "GDP - per capita \(PPP\):":"gdp_per_capita",\
                              'Infant mortality rate:':'infant_mortality', \
                              'Urbanization:':'urbanization', \
                              'Telephones - fixed lines:':'tel_fixed', \
                              'Telephones - mobile cellular:':'tel_cell', \
                              'Internet users:':'internet_users', \
                              'GDP - composition, by sector of origin:':'gdp_comp', \
                                  'Land boundaries:' : 'land_boundaries', \
                                  'Geographic coordinates:' : 'geo_coords'})


# Cleaning
df['education_exp'] = df['education_exp'].str.replace('%.*','')
df['unemp_rate'] = df['unemp_rate'].str.replace('%.*','')
df['public_debt'] = df['public_debt'].str.replace('%.*','').str.extract(r'([0123456789.]+)')
df['pop_below_pov'] = df['pop_below_pov'].str.replace('%.*','')
df['tel_cell'] = df['tel_cell'].str.replace(',','').str.extract(r'([\d]+)')
df['tel_fixed'] = df['tel_fixed'].str.replace(',','').str.extract(r'([\d]+)')
df['internet_users'] = df['internet_users'].str.replace(',','').str.extract(r'([\d]+)')

# Chaning NA to np.nan
df['education_exp'] = df['education_exp'].replace('NA',np.nan)
df['unemp_rate'] = df['unemp_rate'].replace('NA',np.nan)
df['pop_below_pov'] = df['pop_below_pov'].replace('NA',np.nan)

# Removing end date and commas in population
df['population'] = df['population'].str.replace('\(.*','').str.replace(',','').str.extract(r'([0123456789.]+)')
df['population'] = df['population'].replace('NA',np.nan)


# Getting rid of end dates and millions and billions
df['exports'] = df['exports'].str.replace('\(.*','').str.replace(',','')
df['imports'] = df['imports'].str.replace('\(.*','').str.replace(',','')

df["gdp_per_capita"] = df["gdp_per_capita"].str.replace('\(.*','').str.replace(',','')
df["gdp_per_capita"] = df["gdp_per_capita"].str.extract(r'(\d+)')
df["gdp_per_capita"] = df["gdp_per_capita"].replace('NA',np.nan)


# Convert strings 'millions' and 'billions' and 'trillions' to numerical millions

powers = {'billion': 10 ** 9, 'million': 10 ** 6, 'trillion' : 10 **12 , 'NaN' : 1}

def convert_millions(metric):
    extracted = metric.str.extract(r'([1234567890.]+)\s(\w+)')
    extracted.iloc[:, 1] = extracted.iloc[:, 1].map(powers).astype('float')
    out = extracted.iloc[:, 1]*extracted.iloc[:, 0].astype('float')
    return out
    
df['exports'] = convert_millions(df['exports'])
df['imports'] = convert_millions(df['imports'])

df
# Out:
#                         Country education_exp       exports  \
# 0                  Afghanistan            3.2  7.840000e+08
# 2                      Albania            3.5  9.609000e+08
# 3                      Algeria            4.3  3.315000e+10
# 4               American Samoa            NaN  4.280000e+08
# 5                      Andorra            3.3  7.871000e+07
# 6                       Angola            3.5  3.382000e+10
# 7                     Anguilla            2.8  4.200000e+06
# 9          Antigua and Barbuda            2.5  6.130000e+07
# 11                   Argentina            5.9  5.969000e+10
# 12                     Armenia            2.8  2.233000e+09
# 13                       Aruba            6.5  2.463000e+08
# 16                   Australia            5.2  2.245000e+11
# 17                     Austria            5.4  1.618000e+11
# 18                  Azerbaijan              3  1.569000e+10
# 19                Bahamas, The            NaN  9.347000e+08
# 20                     Bahrain            2.7  1.433000e+10
# 22                  Bangladesh            2.5  3.591000e+10
# 23                    Barbados            5.1  4.825000e+08
# 24                     Belarus              5  2.420000e+10
# 25                     Belgium            6.6  3.091000e+11
# 26                      Belize            7.4  4.834000e+08
# 27                       Benin            4.4  1.760000e+09
# 28                     Bermuda            1.5  2.000000e+07
# 29                      Bhutan            7.4  5.800000e+08
# 30                     Bolivia            7.3  7.986000e+09
# 31      Bosnia and Herzegovina            NaN  4.803000e+09
# 32                    Botswana            9.6  7.580000e+09
# 34                      Brazil            5.9  2.172000e+11
# 36      British Virgin Islands            6.3  2.300000e+07
# 37                      Brunei            4.4  5.776000e+09
# ..                          ...           ...           ...
# 235                   Tanzania            3.5  5.194000e+09
# 236                   Thailand            4.1  2.282000e+11
# 237                Timor-Leste            7.5  2.000000e+07
# 238                       Togo            5.1  1.002000e+09
# 239                    Tokelau            NaN           NaN
# 240                      Tonga            NaN  1.820000e+07
# 241        Trinidad and Tobago            NaN  9.668000e+09
# 242                    Tunisia            6.6  1.422000e+10
# 243                     Turkey            4.4  1.573000e+11
# 244               Turkmenistan              3  7.394000e+09
# 245   Turks and Caicos Islands            3.3  2.477000e+07
# 246                     Tuvalu            NaN           NaN
# 247                     Uganda            2.3  2.902000e+09
# 248                    Ukraine            5.9  3.685000e+10
# 249       United Arab Emirates            NaN  3.147000e+11
# 250             United Kingdom            5.6  4.365000e+11
# 251              United States              5  1.576000e+12
# 253                    Uruguay            4.4  8.976000e+09
# 254                 Uzbekistan            NaN  1.138000e+10
# 255                    Vanuatu            5.5  4.390000e+07
# 256                  Venezuela            6.9  2.916000e+10
# 257                    Vietnam            5.7  2.140000e+11
# 258             Virgin Islands            NaN  1.810000e+09
# 260          Wallis and Futuna            NaN           NaN
# 261                  West Bank            5.7  1.955000e+09
# 262             Western Sahara            NaN           NaN
# 263                      Yemen            4.6  5.012000e+08
# 264                     Zambia            1.1  8.106000e+09
# 265                   Zimbabwe            8.4  3.763000e+09
# 266             European Union            NaN  1.929000e+12
#
#                                               gdp_comp gdp_per_capita  \
# 0    [agriculture: 23%, industry: 21.1%, services: ...           2000
# 2    [agriculture: 22.6%, industry: 23.8%, services...          12500
# 3    [agriculture: 13.2%, industry: 36.1%, services...          15200
# 4    [agriculture: 27.4%, industry: 12.4%, services...          11200
# 5    [agriculture: 11.9%, industry: 33.6%, services...          49900
# 6    [agriculture: 10.2%, industry: 61.4%, services...           6800
# 7    [agriculture: 2.4%, industry: 21.3%, services:...          12200
# 9    [agriculture: 2.3%, industry: 20.2%, services:...          26300
# 11   [agriculture: 10.9%, industry: 28.2%, services...          20900
# 12   [agriculture: 17.7%, industry: 27.8%, services...           9500
# 13   [agriculture: 0.4%, industry: 33.3%, services:...          25300
# 16   [agriculture: 3.6%, industry: 26.1%, services:...          50300
# 17   [agriculture: 1.2%, industry: 28.4%, services:...          49900
# 18   [agriculture: 6.2%, industry: 49.1%, services:...          17500
# 19   [agriculture: 2.3%, industry: 7.7%, services: ...          31200
# 20   [agriculture: 0.3%, industry: 38.2%, services:...          48500
# 22   [agriculture: 14.2%, industry: 29.2%, services...           4200
# 23   [agriculture: 1.4%, industry: 4.8%, services: ...          18700
# 24   [agriculture: 8.3%, industry: 40.6%, services:...          18900
# 25   [agriculture: 0.7%, industry: 21.8%, services:...          46600
# 26   [agriculture: 9.7%, industry: 13.8%, services:...           8300
# 27   [agriculture: 25.6%, industry: 23.1%, services...           2300
# 28   [agriculture: 0.8%, industry: 5.8%, services: ...          99400
# 29   [agriculture: 15.7%, industry: 42.6%, services...           8700
# 30   [agriculture: 13%, industry: 37.4%, services: ...           7500
# 31   [agriculture: 7.8%, industry: 26.8%, services:...          12700
# 32   [agriculture: 1.7%, industry: 29.2%, services:...          17800
# 34   [agriculture: 6.2%, industry: 21%, services: 7...          15600
# 36   [agriculture: 1%, industry: 11.2%, services: 8...          34200
# 37   [agriculture: 1.2%, industry: 56.5%, services:...          78200
# ..                                                 ...            ...
# 235  [agriculture: 23.4%, industry: 28.6%, services...           3200
# 236  [agriculture: 8.2%, industry: 36.2%, services:...          17900
# 237  [agriculture: 9.4%, industry: 57.8%, services:...           5400
# 238  [agriculture: 28.1%, industry: 21.6%, services...           1700
# 239   [agriculture: NA%, industry: NA%, services: NA%]           1000
# 240  [agriculture: 19.5%, industry: 20.8%, services...           5600
# 241  [agriculture: 0.4%, industry: 48.8%, services:...          31400
# 242  [agriculture: 9.9%, industry: 25.6%, services:...          11800
# 243  [agriculture: 6.7%, industry: 31.8%, services:...          26900
# 244  [agriculture: 7.5%, industry: 44.9%, services:...          18100
# 245  [agriculture: 0.5%, industry: 8.9%, services: ...          29100
# 246  [agriculture: 24.5%, industry: 5.6%, services:...           3800
# 247  [agriculture: 25.8%, industry: 23.2%, services...           2400
# 248  [agriculture: 14%, industry: 27.8%, services: ...           8700
# 249  [agriculture: 0.9%, industry: 49.8%, services:...          67700
# 250  [agriculture: 0.6%, industry: 19%, services: 8...          44100
# 251  [agriculture: 0.9%, industry: 18.9%, services:...          59500
# 253  [agriculture: 6.2%, industry: 25%, services: 6...          22400
# 254  [agriculture: 18.5%, industry: 34.4%, services...           6900
# 255  [agriculture: 27%, industry: 9.1%, services: 6...           2700
# 256  [agriculture: 4.4%, industry: 38.2%, services:...          12100
# 257  [agriculture: 15.3%, industry: 33.3%, services...           6900
# 258  [agriculture: 2%, industry: 20%, services: 78%...          37000
# 260   [agriculture: NA%, industry: NA%, services: NA%]           3800
# 261  [agriculture: 3%, industry: 21.1%, services: 75%]           4300
# 262  [agriculture: NA%, industry: NA%, services: 40...           2500
# 263  [agriculture: 24.1%, industry: 14.3%, services...           1300
# 264  [agriculture: 5.4%, industry: 35.6%, services:...           4000
# 265  [agriculture: 12.5%, industry: 26.9%, services...           2300
# 266  [agriculture: 1.6%, industry: 24.7%, services:...          40900
#
#             geo_coords       imports                       infant_mortality  \
# 0     33 00 N, 65 00 E  7.616000e+09  total: 110.6 deaths/1,000 live births
# 2     41 00 N, 20 00 E  4.084000e+09   total: 11.9 deaths/1,000 live births
# 3      28 00 N, 3 00 E  4.999000e+10   total: 19.6 deaths/1,000 live births
# 4    14 20 S, 170 00 W  6.150000e+08   total: 11.3 deaths/1,000 live births
# 5      42 30 N, 1 30 E  1.257000e+09    total: 3.6 deaths/1,000 live births
# 6     12 30 S, 18 30 E  2.300000e+10   total: 67.6 deaths/1,000 live births
# 7     18 15 N, 63 10 W  1.111000e+08    total: 3.3 deaths/1,000 live births
# 9     17 03 N, 61 48 W  4.207000e+08   total: 12.1 deaths/1,000 live births
# 11    34 00 S, 64 00 W  6.078000e+10    total: 9.8 deaths/1,000 live births
# 12    40 00 N, 45 00 E  3.361000e+09   total: 12.7 deaths/1,000 live births
# 13    12 30 N, 69 58 W  1.165000e+09   total: 10.7 deaths/1,000 live births
# 16   27 00 S, 133 00 E  2.154000e+11    total: 4.3 deaths/1,000 live births
# 17    47 20 N, 13 20 E  1.683000e+11    total: 3.4 deaths/1,000 live births
# 18    40 30 N, 47 30 E  8.734000e+09   total: 23.8 deaths/1,000 live births
# 19    24 15 N, 76 00 W  3.105000e+09   total: 11.3 deaths/1,000 live births
# 20    26 00 N, 50 33 E  1.396000e+10    total: 8.9 deaths/1,000 live births
# 22    24 00 N, 90 00 E  4.238000e+10   total: 31.7 deaths/1,000 live births
# 23    13 10 N, 59 32 W  1.515000e+09   total: 10.2 deaths/1,000 live births
# 24    53 00 N, 28 00 E  2.620000e+10    total: 3.6 deaths/1,000 live births
# 25     50 50 N, 4 00 E  3.061000e+11    total: 3.4 deaths/1,000 live births
# 26    17 15 N, 88 45 W  9.444000e+08   total: 18.9 deaths/1,000 live births
# 27      9 30 N, 2 15 E  2.448000e+09   total: 52.8 deaths/1,000 live births
# 28    32 20 N, 64 45 W  9.795000e+08    total: 2.5 deaths/1,000 live births
# 29    27 30 N, 90 30 E  1.100000e+09   total: 32.1 deaths/1,000 live births
# 30    17 00 S, 65 00 W  9.288000e+09   total: 35.3 deaths/1,000 live births
# 31    44 00 N, 18 00 E  9.113000e+09    total: 5.5 deaths/1,000 live births
# 32    22 00 S, 24 00 E  5.998000e+09   total: 29.6 deaths/1,000 live births
# 34    10 00 S, 55 00 W  1.532000e+11   total: 17.5 deaths/1,000 live births
# 36    18 30 N, 64 30 W           NaN   total: 12.1 deaths/1,000 live births
# 37    4 30 N, 114 40 E  3.275000e+09    total: 9.6 deaths/1,000 live births
# ..                 ...           ...                                    ...
# 235    6 00 S, 35 00 E  8.610000e+09   total: 39.9 deaths/1,000 live births
# 236  15 00 N, 100 00 E  1.900000e+11    total: 9.2 deaths/1,000 live births
# 237   8 50 S, 125 55 E  5.586000e+08   total: 35.1 deaths/1,000 live births
# 238     8 00 N, 1 10 E  2.009000e+09   total: 42.2 deaths/1,000 live births
# 239   9 00 S, 172 00 W           NaN                              total: NA
# 240  20 00 S, 175 00 W  3.207000e+08   total: 11.3 deaths/1,000 live births
# 241   11 00 N, 61 00 W  1.019000e+10   total: 22.3 deaths/1,000 live births
# 242    34 00 N, 9 00 E  2.333000e+10   total: 12.1 deaths/1,000 live births
# 243   39 00 N, 35 00 E  1.968000e+11   total: 17.6 deaths/1,000 live births
# 244   40 00 N, 60 00 E  4.801000e+09   total: 34.3 deaths/1,000 live births
# 245   21 45 N, 71 35 W  5.913000e+08   total: 10.1 deaths/1,000 live births
# 246   8 00 S, 178 00 E  1.365000e+08     total: 29 deaths/1,000 live births
# 247    1 00 N, 32 00 E  4.592000e+09   total: 56.1 deaths/1,000 live births
# 248   49 00 N, 32 00 E  4.442000e+10    total: 7.8 deaths/1,000 live births
# 249   24 00 N, 54 00 E  2.413000e+11     total: 10 deaths/1,000 live births
# 250    54 00 N, 2 00 W  6.025000e+11    total: 4.3 deaths/1,000 live births
# 251   38 00 N, 97 00 W  2.352000e+12    total: 5.8 deaths/1,000 live births
# 253   33 00 S, 56 00 W  8.740000e+09    total: 8.3 deaths/1,000 live births
# 254   41 00 N, 64 00 E  1.144000e+10     total: 18 deaths/1,000 live births
# 255  16 00 S, 167 00 E  2.499000e+08   total: 14.4 deaths/1,000 live births
# 256    8 00 N, 66 00 W  1.775000e+10   total: 12.2 deaths/1,000 live births
# 257  16 10 N, 107 50 E  2.111000e+11   total: 17.3 deaths/1,000 live births
# 258   18 20 N, 64 50 W  2.489000e+09    total: 7.9 deaths/1,000 live births
# 260  13 18 S, 176 12 W  6.117000e+07    total: 4.3 deaths/1,000 live births
# 261   32 00 N, 35 15 E  6.476000e+09   total: 14.1 deaths/1,000 live births
# 262   24 30 N, 13 00 W           NaN   total: 51.9 deaths/1,000 live births
# 263   15 00 N, 48 00 E  4.573000e+09     total: 46 deaths/1,000 live births
# 264   15 00 S, 30 00 E  7.336000e+09   total: 61.1 deaths/1,000 live births
# 265   20 00 S, 30 00 E  5.605000e+09   total: 32.7 deaths/1,000 live births
# 266                NaN  1.895000e+12      total: 4 deaths/1,000 live births
#
#     internet_users                                    land_boundaries  \
# 0          3531770  border countries (6): China 91 km, Iran 921 km...
# 2          2016516  border countries (4): Greece 212 km, Kosovo 11...
# 3         17291463  border countries (7): Libya 989 km, Mali 1,359...
# 4            17000                                         Coastline:
# 5            83887    border countries (2): France 55 km, Spain 63 km
# 6          2622403  border countries (4): Democratic Republic of t...
# 7            13665                                         Coastline:
# 9            60000                                         Coastline:
# 11        30786889  border countries (5): Bolivia 942 km, Brazil 1...
# 12         1891775  border countries (4): Azerbaijan 996 km, Georg...
# 13          106309                                         Coastline:
# 16        20288409                                         Coastline:
# 17         7346055  border countries (8): Czech Republic 402 km, G...
# 18         7720502  border countries (5): Armenia 996 km, Georgia ...
# 19          261853                                         Coastline:
# 20         1351326                                         Coastline:
# 22        28499324  border countries (2): Burma 271 km, India 4,14...
# 23          231883                                         Coastline:
# 24         6805786  border countries (5): Latvia 161 km, Lithuania...
# 25         9870734  border countries (4): France 556 km, Germany 1...
# 26          157735  border countries (2): Guatemala 266 km, Mexico...
# 27         1288336  border countries (4): Burkina Faso 386 km, Nig...
# 28           69126                                         Coastline:
# 29          313347   border countries (2): China 477 km, India 659 km
# 30         4354678  border countries (5): Argentina 942 km, Brazil...
# 31         2677502  border countries (3): Croatia 956 km, Monteneg...
# 32          869610  border countries (4): Namibia 1,544 km, South ...
# 34       122841218  border countries (10): Argentina 1,263 km, Bol...
# 36           14600                                         Coastline:
# 37          306000              border countries (1): Malaysia 266 km
# ..             ...                                                ...
# 235        6822754  border countries (8): Burundi 589 km, Democrat...
# 236       32398778  border countries (4): Burma 2,416 km, Cambodia...
# 237         318373             border countries (1): Indonesia 253 km
# 238         877310  border countries (3): Benin 651 km, Burkina Fa...
# 239            805                                         Coastline:
# 240          42552                                         Coastline:
# 241         846000                                         Coastline:
# 242        5665242  border countries (2): Algeria 1,034 km, Libya ...
# 243       46838412  border countries (8): Armenia 311 km, Azerbaij...
# 244         951925  border countries (4): Afghanistan 804 km, Iran...
# 245            NaN                                         Coastline:
# 246           5042                                         Coastline:
# 247       18148923  border countries (5): Democratic Republic of t...
# 248       23202067  border countries (7): Belarus 1,111 km, Hungar...
# 249        5370299  border countries (2): Oman 609 km, Saudi Arabi...
# 250       61064454               border countries (1): Ireland 443 km
# 251      246809221  border countries (2): Canada 8,893 km (includi...
# 253        2225075  border countries (2): Argentina 541 km, Brazil...
# 254       13791083  border countries (5): Afghanistan 144 km, Kaza...
# 255          66613                                         Coastline:
# 256       18547381  border countries (3): Brazil 2,137 km, Colombi...
# 257             49  border countries (3): Cambodia 1,158 km, China...
# 258          57000                                         Coastline:
# 260           3450                                         Coastline:
# 261              2  border countries (2): Israel 330 km, Jordan 14...
# 262            NaN  border countries (3): Algeria 41 km, Mauritani...
# 263        6732928  border countries (2): Oman 294 km, Saudi Arabi...
# 264        3956252  border countries (8): Angola 1,065 km, Botswan...
# 265        3363256  border countries (4): Botswana 834 km, Mozambi...
# 266            398  border countries (17): Albania 212 km, Andorra...
#
#     pop_below_pov population public_debt  tel_fixed   tel_cell unemp_rate  \
# 0            54.5   34124811         7.3     118769   23929713       23.9
# 2            14.3    3047987        71.2     247010    3497950         14
# 3              23   40969443        25.8    3130090   49873389       11.7
# 4             NaN      51504        12.2      10000        NaN       29.8
# 5             NaN      76965          41      38411      80337        3.7
# 6            36.6   29310273        65.3     161070   13323952        6.6
# 7              23      17087        20.1       6000      26000          8
# 9             NaN      94731        86.8      22504     180000         11
# 11           25.7   44293293        52.6    9530349   61897379        8.1
# 12             32    3045191        53.5     505190    3488524       18.9
# 13            NaN     115120          67      35000     141000        6.9
# 16            NaN   23232413        41.6          8         27        5.6
# 17              3    8754413        78.8    3762801   14924340        5.5
# 18            4.9    9961396        54.7    1688325         10          6
# 19            9.3     329988        57.2     113852     353540         10
# 20            NaN    1410942        90.3     285318    2364477        3.8
# 22           24.3  157826578        32.4     710189  145113669          4
# 23            NaN     292336       132.9     139645     337791       10.5
# 24            5.7    9549747          51    4499821   10963224          1
# 25           15.1   11491346       103.2    4251564   11961089        7.3
# 26             41     360346          99      23000     227000       10.1
# 27           36.2   11038805        54.6      56787    8773044          1
# 28             11      70864          43      21883      64997          7
# 29             12     758288       102.4      21364     730623        3.2
# 30           38.6   11138234        50.9     851110   10106216          4
# 31           16.9    3856181          41     759344    3440085       20.5
# 32           19.3    2214858        15.6     141207    3240589         20
# 34            4.2  207353391          84   40878018  236488548       11.8
# 36            NaN      35015         NaN      10004      42000        2.9
# 37            NaN     443593         2.7      74213     544732        6.9
# ..            ...        ...         ...        ...        ...        ...
# 235          22.8   53950935        38.2     127094   39953860       10.3
# 236           7.2   68414135        41.9          2        121        0.7
# 237          41.8    1291358           0       2364    1546624        4.4
# 238          55.1    7965055        78.6      36111    6219981        6.9
# 239           NaN       1285         NaN        300        NaN        NaN
# 240          22.5     106479          48      11000      80000        1.1
# 241            20    1218208        41.3     257445    2030637        4.5
# 242          15.5   11403800        71.3    1113168   14334080       15.9
# 243          21.9   80845215        28.5   11308444   77800170       11.2
# 244           0.2    5351277        28.8     665000          8         11
# 245           NaN      52570         NaN        NaN        NaN         10
# 246          26.3      11052        49.2       2000       7600        NaN
# 247          21.4   39570125          39     262286   24948878        9.4
# 248           3.8   44033874        75.6    7186579   55714733        9.5
# 249          19.5    6072475        19.5    2320837   19826224        1.6
# 250            15   65648100          87   33140662   79173658        4.4
# 251          15.1  326625791        82.3        119        395        4.4
# 253           9.7    3360148        66.2    1136977    5097569        7.3
# 254            14   29748859        24.5    3444330   24265460        4.9
# 255           NaN     282814        48.4       3499     228016        1.7
# 256          19.7   31304016        34.9    5928714   24493687       26.4
# 257             8   96160163        58.2    4526077  120016181        2.2
# 258          28.9     107268        53.3      76000        NaN       10.4
# 260           NaN      15714         5.6       3132        NaN        8.8
# 261            18    2747943        24.4     472293    4135363       26.7
# 262           NaN     603253         NaN        NaN        NaN        NaN
# 263            54   28036829       135.5    1165828   16433055         27
# 264          54.4   15972001        62.8     101444   13438539         15
# 265          72.3   13805084        75.5     264150   14092104       11.3
# 266           9.8  516195432        86.8  210621546  625000799        8.6
#
#                                           urbanization
# 0    urban population: 25.5% of total population (2...
# 2    urban population: 60.3% of total population (2...
# 3    urban population: 72.6% of total population (2...
# 4    urban population: 87.2% of total population (2...
# 5    urban population: 88.1% of total population (2...
# 6    urban population: 65.5% of total population (2...
# 7    urban population: 100% of total population (2018)
# 9    urban population: 24.6% of total population (2...
# 11   urban population: 91.9% of total population (2...
# 12   urban population: 63.1% of total population (2...
# 13   urban population: 43.4% of total population (2...
# 16    urban population: 86% of total population (2018)
# 17   urban population: 58.3% of total population (2...
# 18   urban population: 55.7% of total population (2...
# 19    urban population: 83% of total population (2018)
# 20   urban population: 89.3% of total population (2...
# 22   urban population: 36.6% of total population (2...
# 23   urban population: 31.1% of total population (2...
# 24   urban population: 78.6% of total population (2...
# 25    urban population: 98% of total population (2018)
# 26   urban population: 45.7% of total population (2...
# 27   urban population: 47.3% of total population (2...
# 28   urban population: 100% of total population (2018)
# 29   urban population: 40.9% of total population (2...
# 30   urban population: 69.4% of total population (2...
# 31   urban population: 48.2% of total population (2...
# 32   urban population: 69.4% of total population (2...
# 34   urban population: 86.6% of total population (2...
# 36   urban population: 47.7% of total population (2...
# 37   urban population: 77.6% of total population (2...
# ..                                                 ...
# 235  urban population: 33.8% of total population (2...
# 236  urban population: 49.9% of total population (2...
# 237  urban population: 30.6% of total population (2...
# 238  urban population: 41.7% of total population (2...
# 239    urban population: 0% of total population (2018)
# 240  urban population: 23.1% of total population (2...
# 241  urban population: 53.2% of total population (2...
# 242  urban population: 68.9% of total population (2...
# 243  urban population: 75.1% of total population (2...
# 244  urban population: 51.6% of total population (2...
# 245  urban population: 93.1% of total population (2...
# 246  urban population: 62.4% of total population (2...
# 247  urban population: 23.8% of total population (2...
# 248  urban population: 69.4% of total population (2...
# 249  urban population: 86.5% of total population (2...
# 250  urban population: 83.4% of total population (2...
# 251  urban population: 82.3% of total population (2...
# 253  urban population: 95.3% of total population (2...
# 254  urban population: 50.5% of total population (2...
# 255  urban population: 25.3% of total population (2...
# 256  urban population: 88.2% of total population (2...
# 257  urban population: 35.9% of total population (2...
# 258  urban population: 95.7% of total population (2...
# 260    urban population: 0% of total population (2018)
# 261  urban population: 76.2% of total population (2...
# 262  urban population: 86.7% of total population (2...
# 263  urban population: 36.6% of total population (2...
# 264  urban population: 43.5% of total population (2...
# 265  urban population: 32.2% of total population (2...
# 266                                                NaN
#
# [229 rows x 17 columns]

# %%
# Cleaning infant mortality

def convert_infant_mortality(metric):
    extracted = metric.str.extract(r'([1234567890.]+)\D+([1234567890,]+)')
    extracted.iloc[:, 1] = extracted.iloc[:, 1].str.replace(',','')
    out = extracted.iloc[:, 0].astype('float')/extracted.iloc[:, 1].astype('float')                                  
    return out

df['infant_mortality'] = convert_infant_mortality(df['infant_mortality'])

# %%
# Set country to the index and remove whitespace

df = df.set_index('Country')
df.index = df.index.map(str.strip)

# %%
# Seperate GDP compositions agriculture, industry and services into 3 different columns/features.

gdp_comp_list = df['gdp_comp'].values.tolist()

for i,v in enumerate(gdp_comp_list):
    if isinstance(v, (float,)):
        gdp_comp_list[i] = [np.nan]*3

df[['agr','ind','ser']] = pd.DataFrame(gdp_comp_list, index= df.index)
df = df.drop(columns = 'gdp_comp')    

df['urbanization'] = df['urbanization'].str.extract(r'([0123456789.]+)')
df['agr'] = df['agr'].str.extract(r'([0123456789.]+)')
df['ind'] = df['ind'].str.extract(r'([0123456789.]+)')
df['ser'] = df['ser'].str.extract(r'([0123456789.]+)')
df.head()
# Out:
#                education_exp       exports gdp_per_capita         geo_coords  \
# Country
# Afghanistan              3.2  7.840000e+08           2000   33 00 N, 65 00 E
# Albania                  3.5  9.609000e+08          12500   41 00 N, 20 00 E
# Algeria                  4.3  3.315000e+10          15200    28 00 N, 3 00 E
# American Samoa           NaN  4.280000e+08          11200  14 20 S, 170 00 W
# Andorra                  3.3  7.871000e+07          49900    42 30 N, 1 30 E
#
#                      imports  infant_mortality internet_users  \
# Country
# Afghanistan     7.616000e+09            0.1106        3531770
# Albania         4.084000e+09            0.0119        2016516
# Algeria         4.999000e+10            0.0196       17291463
# American Samoa  6.150000e+08            0.0113          17000
# Andorra         1.257000e+09            0.0036          83887
#
#                                                   land_boundaries  \
# Country
# Afghanistan     border countries (6): China 91 km, Iran 921 km...
# Albania         border countries (4): Greece 212 km, Kosovo 11...
# Algeria         border countries (7): Libya 989 km, Mali 1,359...
# American Samoa                                         Coastline:
# Andorra           border countries (2): France 55 km, Spain 63 km
#
#                pop_below_pov population public_debt tel_fixed  tel_cell  \
# Country
# Afghanistan             54.5   34124811         7.3    118769  23929713
# Albania                 14.3    3047987        71.2    247010   3497950
# Algeria                   23   40969443        25.8   3130090  49873389
# American Samoa           NaN      51504        12.2     10000       NaN
# Andorra                  NaN      76965          41     38411     80337
#
#                unemp_rate urbanization   agr   ind   ser
# Country
# Afghanistan          23.9         25.5    23  21.1  55.9
# Albania                14         60.3  22.6  23.8  53.7
# Algeria              11.7         72.6  13.2  36.1  50.7
# American Samoa       29.8         87.2  27.4  12.4  60.2
# Andorra               3.7         88.1  11.9  33.6  54.5

# %%
# Cleaning up bordering countries column

df['land_boundaries'] = df['land_boundaries'].str.replace(r'Coastline:','')
df['land_boundaries'] = df['land_boundaries'].str.extract(r'\:(.*)')
df['land_boundaries'] = df['land_boundaries'].str.replace(r'([0-9])','')
df['land_boundaries'] = df['land_boundaries'].str.replace(r'( km)','')
df['land_boundaries'] = df['land_boundaries'].str.replace(r'(,)','')
df['land_boundaries'] = df['land_boundaries'].str.replace(r'(\.)','')
df['land_boundaries'] = df['land_boundaries'].str.replace(r'\([^)]*\)','')
df['land_boundaries'] = df['land_boundaries'].str.split('  ')
    

df['land_boundaries']
# Out:
# Country
# Afghanistan                 [ China, Iran, Pakistan, Tajikistan, Turkmenis...
# Albania                             [ Greece, Kosovo, Macedonia, Montenegro ]
# Algeria                     [ Libya, Mali, Mauritania, Morocco, Niger, Tun...
# American Samoa                                                            NaN
# Andorra                                                     [ France, Spain ]
# Angola                      [ Democratic Republic of the Congo,  Republic ...
# Anguilla                                                                  NaN
# Antigua and Barbuda                                                       NaN
# Argentina                       [ Bolivia, Brazil, Chile, Paraguay, Uruguay ]
# Armenia                                 [ Azerbaijan, Georgia, Iran, Turkey ]
# Aruba                                                                     NaN
# Australia                                                                 NaN
# Austria                     [ Czech Republic, Germany, Hungary, Italy, Lie...
# Azerbaijan                         [ Armenia, Georgia, Iran, Russia, Turkey ]
# Bahamas, The                                                              NaN
# Bahrain                                                                   NaN
# Bangladesh                                                   [ Burma, India ]
# Barbados                                                                  NaN
# Belarus                        [ Latvia, Lithuania, Poland, Russia, Ukraine ]
# Belgium                          [ France, Germany, Luxembourg, Netherlands ]
# Belize                                                  [ Guatemala, Mexico ]
# Benin                                  [ Burkina Faso, Niger, Nigeria, Togo ]
# Bermuda                                                                   NaN
# Bhutan                                                       [ China, India ]
# Bolivia                          [ Argentina, Brazil, Chile, Paraguay, Peru ]
# Bosnia and Herzegovina                        [ Croatia, Montenegro, Serbia ]
# Botswana                          [ Namibia, South Africa, Zambia, Zimbabwe ]
# Brazil                      [ Argentina, Bolivia, Colombia, French Guiana,...
# British Virgin Islands                                                    NaN
# Brunei                                                           [ Malaysia ]
#                                                   ...
# Tanzania                    [ Burundi, Democratic Republic of the Congo, K...
# Thailand                                  [ Burma, Cambodia, Laos, Malaysia ]
# Timor-Leste                                                     [ Indonesia ]
# Togo                                           [ Benin, Burkina Faso, Ghana ]
# Tokelau                                                                   NaN
# Tonga                                                                     NaN
# Trinidad and Tobago                                                       NaN
# Tunisia                                                    [ Algeria, Libya ]
# Turkey                      [ Armenia, Azerbaijan, Bulgaria, Georgia, Gree...
# Turkmenistan                    [ Afghanistan, Iran, Kazakhstan, Uzbekistan ]
# Turks and Caicos Islands                                                  NaN
# Tuvalu                                                                    NaN
# Uganda                      [ Democratic Republic of the Congo, Kenya, Rwa...
# Ukraine                     [ Belarus, Hungary, Moldova, Poland, Romania, ...
# United Arab Emirates                                   [ Oman, Saudi Arabia ]
# United Kingdom                                                    [ Ireland ]
# United States                                             [ Canada,  Mexico ]
# Uruguay                                                 [ Argentina, Brazil ]
# Uzbekistan                  [ Afghanistan, Kazakhstan, Kyrgyzstan, Tajikis...
# Vanuatu                                                                   NaN
# Venezuela                                        [ Brazil, Colombia, Guyana ]
# Vietnam                                             [ Cambodia, China, Laos ]
# Virgin Islands                                                            NaN
# Wallis and Futuna                                                         NaN
# West Bank                                                  [ Israel, Jordan ]
# Western Sahara                               [ Algeria, Mauritania, Morocco ]
# Yemen                                                  [ Oman, Saudi Arabia ]
# Zambia                      [ Angola, Botswana, Democratic Republic of the...
# Zimbabwe                       [ Botswana, Mozambique, South Africa, Zambia ]
# European Union              [ Albania, Andorra, Belarus, Bosnia and Herzeg...
# Name: land_boundaries, Length: 229, dtype: object

# %%
# This function returns the sum of internet users in all of the bordering countries

def get_surrounding_internet(countries):
    internet_numbers = []
    
    if isinstance(countries, float):
        return np.nan      
    elif isinstance(countries, str):
        return countries
    else:
        for i in countries:
            i = i.strip()
            try:
                internet_numbers.append(float(df['internet_users'][i]))
            except KeyError:
                internet_numbers.append(0)
        return sum(internet_numbers)

# %%
# This function returns the sum of the populations of all bordering countries.

def get_surrounding_pop(countries):
    pop_numbers = []
    
    if isinstance(countries, float):
        return np.nan      
    elif isinstance(countries, str):
        return countries
    else:
        for i in countries:
            i = i.strip()
            try:
                pop_numbers.append(float(df['population'][i]))
            except KeyError:
                pop_numbers.append(0)
        return sum(pop_numbers)

# %%
# Create new columns for total bordering internet users and population.

df['bordering_internet'] = df['land_boundaries'].apply(lambda x:get_surrounding_internet(x))
df['bordering_pop'] = df['land_boundaries'].apply(lambda x:get_surrounding_pop(x))

# %%
# Create new columns to store geographic coordinates.

df['NS'] = df['geo_coords'].str.replace(',.*','')
df['EW'] = df['geo_coords'].str.replace('.*,','')

# %%
# This function cleans up the coordinates.

def get_coords(coords): 
    i = 1
    try :
        if coords[-1]=='S' or coords[-1]=='W':
            i = -1
        coords = coords[:-1].strip()
        coords = i*float(coords.replace(' ','.'))
        
    except (TypeError, ValueError):
        coords = np.nan
        
    return coords

# %%
# New columns for cleaned geocoordinates
df['NS_new'] = df['NS'].apply(lambda x:get_coords(x))
df['EW_new'] = df['EW'].apply(lambda x:get_coords(x))

# Scale bordering internet users by bordering population to get density
df['border_internet_scaled'] = df['bordering_internet']/df['bordering_pop']

# Drop columns we dont need
df = df.drop(columns = ['geo_coords','land_boundaries','NS', 'EW'])

df.head()
# Out:
#                education_exp       exports gdp_per_capita       imports  \
# Country
# Afghanistan              3.2  7.840000e+08           2000  7.616000e+09
# Albania                  3.5  9.609000e+08          12500  4.084000e+09
# Algeria                  4.3  3.315000e+10          15200  4.999000e+10
# American Samoa           NaN  4.280000e+08          11200  6.150000e+08
# Andorra                  3.3  7.871000e+07          49900  1.257000e+09
#
#                 infant_mortality internet_users pop_below_pov population  \
# Country
# Afghanistan               0.1106        3531770          54.5   34124811
# Albania                   0.0119        2016516          14.3    3047987
# Algeria                   0.0196       17291463            23   40969443
# American Samoa            0.0113          17000           NaN      51504
# Andorra                   0.0036          83887           NaN      76965
#
#                public_debt tel_fixed           ...           unemp_rate  \
# Country                                        ...
# Afghanistan            7.3    118769           ...                 23.9
# Albania               71.2    247010           ...                   14
# Algeria               25.8   3130090           ...                 11.7
# American Samoa        12.2     10000           ...                 29.8
# Andorra                 41     38411           ...                  3.7
#
#                urbanization   agr   ind   ser bordering_internet  \
# Country
# Afghanistan            25.5    23  21.1  55.9        778511064.0
# Albania                60.3  22.6  23.8  53.7                NaN
# Algeria                72.6  13.2  36.1  50.7                NaN
# American Samoa         87.2  27.4  12.4  60.2                NaN
# Andorra                88.1  11.9  33.6  54.5         96349969.0
#
#                 bordering_pop  NS_new  EW_new  border_internet_scaled
# Country
# Afghanistan      1.709818e+09    33.0    65.0                0.455318
# Albania          1.541000e+07    41.0    20.0                     NaN
# Algeria          9.353608e+07    28.0     3.0                     NaN
# American Samoa            NaN   -14.2  -170.0                     NaN
# Andorra          1.160643e+08    42.3     1.3                0.830143
#
# [5 rows x 21 columns]

# %%
# Create temorary data frame of just geocoordinates.

new_df = df[['EW_new','NS_new']]

# %%
# This loop is for find countries with the closest geocoordinates. 
# This is useful for islands which don't have bordering countries.
# The value of the internet useres of the closest country will be used if a country has no bordering countries.

country_list = new_df.index
closest_internet = {}

for country in country_list:
    distances = {}
    for i in country_list:
        ns = new_df.loc[i]['NS_new']
        ew = new_df.loc[i]['EW_new']

        d = ((ns - new_df.loc[country]['NS_new'])**2) + ((ew - new_df.loc[country]['EW_new'])**2)
        d = d**(1/2)
        distances[i] = d
        distances.pop(country, None)

    closest_country = min(distances, key=distances.get)
    closest_internet[country] = (float(df.loc[closest_country]['internet_users']))/(float(df.loc[closest_country]['population']))
    
    
df['closest_internet'] = pd.Series(closest_internet)

# %%
df = df.drop(columns = ['bordering_pop', 'bordering_internet', 'EW_new', 'NS_new'])
df.head()
# Out:
#                education_exp       exports gdp_per_capita       imports  \
# Country
# Afghanistan              3.2  7.840000e+08           2000  7.616000e+09
# Albania                  3.5  9.609000e+08          12500  4.084000e+09
# Algeria                  4.3  3.315000e+10          15200  4.999000e+10
# American Samoa           NaN  4.280000e+08          11200  6.150000e+08
# Andorra                  3.3  7.871000e+07          49900  1.257000e+09
#
#                 infant_mortality internet_users pop_below_pov population  \
# Country
# Afghanistan               0.1106        3531770          54.5   34124811
# Albania                   0.0119        2016516          14.3    3047987
# Algeria                   0.0196       17291463            23   40969443
# American Samoa            0.0113          17000           NaN      51504
# Andorra                   0.0036          83887           NaN      76965
#
#                public_debt tel_fixed  tel_cell unemp_rate urbanization   agr  \
# Country
# Afghanistan            7.3    118769  23929713       23.9         25.5    23
# Albania               71.2    247010   3497950         14         60.3  22.6
# Algeria               25.8   3130090  49873389       11.7         72.6  13.2
# American Samoa        12.2     10000       NaN       29.8         87.2  27.4
# Andorra                 41     38411     80337        3.7         88.1  11.9
#
#                  ind   ser  border_internet_scaled  closest_internet
# Country
# Afghanistan     21.1  55.9                0.455318          0.152928
# Albania         23.8  53.7                     NaN          0.701022
# Algeria         36.1  50.7                     NaN          0.496785
# American Samoa  12.4  60.2                     NaN          0.292382
# Andorra         33.6  54.5                0.830143          0.799119

# %%
df.border_internet_scaled.fillna(df.closest_internet, inplace=True)
del df['closest_internet']

# %%
df.head()
# Out:
#                education_exp       exports gdp_per_capita       imports  \
# Country
# Afghanistan              3.2  7.840000e+08           2000  7.616000e+09
# Albania                  3.5  9.609000e+08          12500  4.084000e+09
# Algeria                  4.3  3.315000e+10          15200  4.999000e+10
# American Samoa           NaN  4.280000e+08          11200  6.150000e+08
# Andorra                  3.3  7.871000e+07          49900  1.257000e+09
#
#                 infant_mortality internet_users pop_below_pov population  \
# Country
# Afghanistan               0.1106        3531770          54.5   34124811
# Albania                   0.0119        2016516          14.3    3047987
# Algeria                   0.0196       17291463            23   40969443
# American Samoa            0.0113          17000           NaN      51504
# Andorra                   0.0036          83887           NaN      76965
#
#                public_debt tel_fixed  tel_cell unemp_rate urbanization   agr  \
# Country
# Afghanistan            7.3    118769  23929713       23.9         25.5    23
# Albania               71.2    247010   3497950         14         60.3  22.6
# Algeria               25.8   3130090  49873389       11.7         72.6  13.2
# American Samoa        12.2     10000       NaN       29.8         87.2  27.4
# Andorra                 41     38411     80337        3.7         88.1  11.9
#
#                  ind   ser  border_internet_scaled
# Country
# Afghanistan     21.1  55.9                0.455318
# Albania         23.8  53.7                0.701022
# Algeria         36.1  50.7                0.496785
# American Samoa  12.4  60.2                0.292382
# Andorra         33.6  54.5                0.830143

# %%
# Convert everything into floats

df = df.astype(float)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 229 entries, Afghanistan to European Union
# Data columns (total 17 columns):
# education_exp             179 non-null float64
# exports                   220 non-null float64
# gdp_per_capita            227 non-null float64
# imports                   220 non-null float64
# infant_mortality          224 non-null float64
# internet_users            223 non-null float64
# pop_below_pov             172 non-null float64
# population                229 non-null float64
# public_debt               210 non-null float64
# tel_fixed                 222 non-null float64
# tel_cell                  218 non-null float64
# unemp_rate                215 non-null float64
# urbanization              227 non-null float64
# agr                       223 non-null float64
# ind                       222 non-null float64
# ser                       224 non-null float64
# border_internet_scaled    221 non-null float64
# dtypes: float64(17)
# memory usage: 42.2+ KB

# %%
# Manually filling in some infoprmation. 

df.loc['Hong Kong']['internet_users'] = 6000000.0
df.loc['Taiwan']['internet_users'] = 20600000.0
df.loc['West Bank']['internet_users'] = 2600000.0
df.loc['European Union']['internet_users'] = 398000000.0
df.loc['Iran']['internet_users'] = 36000000.0
df.loc['Vietnam']['internet_users'] = 49700000.0
df.loc['Congo, Democratic Republic of the']['internet_users'] = 3000000
df.loc['Laos']['internet_users'] = 1300000

# Manually filling nans for population below poverty

df.loc['Australia']['pop_below_pov'] = 13.13
df.loc['Antigua and Barbuda']['pop_below_pov'] = 22.0
df.loc['Bahrain']['pop_below_pov'] = 80000.0/1400000.0
df.loc['Barbados']['pop_below_pov'] = 13.9
df.loc['Brunei']['pop_below_pov'] = 1000/423196.0
df.loc['British Virgin Islands']['pop_below_pov'] = 22.0
df.loc['Cayman Islands']['pop_below_pov'] = 1.9
df.loc['Cyprus']['pop_below_pov'] = 16.0
df.loc['Finland']['pop_below_pov'] = 6.0
df.loc['Guernsey']['pop_below_pov'] = 20.0
df.loc['Iceland']['pop_below_pov'] = 8.0
df.loc['Korea, North']['pop_below_pov'] = 40.0
df.loc['Kuwait']['pop_below_pov'] = 7.0
df.loc['Libya']['pop_below_pov'] = 40.0
df.loc['Liechtenstein']['pop_below_pov'] = 10.0
df.loc['Luxembourg']['pop_below_pov'] = 15.0
df.loc['Macau']['pop_below_pov'] = 10.0
df.loc['Marshall Islands']['pop_below_pov'] = 30.0
df.loc['Monaco']['pop_below_pov'] = 0.0
df.loc['Montserrat']['pop_below_pov'] = 25.0
df.loc['Nauru']['pop_below_pov'] = 24.0
df.loc['New Zealand']['pop_below_pov'] = 15.0
df.loc['Northern Mariana Islands']['pop_below_pov'] = 50.0
df.loc['Norway']['pop_below_pov'] = 7.5
df.loc['Puerto Rico']['pop_below_pov'] = 43.0
df.loc['Qatar']['pop_below_pov'] = 0.0
df.loc['Saint Kitts and Nevis']['pop_below_pov'] = 20.0
df.loc['Saint Lucia']['pop_below_pov'] = 15.0
df.loc['Saint Vincent and the Grenadines']['pop_below_pov'] = 20.0
df.loc['Samoa']['pop_below_pov'] = 18.8
df.loc['Saudi Arabia']['pop_below_pov'] = 12.7
df.loc['Singapore']['pop_below_pov'] = 20.0
df.loc['Solomon Islands']['pop_below_pov'] = 12.7
df.loc['Somalia']['pop_below_pov'] = 60.0
df.loc['Vanuatu']['pop_below_pov'] = 12.7

# %%
# Scale some of the columns by their populations

df['total_trade'] = df['exports']+ df['imports']
df['total_trade'] = df['total_trade']/df['population']

df['internet_users'] = df['internet_users']/df['population']

df['total_tel'] = df['tel_cell'] + df['tel_fixed']
df['total_tel'] = df['total_tel']/df['population']


df = df.drop(columns = ['exports','imports','ser','tel_fixed','tel_cell','infant_mortality'])
df = df.dropna()

# %%
import pickle

with open('initial_df.pkl', 'wb') as picklefile:
    pickle.dump(df, picklefile)

# %%
# !ls
# Out:
# 1_initial_web_scrape.ipynb find_train_size.pdf
# 2_feature_selection.ipynb  first_heatmap.pdf
# 3_modeling.ipynb           first_heatmap.svg
# 4_check_normality.ipynb    initial_df.pkl
# First_draft.pptx           internet_heatmap.pdf
# Worldfactbook.png          kids_computer.jpeg
# Worldfactbook_data.png     presentation_final.pptx
# find_degree.pdf            ~$presentation_final.pptx

# %%
df
# Out:
#                      education_exp  gdp_per_capita  internet_users  \
# Country
# Afghanistan                    3.2          2000.0        0.103496
# Albania                        3.5         12500.0        0.661589
# Algeria                        4.3         15200.0        0.422058
# Angola                         3.5          6800.0        0.089470
# Anguilla                       2.8         12200.0        0.799731
# Antigua and Barbuda            2.5         26300.0        0.633372
# Argentina                      5.9         20900.0        0.695069
# Armenia                        2.8          9500.0        0.621234
# Australia                      5.2         50300.0        0.873280
# Austria                        5.4         49900.0        0.839126
# Azerbaijan                     3.0         17500.0        0.775042
# Bahrain                        2.7         48500.0        0.957747
# Bangladesh                     2.5          4200.0        0.180574
# Barbados                       5.1         18700.0        0.793207
# Belarus                        5.0         18900.0        0.712667
# Belgium                        6.6         46600.0        0.858971
# Belize                         7.4          8300.0        0.437732
# Benin                          4.4          2300.0        0.116710
# Bhutan                         7.4          8700.0        0.413230
# Bolivia                        7.3          7500.0        0.390967
# Botswana                       9.6         17800.0        0.392626
# Brazil                         5.9         15600.0        0.592424
# Brunei                         4.4         78200.0        0.689822
# Bulgaria                       4.1         21700.0        0.601890
# Burkina Faso                   4.2          1900.0        0.135469
# Cabo Verde                     5.4          6900.0        0.475241
# Cambodia                       1.9          4000.0        0.251805
# Cameroon                       2.8          3700.0        0.243658
# Canada                         5.3         48300.0        0.891823
# Chile                          4.9         24500.0        0.654936
# ...                            ...             ...             ...
# Sierra Leone                   2.9          1600.0        0.114975
# Singapore                      2.9         93900.0        0.795255
# Slovakia                       4.6         33000.0        0.804755
# Slovenia                       5.3         34400.0        0.757245
# South Africa                   5.9         13500.0        0.534675
# Spain                          4.3         38300.0        0.799119
# Sri Lanka                      3.5         12800.0        0.318016
# Sweden                         7.7         51500.0        0.907729
# Switzerland                    5.1         61400.0        0.887867
# Syria                          5.1          2900.0        0.303788
# Tajikistan                     5.2          3200.0        0.201374
# Tanzania                       3.5          3200.0        0.126462
# Thailand                       4.1         17900.0        0.473568
# Timor-Leste                    7.5          5400.0        0.246541
# Togo                           5.1          1700.0        0.110145
# Tunisia                        6.6         11800.0        0.496785
# Turkey                         4.4         26900.0        0.579359
# Turkmenistan                   3.0         18100.0        0.177887
# Uganda                         2.3          2400.0        0.458652
# Ukraine                        5.9          8700.0        0.526914
# United Kingdom                 5.6         44100.0        0.930179
# United States                  5.0         59500.0        0.755633
# Uruguay                        4.4         22400.0        0.662196
# Vanuatu                        5.5          2700.0        0.235536
# Venezuela                      6.9         12100.0        0.592492
# Vietnam                        5.7          6900.0        0.516846
# West Bank                      5.7          4300.0        0.946162
# Yemen                          4.6          1300.0        0.240146
# Zambia                         1.1          4000.0        0.247699
# Zimbabwe                       8.4          2300.0        0.243624
#
#                      pop_below_pov   population  public_debt  unemp_rate  \
# Country
# Afghanistan              54.500000   34124811.0          7.3        23.9
# Albania                  14.300000    3047987.0         71.2        14.0
# Algeria                  23.000000   40969443.0         25.8        11.7
# Angola                   36.600000   29310273.0         65.3         6.6
# Anguilla                 23.000000      17087.0         20.1         8.0
# Antigua and Barbuda      22.000000      94731.0         86.8        11.0
# Argentina                25.700000   44293293.0         52.6         8.1
# Armenia                  32.000000    3045191.0         53.5        18.9
# Australia                13.130000   23232413.0         41.6         5.6
# Austria                   3.000000    8754413.0         78.8         5.5
# Azerbaijan                4.900000    9961396.0         54.7         6.0
# Bahrain                   0.057143    1410942.0         90.3         3.8
# Bangladesh               24.300000  157826578.0         32.4         4.0
# Barbados                 13.900000     292336.0        132.9        10.5
# Belarus                   5.700000    9549747.0         51.0         1.0
# Belgium                  15.100000   11491346.0        103.2         7.3
# Belize                   41.000000     360346.0         99.0        10.1
# Benin                    36.200000   11038805.0         54.6         1.0
# Bhutan                   12.000000     758288.0        102.4         3.2
# Bolivia                  38.600000   11138234.0         50.9         4.0
# Botswana                 19.300000    2214858.0         15.6        20.0
# Brazil                    4.200000  207353391.0         84.0        11.8
# Brunei                    0.002363     443593.0          2.7         6.9
# Bulgaria                 23.400000    7101510.0         23.9         6.2
# Burkina Faso             40.100000   20107509.0         38.3        77.0
# Cabo Verde               30.000000     560899.0        126.0         9.0
# Cambodia                 16.500000   16204486.0         35.1         0.3
# Cameroon                 30.000000   24994885.0         33.8         4.3
# Canada                    9.400000   35623680.0         89.7         6.5
# Chile                    14.400000   17789267.0         23.6         7.0
# ...                            ...          ...          ...         ...
# Sierra Leone             70.200000    6163195.0         58.4         9.1
# Singapore                20.000000    5888926.0        110.9         2.2
# Slovakia                 12.300000    5445829.0         50.4         8.1
# Slovenia                 13.900000    1972126.0         75.4         6.6
# South Africa             16.600000   54841552.0         52.7        27.6
# Spain                    21.100000   48958159.0         98.4        17.1
# Sri Lanka                 6.700000   22409381.0         79.4         4.5
# Sweden                   15.000000    9960487.0         40.9         6.6
# Switzerland               6.600000    8236303.0         42.8         3.0
# Syria                    82.500000   18028549.0         58.4        50.0
# Tajikistan               31.500000    8468555.0         47.8         2.4
# Tanzania                 22.800000   53950935.0         38.2        10.3
# Thailand                  7.200000   68414135.0         41.9         0.7
# Timor-Leste              41.800000    1291358.0          0.0         4.4
# Togo                     55.100000    7965055.0         78.6         6.9
# Tunisia                  15.500000   11403800.0         71.3        15.9
# Turkey                   21.900000   80845215.0         28.5        11.2
# Turkmenistan              0.200000    5351277.0         28.8        11.0
# Uganda                   21.400000   39570125.0         39.0         9.4
# Ukraine                   3.800000   44033874.0         75.6         9.5
# United Kingdom           15.000000   65648100.0         87.0         4.4
# United States            15.100000  326625791.0         82.3         4.4
# Uruguay                   9.700000    3360148.0         66.2         7.3
# Vanuatu                  12.700000     282814.0         48.4         1.7
# Venezuela                19.700000   31304016.0         34.9        26.4
# Vietnam                   8.000000   96160163.0         58.2         2.2
# West Bank                18.000000    2747943.0         24.4        26.7
# Yemen                    54.000000   28036829.0        135.5        27.0
# Zambia                   54.400000   15972001.0         62.8        15.0
# Zimbabwe                 72.300000   13805084.0         75.5        11.3
#
#                      urbanization   agr   ind  border_internet_scaled  \
# Country
# Afghanistan                  25.5  23.0  21.1                0.455318
# Albania                      60.3  22.6  23.8                0.701022
# Algeria                      72.6  13.2  36.1                0.496785
# Angola                       65.5  10.2  61.4                0.255319
# Anguilla                    100.0   2.4  21.3                0.739827
# Antigua and Barbuda          24.6   2.3  20.2                0.540438
# Argentina                    91.9  10.9  28.2                0.586394
# Armenia                      63.1  17.7  27.8                0.320797
# Australia                    86.0   3.6  26.1                0.246541
# Austria                      58.3   1.2  28.4                0.781125
# Azerbaijan                   55.7   6.2  49.1                0.510920
# Bahrain                      89.3   0.3  38.2                0.920085
# Bangladesh                   36.6  14.2  29.2                0.290632
# Barbados                     31.1   1.4   4.8                0.521231
# Belarus                      78.6   8.3  40.6                0.714073
# Belgium                      98.0   0.7  21.8                0.880070
# Belize                       45.7   9.7  13.8                0.561115
# Benin                        47.3  25.6  23.1                0.219234
# Bhutan                       40.9  15.7  42.6                0.415240
# Bolivia                      69.4  13.0  37.4                0.594563
# Botswana                     69.4   1.7  29.2                0.429352
# Brazil                       86.6   6.2  21.0                0.572513
# Brunei                       77.6   1.2  56.5                0.777036
# Bulgaria                     75.0   4.3  28.0                0.587819
# Burkina Faso                 29.4  31.9  22.0                0.190486
# Cabo Verde                   65.7   7.9  17.9                0.181238
# Cambodia                     23.4  25.3  32.8                0.188693
# Cameroon                     56.4  23.1  28.0                0.235269
# Canada                       81.4   1.7  28.1                0.755633
# Chile                        87.6   4.4  31.4                0.568035
# ...                           ...   ...   ...                     ...
# Sierra Leone                 42.1  60.7   6.5                0.087697
# Singapore                   100.0   0.0  24.8                0.777036
# Slovakia                     53.7   3.8  35.0                0.658778
# Slovenia                     54.5   1.8  32.2                0.662483
# South Africa                 66.4   2.8  29.7                0.216094
# Spain                        80.3   2.6  23.2                0.713513
# Sri Lanka                    18.5   7.8  30.5                0.591303
# Sweden                       87.4   1.6  33.0                0.917573
# Switzerland                  73.8   0.7  25.6                0.800442
# Syria                        54.2  20.0  19.6                0.492391
# Tajikistan                   27.1  28.6  25.5                0.517626
# Tanzania                     33.8  23.4  28.6                0.260588
# Thailand                     49.9   8.2  36.2                0.389028
# Timor-Leste                  30.6   9.4  57.8                0.251458
# Togo                         41.7  28.1  21.6                0.227471
# Tunisia                      68.9   9.9  25.6                0.390941
# Turkey                       75.1   6.7  31.8                0.213482
# Turkmenistan                 51.6   7.5  44.9                0.191081
# Uganda                       23.8  25.8  23.2                0.312959
# Ukraine                      69.4  14.0  27.8                0.743201
# United Kingdom               83.4   0.6  19.0                0.812083
# United States                82.3   0.9  18.9                0.656087
# Uruguay                      95.3   6.2  25.0                0.610491
# Vanuatu                      25.3  27.0   9.1                0.720249
# Venezuela                    88.2   4.4  38.2                0.588594
# Vietnam                      35.9  15.3  33.3                0.523875
# West Bank                    76.2   3.0  21.1                0.626556
# Yemen                        36.6  24.1  14.3                0.696427
# Zambia                       43.5   5.4  35.6                0.140730
# Zimbabwe                     32.2  12.5  26.9                0.388461
#
#                        total_trade  total_tel
# Country
# Afghanistan             246.155209   0.704721
# Albania                1655.157978   1.228667
# Algeria                2029.317313   1.293732
# Angola                 1938.569457   0.460078
# Anguilla               6747.819980   1.872769
# Antigua and Barbuda    5088.091543   2.137674
# Argentina              2719.824873   1.612608
# Armenia                1836.994789   1.311482
# Australia             18934.752925   0.000002
# Austria               37706.697182   2.134597
# Azerbaijan             2451.865180   0.169488
# Bahrain               20050.434391   1.878033
# Bangladesh              496.050798   0.923950
# Barbados               6832.890920   1.633176
# Belarus                5277.626727   1.619210
# Belgium               53535.939132   1.410858
# Belize                 3962.302898   0.693778
# Benin                   381.200683   0.799890
# Bhutan                 2215.517059   0.991690
# Bolivia                1550.874223   0.983758
# Botswana               6130.415584   1.526868
# Brazil                 1786.322366   1.337651
# Brunei                20403.838654   1.395299
# Bulgaria               9623.305466   1.384948
# Burkina Faso            284.470841   0.896301
# Cabo Verde             1574.971608   1.207399
# Cambodia               1529.823285   1.154365
# Cameroon                419.765884   0.816370
# Canada                24610.034674   1.295752
# Chile                  6994.667065   1.473151
# ...                            ...        ...
# Sierra Leone            389.538218   1.021592
# Singapore            118918.118516   1.773821
# Slovakia              29110.352161   1.446354
# Slovenia              29881.457878   1.602538
# South Africa           2889.597289   1.741516
# Spain                 12968.216391   1.474027
# Sri Lanka              1431.097093   1.374525
# Sweden                32578.728329   1.529054
# Switzerland           75701.440319   0.445893
# Syria                   412.401464   0.151216
# Tajikistan              415.619902   0.055264
# Tanzania                255.862109   0.742915
# Thailand               6112.771871   0.000002
# Timor-Leste             448.055458   1.199503
# Togo                    378.026266   0.785442
# Tunisia                3292.762062   1.354570
# Turkey                 4379.974746   1.102213
# Turkmenistan           2278.895299   0.124271
# Uganda                  189.385300   0.637126
# Ukraine                1845.624575   1.428476
# United Kingdom        15826.809915   1.710854
# United States         12025.994604   0.000002
# Uruguay                5272.386812   1.855438
# Vanuatu                1038.845319   0.818612
# Venezuela              1498.529773   0.971837
# Vietnam                4420.749578   1.295154
# West Bank              3068.113130   1.676765
# Yemen                   180.983377   0.627706
# Zambia                  966.816869   0.847732
# Zimbabwe                678.590583   1.039925
#
# [148 rows x 13 columns]
